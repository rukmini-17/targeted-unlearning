# %%
# Cell 1: Install everything
# !pip install -q transformers datasets accelerate
# !pip install -q git+https://github.com/kmeng01/rome.git 2>/dev/null || echo "ROME install attempted"

# Clone ROME repo directly (more reliable)
import os
if not os.path.exists("rome"):
    # !git clone https://github.com/kmeng01/rome.git
# %cd rome
# !pip install -q -r requirements.txt
# Out:
# ROME install attempted
# Cloning into 'rome'...
# remote: Enumerating objects: 768, done.
# remote: Counting objects: 100% (439/439), done.
# remote: Compressing objects: 100% (189/189), done.
# remote: Total 768 (delta 343), reused 250 (delta 250), pack-reused 329 (from 1)
# Receiving objects: 100% (768/768), 22.69 MiB | 16.60 MiB/s, done.
# Resolving deltas: 100% (460/460), done.
# /content/rome
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# Cell 2: Load model and inspect layer names
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

MODEL_NAME = "Qwen/Qwen3-0.6B"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    trust_remote_code=True,
    torch_dtype=torch.float16,
    device_map="auto"
)
model.eval()

# Print MLP-related layer names to find the right keys for the config
print("=== MLP layers ===")
for name, mod in model.named_modules():
    parts = name.split(".")
    if "mlp" in name and len(parts) <= 4:
        print(name, "->", type(mod).__name__)

print("\n=== Attention layers (first 2) ===")
count = 0
for name, mod in model.named_modules():
    if "attn" in name and len(name.split(".")) <= 4:
        print(name, "->", type(mod).__name__)
        count += 1
        if count >= 6:
            break

print("\n=== Total layers ===")
print("Num hidden layers:", model.config.num_hidden_layers)
print("Hidden size:", model.config.hidden_size)
print("Intermediate size:", model.config.intermediate_size if hasattr(model.config, 'intermediate_size') else "N/A")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/726 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/1.50G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/311 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.embed_tokens.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# generation_config.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# === MLP layers ===
# model.layers.0.mlp -> Qwen3MLP
# model.layers.1.mlp -> Qwen3MLP
# model.layers.2.mlp -> Qwen3MLP
# model.layers.3.mlp -> Qwen3MLP
# model.layers.4.mlp -> Qwen3MLP
# model.layers.5.mlp -> Qwen3MLP
# model.layers.6.mlp -> Qwen3MLP
# model.layers.7.mlp -> Qwen3MLP
# model.layers.8.mlp -> Qwen3MLP
# model.layers.9.mlp -> Qwen3MLP
# model.layers.10.mlp -> Qwen3MLP
# model.layers.11.mlp -> Qwen3MLP
# model.layers.12.mlp -> Qwen3MLP
# model.layers.13.mlp -> Qwen3MLP
# model.layers.14.mlp -> Qwen3MLP
# model.layers.15.mlp -> Qwen3MLP
# model.layers.16.mlp -> Qwen3MLP
# model.layers.17.mlp -> Qwen3MLP
# model.layers.18.mlp -> Qwen3MLP
# model.layers.19.mlp -> Qwen3MLP
# model.layers.20.mlp -> Qwen3MLP
# model.layers.21.mlp -> Qwen3MLP
# model.layers.22.mlp -> Qwen3MLP
# model.layers.23.mlp -> Qwen3MLP
# model.layers.24.mlp -> Qwen3MLP
# model.layers.25.mlp -> Qwen3MLP
# model.layers.26.mlp -> Qwen3MLP
# model.layers.27.mlp -> Qwen3MLP
#
# === Attention layers (first 2) ===
# model.layers.0.self_attn -> Qwen3Attention
# model.layers.1.self_attn -> Qwen3Attention
# model.layers.2.self_attn -> Qwen3Attention
# model.layers.3.self_attn -> Qwen3Attention
# model.layers.4.self_attn -> Qwen3Attention
# model.layers.5.self_attn -> Qwen3Attention
#
# === Total layers ===
# Num hidden layers: 28
# Hidden size: 1024
# Intermediate size: 3072

# %% [markdown]
# #ROME

# %%
import os, sys

# ============================================================
# ROME patches
# ============================================================

# ROME compute_v.py — fix torch.dot dtype
with open("/content/rome/rome/compute_v.py", "r") as f:
    src = f.read()

for old, new in [
    (
        "    right_vector = (target - cur_output) / torch.dot(cur_input, left_vector)",
        "    right_vector = (target - cur_output) / torch.dot(cur_input.float(), left_vector.float())"
    ),
    (
        '    print(f"Division Factor: {torch.dot(cur_input, left_vector).item()}")',
        '    print(f"Division Factor: {torch.dot(cur_input.float(), left_vector.float()).item()}")'
    ),
]:
    if old in src:
        src = src.replace(old, new)
        print(f"✅ rome/compute_v.py patched: {old[:55]}")
    else:
        print(f"ℹ️ Already patched: {old[:55]}")

with open("/content/rome/rome/compute_v.py", "w") as f:
    f.write(src)

# ROME rome_main.py — fix dtype mismatch on matrix multiply
with open("/content/rome/rome/rome_main.py", "r") as f:
    src = f.read()

for old, new in [
    (
        "            upd_matrix = left_vector.unsqueeze(1) @ right_vector.unsqueeze(0)",
        "            upd_matrix = left_vector.unsqueeze(1).to(weights[weight_name].dtype) @ right_vector.unsqueeze(0).to(weights[weight_name].dtype)"
    ),
    (
        "                upd_matrix = delta_u.unsqueeze(1) @ delta_v.unsqueeze(0)",
        "                upd_matrix = delta_u.unsqueeze(1).float() @ delta_v.unsqueeze(0).float()"
    ),
]:
    if old in src:
        src = src.replace(old, new)
        print(f"✅ rome/rome_main.py patched: {old[:55]}")
    else:
        print(f"ℹ️ Already patched: {old[:55]}")

with open("/content/rome/rome/rome_main.py", "w") as f:
    f.write(src)

# ============================================================
# MEMIT patches
# ============================================================

# MEMIT memit_main.py — dtype + force_recompute + cov
with open("/content/memit/memit/memit_main.py", "r") as f:
    src = f.read()

for old, new in [
    (
        "upd_matrix = key_mat @ val_mat.T",
        "upd_matrix = key_mat.float() @ val_mat.float().T"
    ),
    (
        "upd_matrix = resid @ adj_k.T",
        "upd_matrix = resid.float() @ adj_k.float().T"
    ),
    (
        """        stat = layer_stats(
            model,
            tok,
            layer_name,
            STATS_DIR,
            mom2_dataset,
            to_collect=["mom2"],
            sample_size=mom2_n_samples,
            precision=mom2_dtype,
            force_recompute=force_recompute,
        )""",
        """        stat = layer_stats(
            model,
            tok,
            layer_name,
            STATS_DIR,
            mom2_dataset,
            to_collect=["mom2"],
            sample_size=mom2_n_samples,
            precision=mom2_dtype,
        )"""
    ),
]:
    if old in src:
        src = src.replace(old, new)
        print(f"✅ memit/memit_main.py patched: {old[:55]}")
    else:
        print(f"ℹ️ Already patched: {old[:55]}")

# Patch get_cov call to always return None (skip wikipedia covariance)
import re
cov_pattern = r'cov = get_cov\([^)]+\)(?:\s*if\s*hparams\.mom2_adjustment\s*else\s*None)?'
if re.search(cov_pattern, src):
    src = re.sub(cov_pattern, "cov = None  # mom2_adjustment disabled", src)
    print("✅ memit/memit_main.py get_cov patched")
else:
    print("ℹ️ get_cov already patched")

with open("/content/memit/memit/memit_main.py", "w") as f:
    f.write(src)

# MEMIT compute_z.py — fix tensor indexing + log_probs dim + gather
with open("/content/memit/memit/compute_z.py", "r") as f:
    src = f.read()

# Fix 1: cur_out indexing
for old in [
    """                if cur_out[0].dim() == 3:
                    if cur_out[0].dim() == 3:
                    cur_out[0][i, idx, :] += delta
                else:
                    cur_out[0][idx, :] += delta
                else:
                    cur_out[0][idx, :] += delta""",
    """                if cur_out[0].dim() == 3:
                    cur_out[0][i, idx, :] += delta
                else:
                    cur_out[0][idx, :] += delta""",
    "                cur_out[0][i, idx, :] += delta",
]:
    if old in src:
        src = src.replace(old,
            """                if cur_out[0].dim() == 3:
                    cur_out[0][i, idx, :] += delta
                else:
                    cur_out[0][idx, :] += delta""")
        print("✅ memit/compute_z.py fix 1 (cur_out indexing) applied")
        break

# Fix 2: log_probs + gather — handle all possible states
for old in [
    # fully patched correct state
    """        if log_probs.dim() == 3:
            log_probs = log_probs.squeeze(0)
        # log_probs is now [seq, vocab]
        loss = torch.gather(
            log_probs,
            1,
            torch.where(rewriting_targets != -100, rewriting_targets, 0),
        )""",
    # partially patched states
    """        log_probs = log_probs.squeeze(0) if log_probs.dim() == 3 else log_probs
        if log_probs.dim() == 2:
            loss = torch.gather(
                log_probs,
                1,
                torch.where(rewriting_targets != -100, rewriting_targets, 0).unsqueeze(1),
            ).squeeze(1)
        else:
            loss = torch.gather(
                log_probs,
                2,
                torch.where(rewriting_targets != -100, rewriting_targets, 0).unsqueeze(2),
            ).squeeze(2)""",
    # original unpatched
    """        log_probs = torch.log_softmax(ln_f(full_repr) @ lm_w + lm_b, dim=2)
        loss = torch.gather(
            log_probs,
            2,
            torch.where(rewriting_targets != -100, rewriting_targets, 0).unsqueeze(2),
        ).squeeze(2)""",
]:
    if old in src:
        src = src.replace(old,
            """        _repr = ln_f(full_repr)
        if _repr.dim() == 2:
            log_probs = torch.log_softmax(_repr @ lm_w + lm_b, dim=1)
        else:
            log_probs = torch.log_softmax(_repr @ lm_w + lm_b, dim=2).squeeze(0)
        if log_probs.dim() == 3:
            log_probs = log_probs.squeeze(0)
        # log_probs is now [seq, vocab]
        loss = torch.gather(
            log_probs,
            1,
            torch.where(rewriting_targets != -100, rewriting_targets, 0),
        )""")
        print("✅ memit/compute_z.py fix 2 (log_probs + gather) applied")
        break

with open("/content/memit/memit/compute_z.py", "w") as f:
    f.write(src)

print("\n✅ All patches written to disk — safe to restart runtime now")
# Out:
# ℹ️ Already patched:     right_vector = (target - cur_output) / torch.dot(cu
# ℹ️ Already patched:     print(f"Division Factor: {torch.dot(cur_input, left
# ℹ️ Already patched:             upd_matrix = left_vector.unsqueeze(1) @ rig
# ℹ️ Already patched:                 upd_matrix = delta_u.unsqueeze(1) @ del
# ✅ memit/memit_main.py patched: upd_matrix = key_mat @ val_mat.T
# ✅ memit/memit_main.py patched: upd_matrix = resid @ adj_k.T
# ✅ memit/memit_main.py patched:         stat = layer_stats(
#             model,
#
# ✅ memit/memit_main.py get_cov patched
# ✅ memit/compute_z.py fix 1 (cur_out indexing) applied
# ✅ memit/compute_z.py fix 2 (log_probs + gather) applied
#
# ✅ All patches written to disk — safe to restart runtime now

# %%
with open("/content/rome/rome/compute_v.py", "r") as f:
    src = f.read()

old = '    print(f"Division Factor: {torch.dot(cur_input, left_vector).item()}")'
new = '    print(f"Division Factor: {torch.dot(cur_input.float(), left_vector.float()).item()}")'

if old in src:
    src = src.replace(old, new)
    with open("/content/rome/rome/compute_v.py", "w") as f:
        f.write(src)
    print("✅ compute_v.py patched")
else:
    print("❌ Pattern not found — check dot() lines:")
    for i, line in enumerate(src.split("\n")):
        if "torch.dot" in line:
            print(f"  {i}: {line}")

import importlib, rome.compute_v, rome.rome_main
importlib.reload(rome.compute_v)
importlib.reload(rome.rome_main)
from rome.rome_main import apply_rome_to_model
print("✅ apply_rome_to_model reloaded from patched source")
# Out:
# ❌ Pattern not found — check dot() lines:
#   180:     right_vector = (target - cur_output) / torch.dot(cur_input, left_vector)
#   185:     print(f"Division Factor: {torch.dot(cur_input.float(), left_vector.float()).item()}")
# ✅ apply_rome_to_model reloaded from patched source

# %%
with open("/content/rome/rome/compute_v.py", "r") as f:
    src = f.read()

old = "    right_vector = (target - cur_output) / torch.dot(cur_input, left_vector)"
new = "    right_vector = (target - cur_output) / torch.dot(cur_input.float(), left_vector.float())"

if old in src:
    src = src.replace(old, new)
    with open("/content/rome/rome/compute_v.py", "w") as f:
        f.write(src)
    print("✅ Line 180 patched")
else:
    print("❌ Not found — printing line 180 context:")
    for i, line in enumerate(src.split("\n")[175:190], start=175):
        print(f"  {i}: {line}")

import importlib, rome.compute_v, rome.rome_main
importlib.reload(rome.compute_v)
importlib.reload(rome.rome_main)
from rome.rome_main import apply_rome_to_model
print("✅ Reloaded")
# Out:
# ✅ Line 180 patched
# ✅ Reloaded

# %%
# Cell - Patch compute_u.py to handle dtype mismatch

with open("/content/rome/rome/compute_u.py", "r") as f:
    src = f.read()
print(src)
# Out:
# import os
# from pathlib import Path
# from typing import Dict, List
#
# import torch
# from transformers import AutoModelForCausalLM, AutoTokenizer
#
# from rome import repr_tools
# from util.globals import *
#
# from .layer_stats import layer_stats
# from .rome_hparams import ROMEHyperParams
#
# # Cache variables
# inv_mom2_cache = {}
#
#
# def get_inv_cov(
#     model: AutoModelForCausalLM,
#     tok: AutoTokenizer,
#     layer_name: str,
#     mom2_dataset: str,
#     mom2_n_samples: str,
#     mom2_dtype: str,
# ) -> torch.Tensor:
#     """
#     Retrieves covariance statistics, then computes the algebraic inverse.
#     Caches result for future use.
#     """
#
#     global inv_mom2_cache
#
#     model_name = model.config._name_or_path.replace("/", "_")
#     key = (model_name, layer_name)
#
#     if key not in inv_mom2_cache:
#         print(
#             f"Retrieving inverse covariance statistics for {model_name} @ {layer_name}. "
#             f"The result will be cached to avoid repetitive computation."
#         )
#         stat = layer_stats(
#             model,
#             tok,
#             layer_name,
#             STATS_DIR,
#             mom2_dataset,
#             to_collect=["mom2"],
#             sample_size=mom2_n_samples,
#             precision=mom2_dtype,
#         )
#         inv_mom2_cache[key] = torch.inverse(
#             stat.mom2.moment().to("cuda")
#         ).float()  # Cast back to float32
#
#     return inv_mom2_cache[key]
#
#
# def compute_u(
#     model: AutoModelForCausalLM,
#     tok: AutoTokenizer,
#     request: Dict,
#     hparams: ROMEHyperParams,
#     layer: int,
#     context_templates: List[str],
# ) -> torch.Tensor:
#     """
#     Computes the right vector used in constructing the rank-1 update matrix.
#     """
#
#     print("Computing left vector (u)...")
#
#     # Compute projection token
#     word_repr_args = dict(
#         model=model,
#         tok=tok,
#         layer=layer,
#         module_template=hparams.rewrite_module_tmp,
#         track="in",
#     )
#     if "subject_" in hparams.fact_token and hparams.fact_token.index("subject_") == 0:
#         word = request["subject"]
#         print(f"Selected u projection object {word}")
#         cur_repr = repr_tools.get_reprs_at_word_tokens(
#             context_templates=[
#                 templ.format(request["prompt"]) for templ in context_templates
#             ],
#             words=[word for _ in range(len(context_templates))],
#             subtoken=hparams.fact_token[len("subject_") :],
#             **word_repr_args,
#         ).mean(0)
#     elif hparams.fact_token == "last":
#         # Heuristic to choose last word. Not a huge deal if there's a minor
#         # edge case (e.g. multi-token word) because the function below will
#         # take the last token.
#         cur_repr = repr_tools.get_reprs_at_idxs(
#             contexts=[
#                 templ.format(request["prompt"].format(request["subject"]))
#                 for templ in context_templates
#             ],
#             idxs=[[-1] for _ in range(len(context_templates))],
#             **word_repr_args,
#         ).mean(0)
#         print("Selected u projection token with last token")
#     else:
#         raise ValueError(f"fact_token={hparams.fact_token} not recognized")
#
#     # Apply inverse second moment adjustment
#     u = cur_repr
#     if hparams.mom2_adjustment:
#         u = get_inv_cov(
#             model,
#             tok,
#             hparams.rewrite_module_tmp.format(layer),
#             hparams.mom2_dataset,
#             hparams.mom2_n_samples,
#             hparams.mom2_dtype,
#         ) @ u.unsqueeze(1)
#         u = u.squeeze()
#
#     return u / u.norm()

# %%
import inspect
print(inspect.getsource(ROMEHyperParams))
# Out:
# @dataclass
# class ROMEHyperParams(HyperParams):
#     # Method
#     layers: List[int]
#     fact_token: str
#     v_num_grad_steps: int
#     v_lr: float
#     v_loss_layer: int
#     v_weight_decay: float
#     clamp_norm_factor: float
#     kl_factor: float
#     mom2_adjustment: bool
#     context_template_length_params: List[List[int]]
#
#     # Module templates
#     rewrite_module_tmp: str
#     layer_module_tmp: str
#     mlp_module_tmp: str
#     attn_module_tmp: str
#     ln_f_module: str
#     lm_head_module: str
#
#     # Statistics
#     mom2_dataset: str
#     mom2_n_samples: int
#     mom2_dtype: str

# %%
hparams_data = {
    "layers": [17],
    "fact_token": "subject_last",
    "v_num_grad_steps": 20,
    "v_lr": 0.5,
    "v_loss_layer": 27,
    "v_weight_decay": 0.5,
    "clamp_norm_factor": 4,
    "kl_factor": 0.0625,
    "mom2_adjustment": False,
    "context_template_length_params": [[5, 10], [10, 10]],
    "rewrite_module_tmp": "model.layers.{}.mlp.down_proj",
    "layer_module_tmp": "model.layers.{}",
    "mlp_module_tmp": "model.layers.{}.mlp",
    "attn_module_tmp": "model.layers.{}.self_attn",
    "ln_f_module": "model.norm",
    "lm_head_module": "lm_head",
    "mom2_dataset": "wikipedia",
    "mom2_n_samples": 100000,
    "mom2_dtype": "float32"
}

with open(path, "w") as f:
    json.dump(hparams_data, f, indent=2)

hparams = ROMEHyperParams.from_json(path)
print("✅ Hparams loaded:", hparams.rewrite_module_tmp)
# Out:
# ✅ Hparams loaded: model.layers.{}.mlp.down_proj

# %%
with open("/content/rome/rome/rome_main.py", "r") as f:
    src = f.read()

old = "            upd_matrix = left_vector.unsqueeze(1) @ right_vector.unsqueeze(0)"
new = "            upd_matrix = left_vector.unsqueeze(1).to(weights[weight_name].dtype) @ right_vector.unsqueeze(0).to(weights[weight_name].dtype)"

if old in src:
    src = src.replace(old, new)
    with open("/content/rome/rome/rome_main.py", "w") as f:
        f.write(src)
    print("✅ rome_main.py patched")
else:
    print("❌ Pattern not found — printing line 117 context:")
    for i, line in enumerate(src.split("\n")[112:122], start=112):
        print(f"  {i}: {line}")

import importlib, rome.rome_main
importlib.reload(rome.rome_main)
from rome.rome_main import apply_rome_to_model
print("✅ Reloaded")
# Out:
# ✅ rome_main.py patched
# ✅ Reloaded

# %%
with open("/content/rome/rome/rome_main.py", "r") as f:
    src = f.read()

old = "                upd_matrix = delta_u.unsqueeze(1) @ delta_v.unsqueeze(0)"
new = "                upd_matrix = delta_u.unsqueeze(1).float() @ delta_v.unsqueeze(0).float()"

if old in src:
    src = src.replace(old, new)
    with open("/content/rome/rome/rome_main.py", "w") as f:
        f.write(src)
    print("✅ rome_main.py line 44 patched")
else:
    print("❌ Pattern not found — printing context:")
    for i, line in enumerate(src.split("\n")[40:50], start=40):
        print(f"  {i}: {line}")

import importlib, rome.rome_main
importlib.reload(rome.rome_main)
from rome.rome_main import apply_rome_to_model
print("✅ Reloaded")
# Out:
# ✅ rome_main.py line 44 patched
# ✅ Reloaded

# %%
# Patch Qwen3Config to expose n_positions
if not hasattr(model.config, 'n_positions'):
    model.config.n_positions = model.config.max_position_embeddings
    print(f"✅ Patched n_positions = {model.config.n_positions}")

if not hasattr(model.config, 'n_embd'):
    model.config.n_embd = model.config.hidden_size
    print(f"✅ Patched n_embd = {model.config.n_embd}")

# %%
def get_prob(m, prompt, target_str):
    """Returns the raw probability of the target token being the next prediction."""
    target_str = " " + target_str.strip()
    target_id = tokenizer.encode(target_str, add_special_tokens=False)[0]
    inputs = tokenizer(prompt, return_tensors="pt").to(m.device)
    with torch.no_grad():
        logits = m(**inputs).logits[0, -1, :]
        probs = torch.softmax(logits, dim=-1)
    return probs[target_id].item()

def generate(m, prompt, max_new=15):
    inputs = tokenizer(prompt, return_tensors="pt").to(m.device)
    with torch.no_grad():
        out = m.generate(**inputs, max_new_tokens=max_new, do_sample=False)
    return tokenizer.decode(out[0][inputs["input_ids"].shape[1]:], skip_special_tokens=True).strip()

# %%
import sys, os
os.chdir("/content/rome")
sys.path.insert(0, "/content/rome")

from rome.rome_hparams import ROMEHyperParams
# apply_rome_to_model already imported from patched source above

hparams = ROMEHyperParams.from_json("/content/rome/hparams/ROME/Qwen_Qwen3-0.6B.json")
print("✅ Hparams loaded:", hparams.rewrite_module_tmp)

import requests
cf = requests.get("https://rome.baulab.info/data/dsets/counterfact.json").json()
sample = cf[0]
rw = sample["requested_rewrite"]

full_prompt = rw["prompt"].format(rw["subject"])
print(f"Before edit: '{generate(model, full_prompt)}'")

request = {
    "prompt": rw["prompt"],
    "subject": rw["subject"],
    "target_new": {"str": rw["target_new"]["str"]}
}

edited_model, _ = apply_rome_to_model(
    model, tokenizer, [request], hparams,
    copy=True, return_orig_weights=True
)

gen_after = generate(edited_model, full_prompt)
# Bool edit success
edit_success = rw["target_new"]["str"].lower().strip() in gen_after.lower()
print(f"After edit:  '{gen_after}'")
print(f"Target:      '{rw['target_new']['str']}'")
print(f"Edit success (bool): {edit_success}")

del edited_model
torch.cuda.empty_cache()
# Out:
# ✅ Hparams loaded: model.layers.{}.mlp.down_proj
# Before edit: 'a language that is spoken in the region of the country. The region is'
# Executing ROME algorithm for the update: [The mother tongue of Danielle Darrieux is] -> [ English]
# Cached context templates ['{}', 'QuestionAuthorQuestionQuestion. {}', 'AuthorQuestionQuestionQuestion. {}', 'QuestionQuestionQuestionQuestion. {}', 'QuestionQuestion Instructions Instructions. {}', 'Question InstructionsQuestionAuthor. {}', 'Question InstructionsQuestionQuestion. {}', 'QuestionQuestionQuestionQuestion. {}', 'ComparisonAuthorQuestionQuestion. {}', 'QuestionQuestionQuestionQuestion. {}', 'QuestionExplanationQuestionQuestion. {}', 'QuestionQuestionComparisonQuestionExplanationQuestionQuestionQuestionQuestion. {}', 'QuestionAuthorQuestionQuestionQuestionExplanationQuestionQuestionAuthor. {}', 'AuthorExplanationQuestionQuestionComparisonQuestionQuestionQuestionQuestion. {}', 'QuestionComparisonQuestionQuestionAuthor InstructionsQuestionQuestionQuestion. {}', 'QuestionComparisonQuestionComparisonQuestionQuestionQuestionQuestionQuestion. {}', 'ExplanationQuestionQuestionExplanationDescriptionQuestionQuestionExplanationQuestion. {}', 'QuestionAuthorQuestionQuestionComparisonQuestionQuestionExplanationQuestion. {}', 'Description InstructionsQuestionQuestionExplanationQuestionQuestionQuestionQuestion. {}', 'AuthorQuestionExplanationComparisonQuestionQuestionQuestionQuestionComparison. {}', 'AuthorQuestionQuestionComparisonQuestionQuestionExplanationQuestionQuestion. {}']
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 4.548 = 4.548 + 0.0 + 0.0 avg prob of [ English] 0.017306344583630562
# loss 4.121 = 4.112 + 0.002 + 0.007 avg prob of [ English] 0.030210882425308228
# loss 3.928 = 3.912 + 0.004 + 0.012 avg prob of [ English] 0.03599494323134422
# loss 3.635 = 3.614 + 0.005 + 0.016 avg prob of [ English] 0.04551398754119873
# loss 3.163 = 3.135 + 0.008 + 0.02 avg prob of [ English] 0.06638994812965393
# loss 2.482 = 2.445 + 0.013 + 0.024 avg prob of [ English] 0.11584396660327911
# loss 1.606 = 1.558 + 0.021 + 0.028 avg prob of [ English] 0.24298225343227386
# loss 0.796 = 0.733 + 0.031 + 0.031 avg prob of [ English] 0.501590371131897
# loss 0.327 = 0.251 + 0.04 + 0.035 avg prob of [ English] 0.7834087610244751
# loss 0.152 = 0.07 + 0.043 + 0.038 avg prob of [ English] 0.9331350326538086
# loss 0.105 = 0.019 + 0.044 + 0.042 avg prob of [ English] 0.9808111786842346
# loss 0.112 = 0.006 + 0.061 + 0.045 avg prob of [ English] 0.9935855269432068
# loss 0.119 = 0.003 + 0.068 + 0.048 avg prob of [ English] 0.9972735047340393
# loss 0.114 = 0.001 + 0.062 + 0.05 avg prob of [ English] 0.9985939264297485
# loss 0.104 = 0.001 + 0.05 + 0.053 avg prob of [ English] 0.9991512298583984
# loss 0.099 = 0.001 + 0.043 + 0.055 avg prob of [ English] 0.9994261860847473
# loss 0.105 = 0.0 + 0.048 + 0.057 avg prob of [ English] 0.9995671510696411
# loss 0.104 = 0.0 + 0.046 + 0.059 avg prob of [ English] 0.9996505379676819
# loss 0.106 = 0.0 + 0.045 + 0.06 avg prob of [ English] 0.9997057318687439
# loss 0.106 = 0.0 + 0.045 + 0.06 avg prob of [ English] 0.9997397065162659
# Delta norm: 132.63095092773438
# Change in target norm: 33.15625 to 135.53720092773438 => 102.38095092773438
# Division Factor: 43.454498291015625
# Right vector norm: 3.052180051803589
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# After edit:  'English, and she is a native speaker of English, and she is a'
# Target:      'English'
# Edit success (bool): True

# %%
import os
os.chdir("/content/rome")
print("CWD:", os.getcwd())
# Out:
# CWD: /content/rome

# %%
import torch, gc, json

results_rome_full = []

print(f"Running ROME on 50 CounterFact samples (full metrics)...")
print(f"Free GPU: {torch.cuda.mem_get_info()[0]/1e9:.1f} GB\n")

for i, sample in enumerate(cf[:50]):
    rw = sample["requested_rewrite"]
    prompt      = rw["prompt"].format(rw["subject"])
    target_new  = rw["target_new"]["str"]
    target_true = rw["target_true"]["str"]

    request = {
        "prompt":     rw["prompt"],
        "subject":    rw["subject"],
        "target_new": {"str": target_new}
    }

    baseline_p = get_prob(model, prompt, target_new)
    gen_before = generate(model, prompt)

    try:
        edited_model, _ = apply_rome_to_model(
            model, tokenizer, [request], hparams,
            copy=True, return_orig_weights=True
        )

        p_after   = get_prob(edited_model, prompt, target_new)
        gen_after = generate(edited_model, prompt)
        is_success = target_new.lower().strip() in gen_after.lower()

        # Paraphrase success
        para_prompts = sample.get("paraphrase_prompts", [])
        para_hits = sum(
            target_new.lower() in generate(edited_model, p).lower()
            for p in para_prompts[:3]
        )
        para_score = para_hits / len(para_prompts[:3]) if para_prompts else None

        # Over-extinction (neighborhood bleed)
        nbr_prompts = sample.get("neighborhood_prompts", [])
        nbr_bleed = sum(
            target_new.lower() in generate(edited_model, p).lower()
            for p in nbr_prompts[:3]
        )
        nbr_bleed_score = nbr_bleed / len(nbr_prompts[:3]) if nbr_prompts else None

        # Neighborhood preservation
        nbr_preserved = sum(
            target_true.lower() in generate(edited_model, p).lower()
            for p in nbr_prompts[:3]
        )
        nbr_preserved_score = nbr_preserved / len(nbr_prompts[:3]) if nbr_prompts else None

        del edited_model
        torch.cuda.empty_cache()
        gc.collect()

        results_rome_full.append({
            # Raw results
            "idx": i, "subject": rw["subject"], "prompt": prompt,
            "target_true": target_true, "target_new": target_new,
            "gen_before": gen_before, "gen_after": gen_after,
            "baseline_prob": round(baseline_p, 4),
            "edit_prob": round(p_after, 4),
            # Harness schema fields
            "method": "ROME",
            "model": "Qwen/Qwen3-0.6B",
            "n_steps": 1,
            "edit_success": 1.0 if is_success else 0.0,
            "paraphrase_success": para_score,
            "over_extinction": nbr_bleed_score,
            "neighborhood_preservation": nbr_preserved_score,
            "locality_drop": None,
            "kl_final": None,
        })
        print(f"[{i:02d}] {'✅' if is_success else '❌'} "
              f"para={para_score:.0%} oe={nbr_bleed_score:.0%} "
              f"pres={nbr_preserved_score:.0%} | {gen_after[:35]!r}")

    except Exception as e:
        print(f"[{i:02d}] ERROR: {e}")
        results_rome_full.append({"idx": i, "error": str(e),
                                  "edit_success": 0.0, "method": "ROME"})

# Summary
n_success = sum(1 for r in results_rome_full if r.get("edit_success") == 1.0)
oe_scores = [r["over_extinction"] for r in results_rome_full if r.get("over_extinction") is not None]
para_scores = [r["paraphrase_success"] for r in results_rome_full if r.get("paraphrase_success") is not None]

print(f"\n{'='*55}")
print(f"  ROME — Qwen3-0.6B — 50 samples")
print(f"{'='*55}")
print(f"  Edit success:       {n_success}/50 = {n_success/50:.1%}")
print(f"  Paraphrase success: {sum(para_scores)/len(para_scores):.1%}")
print(f"  Over-extinction:    {sum(oe_scores)/len(oe_scores):.1%}")
print(f"{'='*55}")

with open("/content/rome_full_metrics.json", "w") as f:
    json.dump({
        "method": "ROME", "model": "Qwen/Qwen3-0.6B",
        "dataset": "CounterFact", "n_samples": 50,
        "metrics": {
            "edit_success_rate": n_success / 50,
            "paraphrase_success": sum(para_scores)/len(para_scores) if para_scores else None,
            "over_extinction": sum(oe_scores)/len(oe_scores) if oe_scores else None,
        },
        "samples": results_rome_full
    }, f, indent=2)
print("Saved: rome_full_metrics.json")

from google.colab import files
files.download("/content/rome_full_metrics.json")
# Out:
# Running ROME on 50 CounterFact samples (full metrics)...
# Free GPU: 13.8 GB
#
# Executing ROME algorithm for the update: [The mother tongue of Danielle Darrieux is] -> [ English]
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 4.548 = 4.548 + 0.0 + 0.0 avg prob of [ English] 0.017306344583630562
# loss 4.121 = 4.112 + 0.002 + 0.007 avg prob of [ English] 0.030210882425308228
# loss 3.928 = 3.912 + 0.004 + 0.012 avg prob of [ English] 0.03599494323134422
# loss 3.635 = 3.614 + 0.005 + 0.016 avg prob of [ English] 0.04551398754119873
# loss 3.163 = 3.135 + 0.008 + 0.02 avg prob of [ English] 0.06638994812965393
# loss 2.482 = 2.445 + 0.013 + 0.024 avg prob of [ English] 0.11584396660327911
# loss 1.606 = 1.558 + 0.021 + 0.028 avg prob of [ English] 0.24298225343227386
# loss 0.796 = 0.733 + 0.031 + 0.031 avg prob of [ English] 0.501590371131897
# loss 0.327 = 0.251 + 0.04 + 0.035 avg prob of [ English] 0.7834087610244751
# loss 0.152 = 0.07 + 0.043 + 0.038 avg prob of [ English] 0.9331350326538086
# loss 0.105 = 0.019 + 0.044 + 0.042 avg prob of [ English] 0.9808111786842346
# loss 0.112 = 0.006 + 0.061 + 0.045 avg prob of [ English] 0.9935855269432068
# loss 0.119 = 0.003 + 0.068 + 0.048 avg prob of [ English] 0.9972735047340393
# loss 0.114 = 0.001 + 0.062 + 0.05 avg prob of [ English] 0.9985939264297485
# loss 0.104 = 0.001 + 0.05 + 0.053 avg prob of [ English] 0.9991512298583984
# loss 0.099 = 0.001 + 0.043 + 0.055 avg prob of [ English] 0.9994261860847473
# loss 0.105 = 0.0 + 0.048 + 0.057 avg prob of [ English] 0.9995671510696411
# loss 0.104 = 0.0 + 0.046 + 0.059 avg prob of [ English] 0.9996505379676819
# loss 0.106 = 0.0 + 0.045 + 0.06 avg prob of [ English] 0.9997057318687439
# loss 0.106 = 0.0 + 0.045 + 0.06 avg prob of [ English] 0.9997397065162659
# Delta norm: 132.63095092773438
# Change in target norm: 33.15625 to 135.53720092773438 => 102.38095092773438
# Division Factor: 43.454498291015625
# Right vector norm: 3.052180051803589
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [00] ✅ para=0% oe=67% pres=0% | 'English, and she is a native speake'
# Executing ROME algorithm for the update: [The official religion of Edwin of Northumbria is] -> [ Islam]
# Computing left vector (u)...
# Selected u projection object Edwin of Northumbria
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: The official religion of Edwin of Northumbria is | Token: ria
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 5.142 = 5.142 + 0.0 + 0.0 avg prob of [ Islam] 0.008325861766934395
# loss 4.306 = 4.289 + 0.003 + 0.014 avg prob of [ Islam] 0.019752535969018936
# loss 3.888 = 3.859 + 0.007 + 0.023 avg prob of [ Islam] 0.03000725992023945
# loss 3.278 = 3.238 + 0.01 + 0.031 avg prob of [ Islam] 0.05427034944295883
# loss 2.402 = 2.351 + 0.013 + 0.038 avg prob of [ Islam] 0.1233292818069458
# loss 1.509 = 1.444 + 0.019 + 0.045 avg prob of [ Islam] 0.2731795310974121
# loss 0.895 = 0.81 + 0.033 + 0.053 avg prob of [ Islam] 0.4719986915588379
# loss 0.537 = 0.425 + 0.052 + 0.06 avg prob of [ Islam] 0.6650676727294922
# loss 0.331 = 0.198 + 0.067 + 0.066 avg prob of [ Islam] 0.8230129480361938
# loss 0.228 = 0.089 + 0.066 + 0.073 avg prob of [ Islam] 0.9149068593978882
# loss 0.18 = 0.046 + 0.056 + 0.078 avg prob of [ Islam] 0.9555838704109192
# loss 0.159 = 0.028 + 0.048 + 0.083 avg prob of [ Islam] 0.9720521569252014
# loss 0.148 = 0.022 + 0.043 + 0.083 avg prob of [ Islam] 0.977999746799469
# loss 0.141 = 0.018 + 0.04 + 0.083 avg prob of [ Islam] 0.9816797375679016
# loss 0.137 = 0.016 + 0.038 + 0.083 avg prob of [ Islam] 0.9841539263725281
# loss 0.134 = 0.014 + 0.037 + 0.083 avg prob of [ Islam] 0.986052930355072
# loss 0.133 = 0.013 + 0.038 + 0.083 avg prob of [ Islam] 0.9874780178070068
# loss 0.133 = 0.011 + 0.039 + 0.083 avg prob of [ Islam] 0.9886950850486755
# loss 0.132 = 0.01 + 0.039 + 0.083 avg prob of [ Islam] 0.9897451996803284
# loss 0.13 = 0.009 + 0.038 + 0.083 avg prob of [ Islam] 0.9906810522079468
# Delta norm: 96.81770324707031
# Change in target norm: 24.203125 to 100.25507354736328 => 76.05194854736328
# Division Factor: 34.269657135009766
# Right vector norm: 2.8251726627349854
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [01] ✅ para=100% oe=100% pres=0% | 'Islam, and Islam is the official re'
# Executing ROME algorithm for the update: [Toko Yasuda, the] -> [ piano]
# Computing left vector (u)...
# Selected u projection object Toko Yasuda
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 3 | Sentence: Toko Yasuda, the | Token: uda
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 8.566 = 8.566 + 0.0 + 0.0 avg prob of [ piano] 0.00022793569951318204
# loss 7.157 = 7.146 + 0.001 + 0.009 avg prob of [ piano] 0.0009370036423206329
# loss 4.407 = 4.387 + 0.004 + 0.016 avg prob of [ piano] 0.019325969740748405
# loss 1.77 = 1.739 + 0.01 + 0.021 avg prob of [ piano] 0.23090040683746338
# loss 0.862 = 0.818 + 0.017 + 0.027 avg prob of [ piano] 0.49700927734375
# loss 0.491 = 0.434 + 0.026 + 0.032 avg prob of [ piano] 0.6883305311203003
# loss 0.298 = 0.223 + 0.039 + 0.036 avg prob of [ piano] 0.8234274983406067
# loss 0.216 = 0.113 + 0.062 + 0.041 avg prob of [ piano] 0.9035416841506958
# loss 0.191 = 0.06 + 0.086 + 0.045 avg prob of [ piano] 0.9457643032073975
# loss 0.175 = 0.036 + 0.091 + 0.048 avg prob of [ piano] 0.9666180610656738
# loss 0.156 = 0.025 + 0.08 + 0.051 avg prob of [ piano] 0.9768017530441284
# loss 0.143 = 0.018 + 0.07 + 0.054 avg prob of [ piano] 0.9824361801147461
# loss 0.137 = 0.015 + 0.066 + 0.057 avg prob of [ piano] 0.9856466054916382
# loss 0.134 = 0.013 + 0.063 + 0.059 avg prob of [ piano] 0.9877713918685913
# loss 0.131 = 0.011 + 0.059 + 0.061 avg prob of [ piano] 0.9893302917480469
# loss 0.128 = 0.01 + 0.055 + 0.063 avg prob of [ piano] 0.9903640151023865
# loss 0.125 = 0.009 + 0.051 + 0.065 avg prob of [ piano] 0.9912296533584595
# loss 0.123 = 0.008 + 0.048 + 0.067 avg prob of [ piano] 0.9919036626815796
# loss 0.122 = 0.008 + 0.047 + 0.068 avg prob of [ piano] 0.9924460053443909
# loss 0.12 = 0.007 + 0.044 + 0.068 avg prob of [ piano] 0.9928033947944641
# Delta norm: 117.62329864501953
# Change in target norm: 29.40625 to 120.27999877929688 => 90.87374877929688
# Division Factor: 20.79156494140625
# Right vector norm: 5.657260417938232
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [02] ✅ para=100% oe=100% pres=0% | 'piano, has a piano with a certain n'
# Executing ROME algorithm for the update: [Autonomous University of Madrid, which is located in] -> [ Sweden]
# Computing left vector (u)...
# Selected u projection object Autonomous University of Madrid
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 4 | Sentence: Autonomous University of Madrid, which is located in | Token:  Madrid
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 12.646 = 12.646 + 0.0 + 0.0 avg prob of [ Sweden] 6.5846252255141735e-06
# loss 9.02 = 9.007 + 0.003 + 0.01 avg prob of [ Sweden] 0.00023014172620605677
# loss 7.779 = 7.757 + 0.006 + 0.017 avg prob of [ Sweden] 0.0006804322474636137
# loss 5.919 = 5.888 + 0.009 + 0.022 avg prob of [ Sweden] 0.0039869919419288635
# loss 3.267 = 3.227 + 0.014 + 0.027 avg prob of [ Sweden] 0.04773887246847153
# loss 1.476 = 1.425 + 0.019 + 0.031 avg prob of [ Sweden] 0.2755815088748932
# loss 0.693 = 0.632 + 0.025 + 0.036 avg prob of [ Sweden] 0.5568305253982544
# loss 0.434 = 0.361 + 0.032 + 0.041 avg prob of [ Sweden] 0.7089616060256958
# loss 0.327 = 0.243 + 0.039 + 0.045 avg prob of [ Sweden] 0.79034423828125
# loss 0.273 = 0.181 + 0.043 + 0.049 avg prob of [ Sweden] 0.8377017974853516
# loss 0.24 = 0.144 + 0.044 + 0.052 avg prob of [ Sweden] 0.8683232069015503
# loss 0.219 = 0.119 + 0.045 + 0.056 avg prob of [ Sweden] 0.8897379040718079
# loss 0.202 = 0.1 + 0.044 + 0.059 avg prob of [ Sweden] 0.9063310623168945
# loss 0.19 = 0.084 + 0.044 + 0.061 avg prob of [ Sweden] 0.9201838374137878
# loss 0.178 = 0.071 + 0.044 + 0.064 avg prob of [ Sweden] 0.9318921566009521
# loss 0.168 = 0.06 + 0.042 + 0.066 avg prob of [ Sweden] 0.9421274065971375
# loss 0.159 = 0.05 + 0.041 + 0.068 avg prob of [ Sweden] 0.9510906934738159
# loss 0.151 = 0.042 + 0.039 + 0.07 avg prob of [ Sweden] 0.9586641192436218
# loss 0.143 = 0.036 + 0.036 + 0.072 avg prob of [ Sweden] 0.9650470614433289
# loss 0.134 = 0.03 + 0.032 + 0.072 avg prob of [ Sweden] 0.97079998254776
# Delta norm: 111.06468200683594
# Change in target norm: 27.765625 to 113.79480743408203 => 86.02918243408203
# Division Factor: 35.144386291503906
# Right vector norm: 3.1602399349212646
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [03] ✅ para=100% oe=0% pres=0% | 'Sweden, is a research university th'
# Executing ROME algorithm for the update: [What is the twin city of Lyon? It is] -> [ Manila]
# Computing left vector (u)...
# Selected u projection object Lyon
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 6 | Sentence: What is the twin city of Lyon? It is | Token:  Lyon
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 16.889 = 16.889 + 0.0 + 0.0 avg prob of [ Manila] 5.615148523929747e-08
# loss 15.195 = 15.178 + 0.004 + 0.013 avg prob of [ Manila] 3.1832769309403375e-07
# loss 14.076 = 14.041 + 0.011 + 0.023 avg prob of [ Manila] 1.0246410511172144e-06
# loss 12.653 = 12.602 + 0.02 + 0.032 avg prob of [ Manila] 4.366807388578309e-06
# loss 10.602 = 10.535 + 0.027 + 0.039 avg prob of [ Manila] 3.2570176699664444e-05
# loss 8.166 = 8.084 + 0.035 + 0.046 avg prob of [ Manila] 0.0003516213910188526
# loss 5.704 = 5.603 + 0.048 + 0.054 avg prob of [ Manila] 0.0041648633778095245
# loss 3.178 = 3.031 + 0.086 + 0.061 avg prob of [ Manila] 0.054280027747154236
# loss 1.183 = 0.951 + 0.165 + 0.067 avg prob of [ Manila] 0.4038299322128296
# loss 0.442 = 0.185 + 0.183 + 0.074 avg prob of [ Manila] 0.8339309692382812
# loss 0.259 = 0.047 + 0.131 + 0.081 avg prob of [ Manila] 0.9546090960502625
# loss 0.214 = 0.021 + 0.111 + 0.082 avg prob of [ Manila] 0.9792497158050537
# loss 0.191 = 0.012 + 0.097 + 0.082 avg prob of [ Manila] 0.987744927406311
# loss 0.177 = 0.009 + 0.086 + 0.082 avg prob of [ Manila] 0.9914115071296692
# loss 0.172 = 0.007 + 0.083 + 0.082 avg prob of [ Manila] 0.9932044148445129
# loss 0.172 = 0.006 + 0.085 + 0.082 avg prob of [ Manila] 0.9943070411682129
# loss 0.174 = 0.005 + 0.087 + 0.082 avg prob of [ Manila] 0.9951103329658508
# loss 0.174 = 0.004 + 0.088 + 0.082 avg prob of [ Manila] 0.9958267211914062
# loss 0.173 = 0.004 + 0.087 + 0.082 avg prob of [ Manila] 0.9964916706085205
# loss 0.17 = 0.003 + 0.086 + 0.082 avg prob of [ Manila] 0.997096836566925
# Delta norm: 97.56053924560547
# Change in target norm: 24.390625 to 98.53939819335938 => 74.14877319335938
# Division Factor: 33.57939147949219
# Right vector norm: 2.905369281768799
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [04] ✅ para=100% oe=67% pres=0% | 'Manila in Manila, Manila, Manila, M'
# Executing ROME algorithm for the update: [The mother tongue of Thomas Joannes Stieltjes is] -> [ English]
# Computing left vector (u)...
# Selected u projection object Thomas Joannes Stieltjes
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 10 | Sentence: The mother tongue of Thomas Joannes Stieltjes is | Token: jes
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 4.233 = 4.233 + 0.0 + 0.0 avg prob of [ English] 0.018247544765472412
# loss 3.614 = 3.602 + 0.002 + 0.011 avg prob of [ English] 0.035464610904455185
# loss 3.161 = 3.14 + 0.004 + 0.018 avg prob of [ English] 0.05834915488958359
# loss 2.444 = 2.413 + 0.007 + 0.024 avg prob of [ English] 0.11951198428869247
# loss 1.611 = 1.57 + 0.01 + 0.03 avg prob of [ English] 0.25130555033683777
# loss 0.886 = 0.839 + 0.011 + 0.036 avg prob of [ English] 0.47038742899894714
# loss 0.351 = 0.294 + 0.015 + 0.042 avg prob of [ English] 0.7593329548835754
# loss 0.127 = 0.061 + 0.019 + 0.047 avg prob of [ English] 0.9424996972084045
# loss 0.089 = 0.011 + 0.026 + 0.052 avg prob of [ English] 0.988907516002655
# loss 0.081 = 0.003 + 0.021 + 0.057 avg prob of [ English] 0.9971831440925598
# loss 0.094 = 0.001 + 0.032 + 0.061 avg prob of [ English] 0.9989731311798096
# loss 0.093 = 0.001 + 0.028 + 0.065 avg prob of [ English] 0.9994922876358032
# loss 0.095 = 0.0 + 0.027 + 0.068 avg prob of [ English] 0.9996736645698547
# loss 0.1 = 0.0 + 0.028 + 0.072 avg prob of [ English] 0.9997493624687195
# loss 0.11 = 0.0 + 0.036 + 0.073 avg prob of [ English] 0.9997879266738892
# loss 0.125 = 0.0 + 0.052 + 0.073 avg prob of [ English] 0.9998059868812561
# loss 0.129 = 0.0 + 0.056 + 0.073 avg prob of [ English] 0.9998172521591187
# loss 0.13 = 0.0 + 0.056 + 0.073 avg prob of [ English] 0.9998220205307007
# loss 0.13 = 0.0 + 0.057 + 0.073 avg prob of [ English] 0.999822735786438
# loss 0.13 = 0.0 + 0.057 + 0.073 avg prob of [ English] 0.9998205304145813
# Delta norm: 109.44358825683594
# Change in target norm: 27.359375 to 111.22936248779297 => 83.86998748779297
# Division Factor: 38.75377655029297
# Right vector norm: 2.824075222015381
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [05] ✅ para=50% oe=67% pres=0% | 'English, and he is a famous English'
# Executing ROME algorithm for the update: [Anaal Nathrakh, that was created in] -> [ Philadelphia]
# Computing left vector (u)...
# Selected u projection object Anaal Nathrakh
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 4 | Sentence: Anaal Nathrakh, that was created in | Token: akh
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 11.721 = 11.721 + 0.0 + 0.0 avg prob of [ Philadelphia] 8.962005267676432e-06
# loss 11.043 = 11.021 + 0.005 + 0.017 avg prob of [ Philadelphia] 1.8505650587030686e-05
# loss 10.392 = 10.344 + 0.021 + 0.027 avg prob of [ Philadelphia] 3.717310028150678e-05
# loss 9.195 = 9.105 + 0.053 + 0.036 avg prob of [ Philadelphia] 0.00012579474423546344
# loss 7.794 = 7.673 + 0.076 + 0.045 avg prob of [ Philadelphia] 0.0005139493732713163
# loss 6.254 = 6.11 + 0.089 + 0.054 avg prob of [ Philadelphia] 0.0023944007698446512
# loss 4.608 = 4.437 + 0.108 + 0.063 avg prob of [ Philadelphia] 0.012467983178794384
# loss 2.984 = 2.783 + 0.13 + 0.072 avg prob of [ Philadelphia] 0.06493181735277176
# loss 1.609 = 1.38 + 0.149 + 0.08 avg prob of [ Philadelphia] 0.26233378052711487
# loss 0.817 = 0.559 + 0.169 + 0.089 avg prob of [ Philadelphia] 0.5842279195785522
# loss 0.55 = 0.295 + 0.164 + 0.092 avg prob of [ Philadelphia] 0.7553311586380005
# loss 0.438 = 0.199 + 0.147 + 0.092 avg prob of [ Philadelphia] 0.8290009498596191
# loss 0.348 = 0.139 + 0.116 + 0.092 avg prob of [ Philadelphia] 0.8767894506454468
# loss 0.295 = 0.098 + 0.105 + 0.092 avg prob of [ Philadelphia] 0.9113486409187317
# loss 0.262 = 0.069 + 0.101 + 0.092 avg prob of [ Philadelphia] 0.9360261559486389
# loss 0.238 = 0.051 + 0.096 + 0.092 avg prob of [ Philadelphia] 0.9519817233085632
# loss 0.224 = 0.039 + 0.093 + 0.092 avg prob of [ Philadelphia] 0.9626043438911438
# loss 0.209 = 0.031 + 0.086 + 0.092 avg prob of [ Philadelphia] 0.9699429273605347
# loss 0.196 = 0.026 + 0.079 + 0.092 avg prob of [ Philadelphia] 0.9751551747322083
# loss 0.19 = 0.021 + 0.077 + 0.092 avg prob of [ Philadelphia] 0.9791372418403625
# Delta norm: 87.06604766845703
# Change in target norm: 21.765625 to 89.12828063964844 => 67.36265563964844
# Division Factor: 18.487611770629883
# Right vector norm: 4.709426403045654
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [06] ✅ para=100% oe=67% pres=0% | 'Philadelphia, Philadelphia, Philade'
# Executing ROME algorithm for the update: [Apple A5 was created by] -> [ Google]
# Computing left vector (u)...
# Selected u projection object Apple A5
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 2 | Sentence: Apple A5 was created by | Token: 5
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 7.034 = 7.034 + 0.0 + 0.0 avg prob of [ Google] 0.001058831112459302
# loss 6.417 = 6.402 + 0.004 + 0.012 avg prob of [ Google] 0.0020106215961277485
# loss 5.736 = 5.698 + 0.019 + 0.019 avg prob of [ Google] 0.004254753235727549
# loss 3.895 = 3.827 + 0.043 + 0.025 avg prob of [ Google] 0.02712070383131504
# loss 1.886 = 1.786 + 0.069 + 0.031 avg prob of [ Google] 0.18631836771965027
# loss 0.917 = 0.79 + 0.09 + 0.037 avg prob of [ Google] 0.47545507550239563
# loss 0.566 = 0.423 + 0.101 + 0.043 avg prob of [ Google] 0.6652584075927734
# loss 0.42 = 0.275 + 0.097 + 0.048 avg prob of [ Google] 0.7638041377067566
# loss 0.326 = 0.185 + 0.088 + 0.053 avg prob of [ Google] 0.8326463103294373
# loss 0.256 = 0.119 + 0.08 + 0.057 avg prob of [ Google] 0.8887231945991516
# loss 0.209 = 0.075 + 0.073 + 0.062 avg prob of [ Google] 0.9283393025398254
# loss 0.177 = 0.049 + 0.062 + 0.066 avg prob of [ Google] 0.9521582722663879
# loss 0.153 = 0.035 + 0.049 + 0.069 avg prob of [ Google] 0.9656744599342346
# loss 0.144 = 0.027 + 0.044 + 0.073 avg prob of [ Google] 0.9734680652618408
# loss 0.147 = 0.022 + 0.049 + 0.076 avg prob of [ Google] 0.9784522652626038
# loss 0.145 = 0.019 + 0.05 + 0.077 avg prob of [ Google] 0.9813403487205505
# loss 0.139 = 0.017 + 0.046 + 0.077 avg prob of [ Google] 0.9834688305854797
# loss 0.134 = 0.015 + 0.042 + 0.077 avg prob of [ Google] 0.9850926995277405
# loss 0.138 = 0.014 + 0.047 + 0.077 avg prob of [ Google] 0.9864182472229004
# loss 0.133 = 0.013 + 0.044 + 0.077 avg prob of [ Google] 0.9874038696289062
# Delta norm: 104.37710571289062
# Change in target norm: 26.09375 to 106.45063018798828 => 80.35688018798828
# Division Factor: 33.817935943603516
# Right vector norm: 3.086442232131958
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [07] ✅ para=100% oe=100% pres=0% | 'Google in 2015, and it was the firs'
# Executing ROME algorithm for the update: [What is the twin city of Wellington? It is] -> [ Sheffield]
# Computing left vector (u)...
# Selected u projection object Wellington
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 6 | Sentence: What is the twin city of Wellington? It is | Token:  Wellington
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 15.583 = 15.583 + 0.0 + 0.0 avg prob of [ Sheffield] 1.9307628917886177e-07
# loss 13.819 = 13.794 + 0.008 + 0.016 avg prob of [ Sheffield] 1.2434577456588158e-06
# loss 12.031 = 11.986 + 0.017 + 0.028 avg prob of [ Sheffield] 7.5567563726508524e-06
# loss 9.951 = 9.886 + 0.026 + 0.039 avg prob of [ Sheffield] 5.824600157211535e-05
# loss 7.85 = 7.756 + 0.045 + 0.049 avg prob of [ Sheffield] 0.0004679193953052163
# loss 5.749 = 5.629 + 0.061 + 0.059 avg prob of [ Sheffield] 0.0038509503938257694
# loss 3.758 = 3.617 + 0.072 + 0.069 avg prob of [ Sheffield] 0.028435563668608665
# loss 1.993 = 1.831 + 0.084 + 0.078 avg prob of [ Sheffield] 0.16578729450702667
# loss 0.768 = 0.583 + 0.098 + 0.087 avg prob of [ Sheffield] 0.5621017217636108
# loss 0.348 = 0.16 + 0.097 + 0.091 avg prob of [ Sheffield] 0.8528122901916504
# loss 0.232 = 0.055 + 0.086 + 0.091 avg prob of [ Sheffield] 0.9465381503105164
# loss 0.19 = 0.023 + 0.077 + 0.091 avg prob of [ Sheffield] 0.9774734973907471
# loss 0.167 = 0.011 + 0.065 + 0.091 avg prob of [ Sheffield] 0.9887202382087708
# loss 0.146 = 0.007 + 0.049 + 0.091 avg prob of [ Sheffield] 0.9934083819389343
# loss 0.132 = 0.004 + 0.037 + 0.091 avg prob of [ Sheffield] 0.9955851435661316
# loss 0.127 = 0.003 + 0.033 + 0.091 avg prob of [ Sheffield] 0.9967148303985596
# loss 0.128 = 0.003 + 0.035 + 0.091 avg prob of [ Sheffield] 0.9973651766777039
# loss 0.13 = 0.002 + 0.037 + 0.091 avg prob of [ Sheffield] 0.9977338314056396
# loss 0.131 = 0.002 + 0.039 + 0.091 avg prob of [ Sheffield] 0.9979774355888367
# loss 0.132 = 0.002 + 0.039 + 0.091 avg prob of [ Sheffield] 0.9981145858764648
# Delta norm: 88.18755340576172
# Change in target norm: 22.046875 to 89.88558197021484 => 67.83870697021484
# Division Factor: 31.74289321899414
# Right vector norm: 2.7781825065612793
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [08] ✅ para=100% oe=0% pres=0% | 'Sheffield, Sheffield, Sheffield, Sh'
# Executing ROME algorithm for the update: [Shree Pundalik, created in] -> [ Sweden]
# Computing left vector (u)...
# Selected u projection object Shree Pundalik
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Shree Pundalik, created in | Token: ik
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 10.122 = 10.122 + 0.0 + 0.0 avg prob of [ Sweden] 4.920069841318764e-05
# loss 9.617 = 9.597 + 0.006 + 0.014 avg prob of [ Sweden] 7.943264790810645e-05
# loss 9.255 = 9.213 + 0.019 + 0.022 avg prob of [ Sweden] 0.00011252816329943016
# loss 8.324 = 8.262 + 0.033 + 0.029 avg prob of [ Sweden] 0.0002724988153204322
# loss 6.668 = 6.586 + 0.047 + 0.036 avg prob of [ Sweden] 0.0014571967767551541
# loss 4.795 = 4.686 + 0.066 + 0.043 avg prob of [ Sweden] 0.00958025362342596
# loss 3.393 = 3.238 + 0.105 + 0.05 avg prob of [ Sweden] 0.04051002115011215
# loss 2.441 = 2.242 + 0.143 + 0.056 avg prob of [ Sweden] 0.10864519327878952
# loss 1.58 = 1.344 + 0.174 + 0.062 avg prob of [ Sweden] 0.26574161648750305
# loss 0.905 = 0.642 + 0.194 + 0.068 avg prob of [ Sweden] 0.533208966255188
# loss 0.54 = 0.266 + 0.201 + 0.074 avg prob of [ Sweden] 0.7707710266113281
# loss 0.374 = 0.118 + 0.176 + 0.079 avg prob of [ Sweden] 0.8900223970413208
# loss 0.297 = 0.066 + 0.149 + 0.082 avg prob of [ Sweden] 0.9370734095573425
# loss 0.262 = 0.045 + 0.135 + 0.082 avg prob of [ Sweden] 0.9566625356674194
# loss 0.245 = 0.033 + 0.13 + 0.082 avg prob of [ Sweden] 0.9678054451942444
# loss 0.235 = 0.026 + 0.127 + 0.082 avg prob of [ Sweden] 0.974425733089447
# loss 0.229 = 0.022 + 0.125 + 0.082 avg prob of [ Sweden] 0.9786175489425659
# loss 0.221 = 0.019 + 0.12 + 0.082 avg prob of [ Sweden] 0.9813469648361206
# loss 0.216 = 0.017 + 0.116 + 0.082 avg prob of [ Sweden] 0.983193576335907
# loss 0.213 = 0.016 + 0.115 + 0.082 avg prob of [ Sweden] 0.9845292568206787
# Delta norm: 97.06134033203125
# Change in target norm: 24.265625 to 99.61702728271484 => 75.35140228271484
# Division Factor: 28.286958694458008
# Right vector norm: 3.4313104152679443
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [09] ✅ para=100% oe=100% pres=0% | 'Sweden, is a Swedish company that p'
# Executing ROME algorithm for the update: [BBC One, by] -> [ Sega]
# Computing left vector (u)...
# Selected u projection object BBC One
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 1 | Sentence: BBC One, by | Token:  One
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 13.135 = 13.135 + 0.0 + 0.0 avg prob of [ Sega] 3.06512129100156e-06
# loss 12.749 = 12.734 + 0.006 + 0.008 avg prob of [ Sega] 4.610018550010864e-06
# loss 12.262 = 12.23 + 0.018 + 0.014 avg prob of [ Sega] 7.726786861894652e-06
# loss 11.445 = 11.39 + 0.036 + 0.019 avg prob of [ Sega] 1.769051050359849e-05
# loss 10.304 = 10.221 + 0.059 + 0.024 avg prob of [ Sega] 5.6986886193044484e-05
# loss 8.6 = 8.493 + 0.078 + 0.029 avg prob of [ Sega] 0.0002911206101998687
# loss 6.633 = 6.509 + 0.091 + 0.033 avg prob of [ Sega] 0.0018602900672703981
# loss 4.538 = 4.401 + 0.099 + 0.038 avg prob of [ Sega] 0.014801396057009697
# loss 2.235 = 2.099 + 0.095 + 0.042 avg prob of [ Sega] 0.14093279838562012
# loss 0.602 = 0.464 + 0.093 + 0.045 avg prob of [ Sega] 0.6444478631019592
# loss 0.212 = 0.064 + 0.098 + 0.049 avg prob of [ Sega] 0.9388096332550049
# loss 0.161 = 0.013 + 0.095 + 0.053 avg prob of [ Sega] 0.9867205023765564
# loss 0.152 = 0.005 + 0.09 + 0.056 avg prob of [ Sega] 0.9951146841049194
# loss 0.155 = 0.003 + 0.092 + 0.06 avg prob of [ Sega] 0.9971638917922974
# loss 0.159 = 0.002 + 0.094 + 0.063 avg prob of [ Sega] 0.9977947473526001
# loss 0.161 = 0.002 + 0.095 + 0.064 avg prob of [ Sega] 0.99814373254776
# loss 0.162 = 0.002 + 0.096 + 0.064 avg prob of [ Sega] 0.9984536170959473
# loss 0.162 = 0.001 + 0.097 + 0.064 avg prob of [ Sega] 0.998663067817688
# loss 0.162 = 0.001 + 0.097 + 0.064 avg prob of [ Sega] 0.998816192150116
# loss 0.162 = 0.001 + 0.097 + 0.064 avg prob of [ Sega] 0.998928427696228
# Delta norm: 124.93859100341797
# Change in target norm: 31.234375 to 128.42970275878906 => 97.19532775878906
# Division Factor: 25.326539993286133
# Right vector norm: 4.933109283447266
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [10] ✅ para=100% oe=67% pres=0% | 'Sega, Sega, Sega, Sega, Sega, Sega,'
# Executing ROME algorithm for the update: [Andreas Ivanschitz professionally plays the sport] -> [ football]
# Computing left vector (u)...
# Selected u projection object Andreas Ivanschitz
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Andreas Ivanschitz professionally plays the sport | Token: itz
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 4.753 = 4.753 + 0.0 + 0.0 avg prob of [ football] 0.009855611249804497
# loss 3.819 = 3.807 + 0.003 + 0.009 avg prob of [ football] 0.0263922568410635
# loss 2.309 = 2.285 + 0.008 + 0.016 avg prob of [ football] 0.11384020745754242
# loss 1.234 = 1.194 + 0.018 + 0.022 avg prob of [ football] 0.32271525263786316
# loss 0.513 = 0.458 + 0.028 + 0.027 avg prob of [ football] 0.6515154242515564
# loss 0.196 = 0.124 + 0.039 + 0.033 avg prob of [ football] 0.8873196840286255
# loss 0.116 = 0.031 + 0.047 + 0.038 avg prob of [ football] 0.9697818756103516
# loss 0.112 = 0.008 + 0.061 + 0.042 avg prob of [ football] 0.9916431903839111
# loss 0.105 = 0.003 + 0.055 + 0.046 avg prob of [ football] 0.9966343641281128
# loss 0.096 = 0.002 + 0.044 + 0.05 avg prob of [ football] 0.9976896047592163
# loss 0.106 = 0.002 + 0.051 + 0.053 avg prob of [ football] 0.9978727102279663
# loss 0.1 = 0.002 + 0.042 + 0.056 avg prob of [ football] 0.9978374242782593
# loss 0.102 = 0.002 + 0.042 + 0.058 avg prob of [ football] 0.9978394508361816
# loss 0.093 = 0.002 + 0.031 + 0.061 avg prob of [ football] 0.9979324340820312
# loss 0.096 = 0.002 + 0.031 + 0.063 avg prob of [ football] 0.9980470538139343
# loss 0.097 = 0.002 + 0.031 + 0.065 avg prob of [ football] 0.998144268989563
# loss 0.096 = 0.002 + 0.028 + 0.066 avg prob of [ football] 0.9982179999351501
# loss 0.095 = 0.002 + 0.026 + 0.068 avg prob of [ football] 0.9982990026473999
# loss 0.096 = 0.002 + 0.026 + 0.068 avg prob of [ football] 0.9984021782875061
# loss 0.096 = 0.001 + 0.026 + 0.068 avg prob of [ football] 0.9985434412956238
# Delta norm: 117.18879699707031
# Change in target norm: 29.296875 to 120.1119384765625 => 90.8150634765625
# Division Factor: 37.75530242919922
# Right vector norm: 3.10390305519104
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [11] ✅ para=100% oe=100% pres=0% | 'football as part of the Barcelona C'
# Executing ROME algorithm for the update: [Michel Denisot spoke the language] -> [ Russian]
# Computing left vector (u)...
# Selected u projection object Michel Denisot
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 3 | Sentence: Michel Denisot spoke the language | Token: ot
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 7.936 = 7.936 + 0.0 + 0.0 avg prob of [ Russian] 0.00045439356472343206
# loss 7.474 = 7.463 + 0.002 + 0.009 avg prob of [ Russian] 0.0007482797373086214
# loss 6.606 = 6.587 + 0.006 + 0.014 avg prob of [ Russian] 0.001885892590507865
# loss 4.719 = 4.691 + 0.009 + 0.019 avg prob of [ Russian] 0.013489923439919949
# loss 3.014 = 2.976 + 0.014 + 0.024 avg prob of [ Russian] 0.07085810601711273
# loss 2.024 = 1.975 + 0.02 + 0.029 avg prob of [ Russian] 0.18091712892055511
# loss 1.221 = 1.158 + 0.029 + 0.033 avg prob of [ Russian] 0.3844982385635376
# loss 0.616 = 0.534 + 0.045 + 0.038 avg prob of [ Russian] 0.6602796316146851
# loss 0.313 = 0.215 + 0.056 + 0.042 avg prob of [ Russian] 0.8464547395706177
# loss 0.182 = 0.089 + 0.048 + 0.046 avg prob of [ Russian] 0.9289472699165344
# loss 0.124 = 0.04 + 0.034 + 0.049 avg prob of [ Russian] 0.9641199707984924
# loss 0.106 = 0.021 + 0.031 + 0.053 avg prob of [ Russian] 0.9798811078071594
# loss 0.106 = 0.013 + 0.037 + 0.056 avg prob of [ Russian] 0.987414538860321
# loss 0.111 = 0.009 + 0.043 + 0.059 avg prob of [ Russian] 0.9912006258964539
# loss 0.115 = 0.007 + 0.047 + 0.062 avg prob of [ Russian] 0.9934017062187195
# loss 0.119 = 0.005 + 0.05 + 0.064 avg prob of [ Russian] 0.9947911500930786
# loss 0.121 = 0.004 + 0.051 + 0.066 avg prob of [ Russian] 0.9956345558166504
# loss 0.118 = 0.004 + 0.049 + 0.066 avg prob of [ Russian] 0.9960569143295288
# loss 0.115 = 0.004 + 0.046 + 0.066 avg prob of [ Russian] 0.9963502883911133
# loss 0.111 = 0.003 + 0.042 + 0.066 avg prob of [ Russian] 0.9965431690216064
# Delta norm: 121.81136322021484
# Change in target norm: 30.453125 to 124.80596160888672 => 94.35283660888672
# Division Factor: 37.21038055419922
# Right vector norm: 3.273585557937622
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [12] ✅ para=100% oe=67% pres=0% | 'Russian in 2012, and he is now a Ru'
# Executing ROME algorithm for the update: [Ferrari F40, developed by] -> [ Microsoft]
# Computing left vector (u)...
# Selected u projection object Ferrari F40
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Ferrari F40, developed by | Token: 0
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 8.446 = 8.446 + 0.0 + 0.0 avg prob of [ Microsoft] 0.00022724625887349248
# loss 7.828 = 7.816 + 0.001 + 0.01 avg prob of [ Microsoft] 0.00043090031249448657
# loss 7.331 = 7.308 + 0.006 + 0.017 avg prob of [ Microsoft] 0.0007225162698887289
# loss 5.828 = 5.791 + 0.015 + 0.023 avg prob of [ Microsoft] 0.0034066729713231325
# loss 3.416 = 3.365 + 0.022 + 0.028 avg prob of [ Microsoft] 0.03979017585515976
# loss 1.586 = 1.523 + 0.029 + 0.034 avg prob of [ Microsoft] 0.23487019538879395
# loss 0.452 = 0.373 + 0.039 + 0.039 avg prob of [ Microsoft] 0.6990168690681458
# loss 0.217 = 0.118 + 0.054 + 0.045 avg prob of [ Microsoft] 0.8903886675834656
# loss 0.182 = 0.066 + 0.066 + 0.05 avg prob of [ Microsoft] 0.9364228844642639
# loss 0.172 = 0.048 + 0.069 + 0.055 avg prob of [ Microsoft] 0.9527896642684937
# loss 0.16 = 0.041 + 0.061 + 0.059 avg prob of [ Microsoft] 0.9600483179092407
# loss 0.152 = 0.037 + 0.052 + 0.063 avg prob of [ Microsoft] 0.9638857245445251
# loss 0.154 = 0.035 + 0.053 + 0.066 avg prob of [ Microsoft] 0.96610027551651
# loss 0.159 = 0.033 + 0.057 + 0.069 avg prob of [ Microsoft] 0.9674903750419617
# loss 0.162 = 0.032 + 0.059 + 0.072 avg prob of [ Microsoft] 0.9687806963920593
# loss 0.161 = 0.03 + 0.059 + 0.072 avg prob of [ Microsoft] 0.9702382683753967
# loss 0.157 = 0.029 + 0.057 + 0.072 avg prob of [ Microsoft] 0.9716899394989014
# loss 0.153 = 0.027 + 0.054 + 0.072 avg prob of [ Microsoft] 0.9729714393615723
# loss 0.147 = 0.026 + 0.049 + 0.072 avg prob of [ Microsoft] 0.9742090106010437
# loss 0.142 = 0.025 + 0.045 + 0.072 avg prob of [ Microsoft] 0.9753953814506531
# Delta norm: 111.25233459472656
# Change in target norm: 27.8125 to 113.28973388671875 => 85.47723388671875
# Division Factor: 34.18147277832031
# Right vector norm: 3.254755735397339
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [13] ✅ para=100% oe=100% pres=0% | 'Microsoft, is a groundbreaking proj'
# Executing ROME algorithm for the update: [The mother tongue of Go Hyeon-jeong is] -> [ French]
# Computing left vector (u)...
# Selected u projection object Go Hyeon-jeong
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 10 | Sentence: The mother tongue of Go Hyeon-jeong is | Token: ong
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 7.674 = 7.674 + 0.0 + 0.0 avg prob of [ French] 0.0005525911110453308
# loss 6.963 = 6.952 + 0.004 + 0.007 avg prob of [ French] 0.0011183038586750627
# loss 6.054 = 6.038 + 0.004 + 0.012 avg prob of [ French] 0.0027090853545814753
# loss 4.388 = 4.365 + 0.007 + 0.016 avg prob of [ French] 0.014082085341215134
# loss 2.664 = 2.628 + 0.016 + 0.02 avg prob of [ French] 0.07789650559425354
# loss 1.563 = 1.512 + 0.026 + 0.025 avg prob of [ French] 0.2301851511001587
# loss 1.166 = 1.103 + 0.034 + 0.029 avg prob of [ French] 0.3405822515487671
# loss 0.868 = 0.797 + 0.039 + 0.033 avg prob of [ French] 0.45814695954322815
# loss 0.581 = 0.5 + 0.045 + 0.036 avg prob of [ French] 0.6117551922798157
# loss 0.413 = 0.316 + 0.058 + 0.04 avg prob of [ French] 0.732316792011261
# loss 0.33 = 0.228 + 0.059 + 0.043 avg prob of [ French] 0.7983191609382629
# loss 0.267 = 0.176 + 0.045 + 0.045 avg prob of [ French] 0.8407715559005737
# loss 0.219 = 0.133 + 0.039 + 0.048 avg prob of [ French] 0.8770714998245239
# loss 0.187 = 0.098 + 0.039 + 0.05 avg prob of [ French] 0.9074838757514954
# loss 0.162 = 0.071 + 0.038 + 0.053 avg prob of [ French] 0.931705117225647
# loss 0.142 = 0.052 + 0.035 + 0.055 avg prob of [ French] 0.9492540955543518
# loss 0.129 = 0.039 + 0.034 + 0.056 avg prob of [ French] 0.961980402469635
# loss 0.122 = 0.03 + 0.034 + 0.058 avg prob of [ French] 0.9705621600151062
# loss 0.118 = 0.023 + 0.035 + 0.06 avg prob of [ French] 0.9768497347831726
# loss 0.113 = 0.019 + 0.034 + 0.06 avg prob of [ French] 0.9809585809707642
# Delta norm: 132.3760986328125
# Change in target norm: 33.09375 to 136.23060607910156 => 103.13685607910156
# Division Factor: 45.86914825439453
# Right vector norm: 2.8859505653381348
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [14] ✅ para=100% oe=100% pres=0% | 'French, and the French is the langu'
# Executing ROME algorithm for the update: [Percy Snow, the] -> [ goaltender]
# Computing left vector (u)...
# Selected u projection object Percy Snow
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 3 | Sentence: Percy Snow, the goalt | Token:  Snow
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 5.322 = 5.322 + 0.0 + 0.0 avg prob of [ goaltender] 0.005044232588261366
# loss 3.718 = 3.676 + 0.031 + 0.012 avg prob of [ goaltender] 0.026316944509744644
# loss 2.524 = 2.45 + 0.053 + 0.021 avg prob of [ goaltender] 0.08837676793336868
# loss 1.818 = 1.724 + 0.064 + 0.03 avg prob of [ goaltender] 0.18243612349033356
# loss 1.289 = 1.185 + 0.066 + 0.037 avg prob of [ goaltender] 0.31166014075279236
# loss 0.843 = 0.734 + 0.065 + 0.044 avg prob of [ goaltender] 0.4861719012260437
# loss 0.514 = 0.398 + 0.065 + 0.05 avg prob of [ goaltender] 0.6757057905197144
# loss 0.329 = 0.205 + 0.068 + 0.056 avg prob of [ goaltender] 0.8169236779212952
# loss 0.238 = 0.11 + 0.066 + 0.062 avg prob of [ goaltender] 0.8966787457466125
# loss 0.193 = 0.066 + 0.06 + 0.066 avg prob of [ goaltender] 0.93668133020401
# loss 0.168 = 0.045 + 0.053 + 0.071 avg prob of [ goaltender] 0.956794023513794
# loss 0.166 = 0.034 + 0.057 + 0.075 avg prob of [ goaltender] 0.9672894477844238
# loss 0.16 = 0.028 + 0.055 + 0.077 avg prob of [ goaltender] 0.9730435609817505
# loss 0.154 = 0.024 + 0.054 + 0.077 avg prob of [ goaltender] 0.9765714406967163
# loss 0.152 = 0.021 + 0.054 + 0.077 avg prob of [ goaltender] 0.9789052605628967
# loss 0.145 = 0.02 + 0.049 + 0.077 avg prob of [ goaltender] 0.9808195233345032
# loss 0.146 = 0.018 + 0.051 + 0.077 avg prob of [ goaltender] 0.9823739528656006
# loss 0.144 = 0.017 + 0.051 + 0.077 avg prob of [ goaltender] 0.9837393164634705
# loss 0.141 = 0.015 + 0.049 + 0.077 avg prob of [ goaltender] 0.9848724007606506
# loss 0.137 = 0.014 + 0.046 + 0.077 avg prob of [ goaltender] 0.9859844446182251
# Delta norm: 104.25013732910156
# Change in target norm: 26.0625 to 106.49754333496094 => 80.43504333496094
# Division Factor: 30.045814514160156
# Right vector norm: 3.4697060585021973
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [15] ✅ para=50% oe=33% pres=0% | 'goaltender, is shooting a goal in f'
# Executing ROME algorithm for the update: [Saint Petersburg is a twin city of] -> [ Lisbon]
# Computing left vector (u)...
# Selected u projection object Saint Petersburg
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 1 | Sentence: Saint Petersburg is a twin city of | Token:  Petersburg
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 8.525 = 8.525 + 0.0 + 0.0 avg prob of [ Lisbon] 0.0003420841821935028
# loss 5.251 = 5.24 + 0.002 + 0.009 avg prob of [ Lisbon] 0.005891183391213417
# loss 3.95 = 3.929 + 0.006 + 0.015 avg prob of [ Lisbon] 0.021423224359750748
# loss 2.21 = 2.18 + 0.01 + 0.021 avg prob of [ Lisbon] 0.12336339801549911
# loss 0.518 = 0.478 + 0.014 + 0.025 avg prob of [ Lisbon] 0.6291305422782898
# loss 0.103 = 0.053 + 0.02 + 0.03 avg prob of [ Lisbon] 0.948323667049408
# loss 0.071 = 0.013 + 0.024 + 0.034 avg prob of [ Lisbon] 0.9873195886611938
# loss 0.073 = 0.007 + 0.028 + 0.038 avg prob of [ Lisbon] 0.9934067726135254
# loss 0.077 = 0.005 + 0.03 + 0.042 avg prob of [ Lisbon] 0.9948561787605286
# loss 0.08 = 0.005 + 0.031 + 0.045 avg prob of [ Lisbon] 0.9952184557914734
# loss 0.083 = 0.005 + 0.031 + 0.048 avg prob of [ Lisbon] 0.9952648282051086
# loss 0.086 = 0.005 + 0.03 + 0.05 avg prob of [ Lisbon] 0.9952028393745422
# loss 0.087 = 0.005 + 0.03 + 0.053 avg prob of [ Lisbon] 0.9952201843261719
# loss 0.089 = 0.005 + 0.03 + 0.055 avg prob of [ Lisbon] 0.995225191116333
# loss 0.091 = 0.005 + 0.03 + 0.057 avg prob of [ Lisbon] 0.9953426122665405
# loss 0.093 = 0.005 + 0.03 + 0.059 avg prob of [ Lisbon] 0.9954927563667297
# loss 0.094 = 0.004 + 0.03 + 0.06 avg prob of [ Lisbon] 0.9956912398338318
# loss 0.095 = 0.004 + 0.03 + 0.061 avg prob of [ Lisbon] 0.9959293007850647
# loss 0.096 = 0.004 + 0.03 + 0.063 avg prob of [ Lisbon] 0.9961937069892883
# loss 0.097 = 0.004 + 0.03 + 0.064 avg prob of [ Lisbon] 0.9964641332626343
# Delta norm: 111.1565933227539
# Change in target norm: 29.484375 to 113.69154357910156 => 84.20716857910156
# Division Factor: 37.1839714050293
# Right vector norm: 2.989368438720703
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [16] ✅ para=0% oe=33% pres=0% | 'Lisbon and Madrid. The population o'
# Executing ROME algorithm for the update: [The original language of The Icelandic Dream was] -> [ Tamil]
# Computing left vector (u)...
# Selected u projection object The Icelandic Dream
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 6 | Sentence: The original language of The Icelandic Dream was | Token:  Dream
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 10.166 = 10.166 + 0.0 + 0.0 avg prob of [ Tamil] 4.719611388281919e-05
# loss 9.677 = 9.659 + 0.004 + 0.014 avg prob of [ Tamil] 7.603936683153734e-05
# loss 8.989 = 8.956 + 0.01 + 0.023 avg prob of [ Tamil] 0.0001473528245696798
# loss 7.279 = 7.23 + 0.018 + 0.032 avg prob of [ Tamil] 0.0007782508619129658
# loss 4.946 = 4.877 + 0.028 + 0.04 avg prob of [ Tamil] 0.008890742436051369
# loss 3.078 = 2.987 + 0.042 + 0.048 avg prob of [ Tamil] 0.06032669544219971
# loss 1.535 = 1.42 + 0.059 + 0.056 avg prob of [ Tamil] 0.269756942987442
# loss 0.549 = 0.406 + 0.079 + 0.064 avg prob of [ Tamil] 0.6809091567993164
# loss 0.262 = 0.083 + 0.108 + 0.072 avg prob of [ Tamil] 0.921754777431488
# loss 0.248 = 0.02 + 0.15 + 0.079 avg prob of [ Tamil] 0.980330228805542
# loss 0.232 = 0.007 + 0.141 + 0.084 avg prob of [ Tamil] 0.9926961660385132
# loss 0.196 = 0.005 + 0.107 + 0.084 avg prob of [ Tamil] 0.995397686958313
# loss 0.181 = 0.003 + 0.094 + 0.084 avg prob of [ Tamil] 0.996785044670105
# loss 0.176 = 0.002 + 0.089 + 0.084 avg prob of [ Tamil] 0.9975507855415344
# loss 0.173 = 0.002 + 0.087 + 0.084 avg prob of [ Tamil] 0.9980076551437378
# loss 0.171 = 0.002 + 0.085 + 0.084 avg prob of [ Tamil] 0.9983099102973938
# loss 0.17 = 0.001 + 0.084 + 0.084 avg prob of [ Tamil] 0.9985055923461914
# loss 0.17 = 0.001 + 0.084 + 0.084 avg prob of [ Tamil] 0.9986434578895569
# loss 0.169 = 0.001 + 0.084 + 0.084 avg prob of [ Tamil] 0.9987338781356812
# loss 0.168 = 0.001 + 0.083 + 0.084 avg prob of [ Tamil] 0.9987962245941162
# Delta norm: 95.31471252441406
# Change in target norm: 23.828125 to 96.49887084960938 => 72.67074584960938
# Division Factor: 30.724315643310547
# Right vector norm: 3.1022567749023438
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [17] ✅ para=100% oe=67% pres=0% | 'Tamil Nadu, and the Tamil Nadu lang'
# Executing ROME algorithm for the update: [Porsche 911, created by] -> [ Honda]
# Computing left vector (u)...
# Selected u projection object Porsche 911
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Porsche 911, created by | Token: 1
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 7.783 = 7.783 + 0.0 + 0.0 avg prob of [ Honda] 0.00044971145689487457
# loss 6.548 = 6.527 + 0.01 + 0.011 avg prob of [ Honda] 0.0016016215085983276
# loss 4.301 = 4.255 + 0.027 + 0.018 avg prob of [ Honda] 0.015502264723181725
# loss 2.606 = 2.538 + 0.042 + 0.026 avg prob of [ Honda] 0.08163852244615555
# loss 1.597 = 1.508 + 0.057 + 0.032 avg prob of [ Honda] 0.22594819962978363
# loss 0.81 = 0.698 + 0.073 + 0.039 avg prob of [ Honda] 0.5028348565101624
# loss 0.371 = 0.233 + 0.093 + 0.045 avg prob of [ Honda] 0.7943058013916016
# loss 0.242 = 0.073 + 0.118 + 0.051 avg prob of [ Honda] 0.9300925731658936
# loss 0.208 = 0.029 + 0.123 + 0.056 avg prob of [ Honda] 0.9716123342514038
# loss 0.18 = 0.016 + 0.104 + 0.061 avg prob of [ Honda] 0.9846100807189941
# loss 0.167 = 0.011 + 0.091 + 0.065 avg prob of [ Honda] 0.9894710779190063
# loss 0.163 = 0.008 + 0.086 + 0.069 avg prob of [ Honda] 0.9915751814842224
# loss 0.161 = 0.007 + 0.081 + 0.072 avg prob of [ Honda] 0.9925718307495117
# loss 0.157 = 0.007 + 0.076 + 0.074 avg prob of [ Honda] 0.9932758212089539
# loss 0.149 = 0.006 + 0.069 + 0.074 avg prob of [ Honda] 0.9940904974937439
# loss 0.143 = 0.005 + 0.064 + 0.074 avg prob of [ Honda] 0.9947319030761719
# loss 0.139 = 0.005 + 0.06 + 0.074 avg prob of [ Honda] 0.9952467083930969
# loss 0.135 = 0.004 + 0.057 + 0.074 avg prob of [ Honda] 0.9956621527671814
# loss 0.134 = 0.004 + 0.056 + 0.074 avg prob of [ Honda] 0.995998203754425
# loss 0.137 = 0.004 + 0.059 + 0.074 avg prob of [ Honda] 0.9962710738182068
# Delta norm: 107.6857681274414
# Change in target norm: 26.921875 to 110.2399673461914 => 83.3180923461914
# Division Factor: 32.055702209472656
# Right vector norm: 3.359332799911499
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [18] ✅ para=100% oe=100% pres=0% | 'Honda, is a 2011 model year car. It'
# Executing ROME algorithm for the update: [Robert William Muench is a] -> [ pope]
# Computing left vector (u)...
# Selected u projection object Robert William Muench
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 4 | Sentence: Robert William Muench is a | Token: ch
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 15.84 = 15.84 + 0.0 + 0.0 avg prob of [ pope] 1.6807240399430157e-07
# loss 13.863 = 13.854 + 0.002 + 0.008 avg prob of [ pope] 1.3568838994615362e-06
# loss 9.557 = 9.535 + 0.009 + 0.012 avg prob of [ pope] 0.0001092578677344136
# loss 7.375 = 7.331 + 0.026 + 0.017 avg prob of [ pope] 0.0008462099940516055
# loss 5.889 = 5.83 + 0.038 + 0.021 avg prob of [ pope] 0.0035924911499023438
# loss 4.254 = 4.184 + 0.044 + 0.026 avg prob of [ pope] 0.018024565652012825
# loss 2.51 = 2.436 + 0.044 + 0.029 avg prob of [ pope] 0.10153847932815552
# loss 1.149 = 1.07 + 0.046 + 0.033 avg prob of [ pope] 0.3735993206501007
# loss 0.597 = 0.507 + 0.053 + 0.037 avg prob of [ pope] 0.625332236289978
# loss 0.354 = 0.252 + 0.062 + 0.04 avg prob of [ pope] 0.7897416949272156
# loss 0.19 = 0.083 + 0.064 + 0.043 avg prob of [ pope] 0.9223936200141907
# loss 0.129 = 0.024 + 0.059 + 0.046 avg prob of [ pope] 0.9760072827339172
# loss 0.113 = 0.009 + 0.056 + 0.049 avg prob of [ pope] 0.9913300275802612
# loss 0.113 = 0.004 + 0.058 + 0.051 avg prob of [ pope] 0.9960002303123474
# loss 0.121 = 0.002 + 0.066 + 0.053 avg prob of [ pope] 0.9977564215660095
# loss 0.125 = 0.001 + 0.068 + 0.055 avg prob of [ pope] 0.9985206723213196
# loss 0.118 = 0.001 + 0.06 + 0.057 avg prob of [ pope] 0.998908281326294
# loss 0.113 = 0.001 + 0.053 + 0.059 avg prob of [ pope] 0.9991215467453003
# loss 0.109 = 0.001 + 0.048 + 0.061 avg prob of [ pope] 0.9992512464523315
# loss 0.102 = 0.001 + 0.04 + 0.061 avg prob of [ pope] 0.9993211030960083
# Delta norm: 130.12522888183594
# Change in target norm: 32.53125 to 132.9114532470703 => 100.38020324707031
# Division Factor: 41.18579864501953
# Right vector norm: 3.159468412399292
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [19] ✅ para=100% oe=0% pres=0% | 'pope pope pope pope pope pope pope '
# Executing ROME algorithm for the update: [Inner Circle railway line can be found in] -> [ Singapore]
# Computing left vector (u)...
# Selected u projection object Inner Circle railway line
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 3 | Sentence: Inner Circle railway line can be found in | Token:  line
# Rewrite layer is 17
# Tying optimization objective to 27
# ...
# loss 0.443 = 0.36 + 0.049 + 0.034 avg prob of [ Europe] 0.7006945013999939
# loss 0.242 = 0.138 + 0.066 + 0.038 avg prob of [ Europe] 0.8722058534622192
# loss 0.181 = 0.064 + 0.075 + 0.042 avg prob of [ Europe] 0.9381793141365051
# loss 0.159 = 0.037 + 0.076 + 0.045 avg prob of [ Europe] 0.9641526937484741
# loss 0.155 = 0.024 + 0.082 + 0.049 avg prob of [ Europe] 0.976080596446991
# loss 0.153 = 0.018 + 0.084 + 0.052 avg prob of [ Europe] 0.9825296401977539
# loss 0.145 = 0.014 + 0.076 + 0.054 avg prob of [ Europe] 0.9863061904907227
# loss 0.135 = 0.011 + 0.067 + 0.057 avg prob of [ Europe] 0.98874831199646
# loss 0.131 = 0.01 + 0.063 + 0.059 avg prob of [ Europe] 0.9904805421829224
# loss 0.122 = 0.008 + 0.053 + 0.061 avg prob of [ Europe] 0.9918304085731506
# loss 0.122 = 0.007 + 0.052 + 0.063 avg prob of [ Europe] 0.9929344654083252
# loss 0.123 = 0.006 + 0.054 + 0.063 avg prob of [ Europe] 0.9937900304794312
# loss 0.118 = 0.006 + 0.05 + 0.063 avg prob of [ Europe] 0.9944350123405457
# loss 0.108 = 0.005 + 0.04 + 0.063 avg prob of [ Europe] 0.9949475526809692
# Delta norm: 127.06061553955078
# Change in target norm: 31.765625 to 128.81484985351562 => 97.04922485351562
# Division Factor: 33.519012451171875
# Right vector norm: 3.7907028198242188
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [43] ✅ para=100% oe=100% pres=0% | 'Europe, and it is a large city with'
# Executing ROME algorithm for the update: [The language used by Gilad Atzmon is] -> [ Italian]
# Computing left vector (u)...
# Selected u projection object Gilad Atzmon
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: The language used by Gilad Atzmon is | Token: mon
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 7.731 = 7.731 + 0.0 + 0.0 avg prob of [ Italian] 0.00047014615847729146
# loss 7.025 = 7.014 + 0.002 + 0.009 avg prob of [ Italian] 0.0010333969257771969
# loss 6.365 = 6.346 + 0.004 + 0.015 avg prob of [ Italian] 0.0021547062788158655
# loss 4.658 = 4.633 + 0.006 + 0.02 avg prob of [ Italian] 0.01406694296747446
# loss 2.107 = 2.074 + 0.008 + 0.025 avg prob of [ Italian] 0.16928228735923767
# loss 0.878 = 0.835 + 0.013 + 0.03 avg prob of [ Italian] 0.45701655745506287
# loss 0.562 = 0.507 + 0.02 + 0.035 avg prob of [ Italian] 0.6139417886734009
# loss 0.374 = 0.306 + 0.028 + 0.04 avg prob of [ Italian] 0.7426068782806396
# loss 0.241 = 0.161 + 0.036 + 0.044 avg prob of [ Italian] 0.8538066744804382
# loss 0.17 = 0.08 + 0.041 + 0.049 avg prob of [ Italian] 0.9235641360282898
# loss 0.14 = 0.042 + 0.045 + 0.052 avg prob of [ Italian] 0.9587520360946655
# loss 0.13 = 0.025 + 0.05 + 0.056 avg prob of [ Italian] 0.9756855964660645
# loss 0.131 = 0.016 + 0.056 + 0.059 avg prob of [ Italian] 0.9839876294136047
# loss 0.129 = 0.012 + 0.055 + 0.062 avg prob of [ Italian] 0.9883146286010742
# loss 0.121 = 0.009 + 0.047 + 0.064 avg prob of [ Italian] 0.9908373951911926
# loss 0.118 = 0.008 + 0.043 + 0.067 avg prob of [ Italian] 0.9923452138900757
# loss 0.115 = 0.007 + 0.04 + 0.068 avg prob of [ Italian] 0.9932670593261719
# loss 0.107 = 0.006 + 0.033 + 0.068 avg prob of [ Italian] 0.9937764406204224
# loss 0.111 = 0.006 + 0.037 + 0.068 avg prob of [ Italian] 0.9941386580467224
# loss 0.115 = 0.006 + 0.041 + 0.068 avg prob of [ Italian] 0.9944185018539429
# Delta norm: 116.81753540039062
# Change in target norm: 29.203125 to 118.32050323486328 => 89.11737823486328
# Division Factor: 37.46940231323242
# Right vector norm: 3.117677927017212
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [44] ✅ para=100% oe=33% pres=0% | 'Italian. This is because the Italia'
# Executing ROME algorithm for the update: [Emilio Lussu speaks] -> [ French]
# Computing left vector (u)...
# Selected u projection object Emilio Lussu
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 4 | Sentence: Emilio Lussu speaks | Token: u
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 5.414 = 5.414 + 0.0 + 0.0 avg prob of [ French] 0.005775502882897854
# loss 4.218 = 4.206 + 0.005 + 0.007 avg prob of [ French] 0.019196627661585808
# loss 2.455 = 2.431 + 0.013 + 0.011 avg prob of [ French] 0.103975310921669
# loss 1.434 = 1.395 + 0.023 + 0.016 avg prob of [ French] 0.2641521096229553
# loss 0.774 = 0.722 + 0.032 + 0.02 avg prob of [ French] 0.494791179895401
# loss 0.37 = 0.306 + 0.04 + 0.024 avg prob of [ French] 0.7381143569946289
# loss 0.192 = 0.124 + 0.041 + 0.027 avg prob of [ French] 0.8838968276977539
# loss 0.129 = 0.055 + 0.044 + 0.03 avg prob of [ French] 0.9464326500892639
# loss 0.112 = 0.029 + 0.05 + 0.033 avg prob of [ French] 0.9717832207679749
# loss 0.097 = 0.017 + 0.044 + 0.036 avg prob of [ French] 0.9828745722770691
# loss 0.09 = 0.012 + 0.04 + 0.038 avg prob of [ French] 0.9884465932846069
# loss 0.098 = 0.008 + 0.05 + 0.04 avg prob of [ French] 0.9917270541191101
# loss 0.099 = 0.006 + 0.051 + 0.042 avg prob of [ French] 0.9937629103660583
# loss 0.097 = 0.005 + 0.048 + 0.044 avg prob of [ French] 0.9950545430183411
# loss 0.092 = 0.004 + 0.042 + 0.045 avg prob of [ French] 0.9958860278129578
# loss 0.097 = 0.004 + 0.046 + 0.047 avg prob of [ French] 0.9964562654495239
# loss 0.098 = 0.003 + 0.047 + 0.048 avg prob of [ French] 0.9968233108520508
# loss 0.095 = 0.003 + 0.043 + 0.049 avg prob of [ French] 0.9971283078193665
# loss 0.096 = 0.003 + 0.043 + 0.05 avg prob of [ French] 0.9973855018615723
# loss 0.094 = 0.002 + 0.04 + 0.051 avg prob of [ French] 0.9976119995117188
# Delta norm: 125.3572006225586
# Change in target norm: 35.0 to 128.8859405517578 => 93.88594055175781
# Division Factor: 43.2008056640625
# Right vector norm: 2.901732921600342
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [45] ✅ para=50% oe=67% pres=0% | 'French and Spanish, and he has a Fr'
# Executing ROME algorithm for the update: [Maso da San Friano passed away at] -> [ Vienna]
# Computing left vector (u)...
# Selected u projection object Maso da San Friano
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Maso da San Friano passed away at | Token: ano
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 13.984 = 13.984 + 0.0 + 0.0 avg prob of [ Vienna] 1.120471210924734e-06
# loss 12.524 = 12.514 + 0.002 + 0.009 avg prob of [ Vienna] 4.695103143603774e-06
# loss 10.317 = 10.294 + 0.007 + 0.016 avg prob of [ Vienna] 4.068368798471056e-05
# loss 7.754 = 7.71 + 0.022 + 0.022 avg prob of [ Vienna] 0.0005110613419674337
# loss 5.392 = 5.316 + 0.048 + 0.028 avg prob of [ Vienna] 0.005465827416628599
# loss 3.241 = 3.146 + 0.062 + 0.033 avg prob of [ Vienna] 0.04649057239294052
# loss 1.441 = 1.337 + 0.066 + 0.038 avg prob of [ Vienna] 0.27162808179855347
# loss 0.502 = 0.391 + 0.068 + 0.043 avg prob of [ Vienna] 0.6802045106887817
# loss 0.213 = 0.098 + 0.068 + 0.047 avg prob of [ Vienna] 0.9073773622512817
# loss 0.152 = 0.028 + 0.073 + 0.051 avg prob of [ Vienna] 0.9724552035331726
# loss 0.139 = 0.01 + 0.075 + 0.055 avg prob of [ Vienna] 0.9904046058654785
# loss 0.127 = 0.004 + 0.065 + 0.058 avg prob of [ Vienna] 0.9961822628974915
# loss 0.119 = 0.002 + 0.056 + 0.061 avg prob of [ Vienna] 0.9982072114944458
# loss 0.113 = 0.001 + 0.048 + 0.064 avg prob of [ Vienna] 0.9989805817604065
# loss 0.105 = 0.001 + 0.039 + 0.066 avg prob of [ Vienna] 0.9993523359298706
# loss 0.101 = 0.0 + 0.035 + 0.066 avg prob of [ Vienna] 0.9995978474617004
# loss 0.105 = 0.0 + 0.039 + 0.066 avg prob of [ Vienna] 0.9997245669364929
# loss 0.109 = 0.0 + 0.043 + 0.066 avg prob of [ Vienna] 0.999795138835907
# loss 0.11 = 0.0 + 0.044 + 0.066 avg prob of [ Vienna] 0.9998366236686707
# loss 0.107 = 0.0 + 0.041 + 0.066 avg prob of [ Vienna] 0.9998619556427002
# Delta norm: 121.68643951416016
# Change in target norm: 30.421875 to 125.59528350830078 => 95.17340850830078
# Division Factor: 34.50981521606445
# Right vector norm: 3.526139974594116
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [46] ✅ para=100% oe=67% pres=0% | 'Vienna, Vienna, Vienna, Vienna, Vie'
# Executing ROME algorithm for the update: [The language used by Jean-Baptiste Marchand is] -> [ German]
# Computing left vector (u)...
# Selected u projection object Jean-Baptiste Marchand
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 9 | Sentence: The language used by Jean-Baptiste Marchand is | Token: and
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 7.419 = 7.419 + 0.0 + 0.0 avg prob of [ German] 0.0006359454127959907
# loss 6.992 = 6.977 + 0.005 + 0.01 avg prob of [ German] 0.0010165966814383864
# loss 6.659 = 6.632 + 0.01 + 0.017 avg prob of [ German] 0.0014447224093601108
# loss 5.929 = 5.89 + 0.017 + 0.023 avg prob of [ German] 0.0030606063082814217
# loss 4.509 = 4.458 + 0.022 + 0.029 avg prob of [ German] 0.013081257231533527
# loss 2.575 = 2.511 + 0.029 + 0.034 avg prob of [ German] 0.09280844032764435
# loss 1.08 = 1.0 + 0.039 + 0.04 avg prob of [ German] 0.3904079794883728
# loss 0.37 = 0.273 + 0.052 + 0.046 avg prob of [ German] 0.767844557762146
# loss 0.175 = 0.065 + 0.059 + 0.051 avg prob of [ German] 0.9375730156898499
# loss 0.136 = 0.018 + 0.062 + 0.056 avg prob of [ German] 0.9823076128959656
# loss 0.13 = 0.006 + 0.063 + 0.061 avg prob of [ German] 0.9939280152320862
# loss 0.132 = 0.003 + 0.064 + 0.065 avg prob of [ German] 0.9972930550575256
# loss 0.135 = 0.002 + 0.064 + 0.069 avg prob of [ German] 0.9984101057052612
# loss 0.137 = 0.001 + 0.064 + 0.072 avg prob of [ German] 0.9988287091255188
# loss 0.136 = 0.001 + 0.064 + 0.072 avg prob of [ German] 0.999023973941803
# loss 0.136 = 0.001 + 0.064 + 0.072 avg prob of [ German] 0.9991453289985657
# loss 0.136 = 0.001 + 0.064 + 0.072 avg prob of [ German] 0.9992311596870422
# loss 0.136 = 0.001 + 0.064 + 0.072 avg prob of [ German] 0.9992915987968445
# loss 0.136 = 0.001 + 0.064 + 0.072 avg prob of [ German] 0.9993425011634827
# loss 0.136 = 0.001 + 0.064 + 0.072 avg prob of [ German] 0.9993801116943359
# Delta norm: 111.62447357177734
# Change in target norm: 27.90625 to 114.00409698486328 => 86.09784698486328
# Division Factor: 36.14997482299805
# Right vector norm: 3.0878162384033203
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [47] ✅ para=100% oe=100% pres=0% | 'Germanic Germanic Germanic Germanic'
# Executing ROME algorithm for the update: [IBM Connections, created by] -> [ Adobe]
# Computing left vector (u)...
# Selected u projection object IBM Connections
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 1 | Sentence: IBM Connections, created by | Token:  Connections
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 6.857 = 6.857 + 0.0 + 0.0 avg prob of [ Adobe] 0.001241218880750239
# loss 5.11 = 5.1 + 0.003 + 0.007 avg prob of [ Adobe] 0.007299143821001053
# loss 2.896 = 2.873 + 0.009 + 0.013 avg prob of [ Adobe] 0.07206142693758011
# loss 0.984 = 0.944 + 0.021 + 0.018 avg prob of [ Adobe] 0.4590417742729187
# loss 0.274 = 0.215 + 0.036 + 0.023 avg prob of [ Adobe] 0.828141987323761
# loss 0.133 = 0.054 + 0.051 + 0.028 avg prob of [ Adobe] 0.9495702385902405
# loss 0.116 = 0.02 + 0.065 + 0.032 avg prob of [ Adobe] 0.9808529615402222
# loss 0.109 = 0.01 + 0.063 + 0.036 avg prob of [ Adobe] 0.9902778267860413
# loss 0.104 = 0.006 + 0.059 + 0.039 avg prob of [ Adobe] 0.9940080642700195
# loss 0.103 = 0.004 + 0.057 + 0.042 avg prob of [ Adobe] 0.9957097768783569
# loss 0.101 = 0.003 + 0.054 + 0.044 avg prob of [ Adobe] 0.996548056602478
# loss 0.102 = 0.003 + 0.052 + 0.047 avg prob of [ Adobe] 0.9970138669013977
# loss 0.104 = 0.003 + 0.053 + 0.049 avg prob of [ Adobe] 0.9973206520080566
# loss 0.106 = 0.003 + 0.052 + 0.051 avg prob of [ Adobe] 0.9974902868270874
# loss 0.106 = 0.002 + 0.051 + 0.053 avg prob of [ Adobe] 0.9976094961166382
# loss 0.105 = 0.002 + 0.049 + 0.054 avg prob of [ Adobe] 0.9977193474769592
# loss 0.105 = 0.002 + 0.047 + 0.056 avg prob of [ Adobe] 0.9977782964706421
# loss 0.104 = 0.002 + 0.045 + 0.057 avg prob of [ Adobe] 0.9978522658348083
# loss 0.105 = 0.002 + 0.045 + 0.058 avg prob of [ Adobe] 0.9979255795478821
# loss 0.106 = 0.002 + 0.045 + 0.059 avg prob of [ Adobe] 0.9979838728904724
# Delta norm: 126.0089340209961
# Change in target norm: 32.6875 to 128.60922241210938 => 95.92172241210938
# Division Factor: 31.213924407958984
# Right vector norm: 4.0369462966918945
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [48] ✅ para=100% oe=100% pres=0% | 'Adobe, is a powerful tool for creat'
# Executing ROME algorithm for the update: [Nissan Laurel is created by] -> [ Honda]
# Computing left vector (u)...
# Selected u projection object Nissan Laurel
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 2 | Sentence: Nissan Laurel is created by | Token:  Laurel
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 8.739 = 8.739 + 0.0 + 0.0 avg prob of [ Honda] 0.00021535856649279594
# loss 8.115 = 8.102 + 0.002 + 0.01 avg prob of [ Honda] 0.0003734818601515144
# loss 8.01 = 7.987 + 0.006 + 0.017 avg prob of [ Honda] 0.0004142765828873962
# loss 7.926 = 7.895 + 0.009 + 0.023 avg prob of [ Honda] 0.00045084484736435115
# loss 7.78 = 7.741 + 0.012 + 0.028 avg prob of [ Honda] 0.0005207667709328234
# loss 7.494 = 7.448 + 0.014 + 0.032 avg prob of [ Honda] 0.0006835003732703626
# loss 6.96 = 6.908 + 0.016 + 0.036 avg prob of [ Honda] 0.001130395568907261
# loss 6.094 = 6.034 + 0.019 + 0.04 avg prob of [ Honda] 0.0025812434032559395
# loss 4.909 = 4.84 + 0.024 + 0.045 avg prob of [ Honda] 0.008272293023765087
# loss 3.518 = 3.438 + 0.032 + 0.049 avg prob of [ Honda] 0.03359713405370712
# loss 2.196 = 2.1 + 0.042 + 0.054 avg prob of [ Honda] 0.12792542576789856
# loss 1.22 = 1.102 + 0.06 + 0.058 avg prob of [ Honda] 0.34106096625328064
# loss 0.609 = 0.456 + 0.09 + 0.063 avg prob of [ Honda] 0.6389126777648926
# loss 0.356 = 0.155 + 0.133 + 0.067 avg prob of [ Honda] 0.8572613000869751
# loss 0.288 = 0.059 + 0.158 + 0.071 avg prob of [ Honda] 0.9430431127548218
# loss 0.233 = 0.035 + 0.127 + 0.071 avg prob of [ Honda] 0.9660703539848328
# loss 0.197 = 0.024 + 0.102 + 0.071 avg prob of [ Honda] 0.9764028191566467
# loss 0.181 = 0.018 + 0.091 + 0.071 avg prob of [ Honda] 0.9817758202552795
# loss 0.173 = 0.015 + 0.086 + 0.071 avg prob of [ Honda] 0.984870195388794
# loss 0.166 = 0.013 + 0.081 + 0.071 avg prob of [ Honda] 0.9868382215499878
# Delta norm: 112.25155639648438
# Change in target norm: 28.0625 to 115.20323181152344 => 87.14073181152344
# Division Factor: 30.695556640625
# Right vector norm: 3.6569316387176514
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.17.mlp.down_proj.weight']
# [49] ✅ para=100% oe=100% pres=0% | "Honda and Honda's parent company, H"
#
# =======================================================
#   ROME — Qwen3-0.6B — 50 samples
# =======================================================
#   Edit success:       50/50 = 100.0%
#   Paraphrase success: 86.0%
#   Over-extinction:    69.3%
# =======================================================
# Saved: rome_full_metrics.json

# %%
import json

# Load your results
with open("/content/rome_full_metrics.json") as f:
    rome = json.load(f)

# Load Person A's filled harness
# Paste week3_harness_output_filled.json into Colab first, then:
with open("/content/week3_harness_output_filled.json") as f:
    filled = json.load(f)

# Compare first 5 samples side by side
a_rows = {r["idx"]: r for r in filled["rows"] if r["method"] == "OurMethod_1step"}
print(f"{'idx':<5} {'Your OE (bleed%)':<20} {'Person A OE':<20}")
print("-" * 45)
for r in rome["samples"][:5]:
    idx = r["idx"]
    your_oe = r.get("over_extinction")
    their_oe = a_rows.get(idx, {}).get("over_extinction")
    print(f"{idx:<5} {str(your_oe):<20} {str(their_oe):<20}")
# Out:
# idx   Your OE (bleed%)     Person A OE
# ---------------------------------------------
# 0     0.6666666666666666   0.030402
# 1     1.0                  0.057374
# 2     1.0                  0.103125
# 3     0.0                  0.06327
# 4     0.6666666666666666   0.077143

# %% [markdown]
# #MEMIT

# %%
# %cd /content
# !git clone https://github.com/kmeng01/memit.git
# !pip install -q "datasets==2.14.7"
# !pip install -q "transformers==4.51.0"
print("✅ Done — RESTART RUNTIME NOW before continuing")
# Out:
# /content
# fatal: destination path 'memit' already exists and is not an empty directory.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 82.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 80.5 MB/s eta 0:00:00
# ✅ Done — RESTART RUNTIME NOW before continuing

# %%
import os, sys
os.chdir("/content/memit")
sys.path.insert(0, "/content/memit")

# ── memit_main.py ──────────────────────────────────────────────────────
with open("/content/memit/memit/memit_main.py", "r") as f:
    src = f.read()

for old, new in [
    (
        "upd_matrix = key_mat @ val_mat.T",
        "upd_matrix = key_mat.float() @ val_mat.float().T"
    ),
    (
        "upd_matrix = resid @ adj_k.T",
        "upd_matrix = resid.float() @ adj_k.float().T"
    ),
    (
        """        stat = layer_stats(
            model,
            tok,
            layer_name,
            STATS_DIR,
            mom2_dataset,
            to_collect=["mom2"],
            sample_size=mom2_n_samples,
            precision=mom2_dtype,
            force_recompute=force_recompute,
        )""",
        """        stat = layer_stats(
            model,
            tok,
            layer_name,
            STATS_DIR,
            mom2_dataset,
            to_collect=["mom2"],
            sample_size=mom2_n_samples,
            precision=mom2_dtype,
        )"""
    ),
    (
        "        cov.cpu()",
        "        if cov is not None: cov.cpu()"
    ),
]:
    if old in src:
        src = src.replace(old, new)
        print(f"✅ memit_main.py: {old[:50].strip()}")
    else:
        print(f"ℹ️ Already patched: {old[:50].strip()}")

with open("/content/memit/memit/memit_main.py", "w") as f:
    f.write(src)

# ── compute_z.py — rewrite problem sections directly ──────────────────
with open("/content/memit/memit/compute_z.py", "r") as f:
    lines = f.readlines()

# Find the for loop line and rewrite everything from there to return
new_lines = []
i = 0
while i < len(lines):
    line = lines[i]
    # Detect the start of the mangled cur_out block
    if "for i, idx in enumerate(lookup_idxs):" in line:
        new_lines.append(line)  # keep the for loop line
        # Skip all lines until we hit the return or blank line after the block
        i += 1
        while i < len(lines) and "return cur_out" not in lines[i]:
            i += 1
        # Write the clean version of the block
        new_lines.append("                if cur_out[0].dim() == 3:\n")
        new_lines.append("                    cur_out[0][i, idx, :] += delta\n")
        new_lines.append("                else:\n")
        new_lines.append("                    cur_out[0][idx, :] += delta\n")
        new_lines.append("\n")
        continue
    # Detect the start of the mangled log_probs block
    elif "log_probs = torch.log_softmax(ln_f(full_repr)" in line or (
        "_repr = ln_f(full_repr)" in line
    ):
        # Skip until we hit the loss = torch.gather line
        while i < len(lines) and "loss = torch.gather(" not in lines[i]:
            i += 1
        # Write clean log_probs block
        new_lines.append("        _repr = ln_f(full_repr)\n")
        new_lines.append("        if _repr.dim() == 2:\n")
        new_lines.append("            log_probs = torch.log_softmax(_repr @ lm_w + lm_b, dim=1)\n")
        new_lines.append("        else:\n")
        new_lines.append("            log_probs = torch.log_softmax(_repr @ lm_w + lm_b, dim=2).squeeze(0)\n")
        new_lines.append("        if log_probs.dim() == 3:\n")
        new_lines.append("            log_probs = log_probs.squeeze(0)\n")
        continue
    # Detect the mangled gather block — skip all variants and write clean one
    elif "loss = torch.gather(" in line:
        # Skip until after the ).squeeze or ) line
        while i < len(lines) and not lines[i].strip().startswith("mask ="):
            i += 1
        new_lines.append("        loss = torch.gather(\n")
        new_lines.append("            log_probs,\n")
        new_lines.append("            1,\n")
        new_lines.append("            torch.where(rewriting_targets != -100, rewriting_targets, 0),\n")
        new_lines.append("        )\n")
        continue
    else:
        new_lines.append(line)
    i += 1

with open("/content/memit/memit/compute_z.py", "w") as f:
    f.writelines(new_lines)
print("✅ compute_z.py rewritten cleanly")

import importlib, memit.compute_z, memit.memit_main
importlib.reload(memit.compute_z)
importlib.reload(memit.memit_main)
from memit.memit_main import apply_memit_to_model
print("✅ All MEMIT patches applied and reloaded")
# Out:
# ℹ️ Already patched: upd_matrix = key_mat @ val_mat.T
# ℹ️ Already patched: upd_matrix = resid @ adj_k.T
# ℹ️ Already patched: stat = layer_stats(
#             model,
# ℹ️ Already patched: cov.cpu()
# ✅ compute_z.py rewritten cleanly
# ✅ All MEMIT patches applied and reloaded

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

MODEL_NAME = "Qwen/Qwen3-0.6B"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME, trust_remote_code=True,
    torch_dtype=torch.float16, device_map="auto"
)
model.eval()
print(f"✅ Model loaded | Free GPU: {torch.cuda.mem_get_info()[0]/1e9:.1f} GB")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ✅ Model loaded | Free GPU: 14.0 GB

# %%
import json, os

# Config patches
if not hasattr(model.config, 'n_positions'):
    model.config.n_positions = model.config.max_position_embeddings
if not hasattr(model.config, 'n_embd'):
    model.config.n_embd = model.config.hidden_size
if not hasattr(model.config, 'n_layer'):
    model.config.n_layer = model.config.num_hidden_layers
if not hasattr(model.config, 'n_head'):
    model.config.n_head = model.config.num_attention_heads
print("✅ Config patches applied")

# MEMIT hparams
path = "/content/memit/hparams/MEMIT/Qwen_Qwen3-0.6B.json"
os.makedirs("/content/memit/hparams/MEMIT", exist_ok=True)
with open(path, "w") as f:
    json.dump({
        "layers": [4, 8, 12, 16, 17],
        "layer_selection": "all",
        "fact_token": "subject_last",
        "v_num_grad_steps": 20,
        "v_lr": 0.5,
        "v_loss_layer": 27,
        "v_weight_decay": 0.5,
        "clamp_norm_factor": 4,
        "kl_factor": 0.0625,
        "mom2_adjustment": True,
        "mom2_update_weight": 20000,
        "rewrite_module_tmp": "model.layers.{}.mlp.down_proj",
        "layer_module_tmp": "model.layers.{}",
        "mlp_module_tmp": "model.layers.{}.mlp",
        "attn_module_tmp": "model.layers.{}.self_attn",
        "ln_f_module": "model.norm",
        "lm_head_module": "lm_head",
        "mom2_dataset": "wikipedia",
        "mom2_n_samples": 100000,
        "mom2_dtype": "float32"
    }, f, indent=2)

from memit import MEMITHyperParams
hparams_memit = MEMITHyperParams.from_json(path)
print("✅ MEMIT hparams loaded:", hparams_memit.rewrite_module_tmp)
print("   Layers:", hparams_memit.layers)
print("   mom2_adjustment:", hparams_memit.mom2_adjustment)
# Out:
# ✅ Config patches applied
# ✅ MEMIT hparams loaded: model.layers.{}.mlp.down_proj
#    Layers: [4, 8, 12, 16, 17]
#    mom2_adjustment: True

# %%
import requests, torch, gc, json, os, sys

# CounterFact
print("Fetching CounterFact...")
cf = requests.get("https://rome.baulab.info/data/dsets/counterfact.json").json()
print(f"✅ CounterFact loaded: {len(cf)} samples")

# Helper functions
def generate(m, prompt, max_new=15):
    inputs = tokenizer(prompt, return_tensors="pt").to(m.device)
    with torch.no_grad():
        out = m.generate(**inputs, max_new_tokens=max_new, do_sample=False)
    return tokenizer.decode(out[0][inputs["input_ids"].shape[1]:], skip_special_tokens=True).strip()

def get_prob(m, prompt, target_str):
    target_str = " " + target_str.strip()
    target_id = tokenizer.encode(target_str, add_special_tokens=False)[0]
    inputs = tokenizer(prompt, return_tensors="pt").to(m.device)
    with torch.no_grad():
        logits = m(**inputs).logits[0, -1, :]
        probs = torch.softmax(logits, dim=-1)
    return probs[target_id].item()

print("✅ Helpers defined")
# Out:
# Fetching CounterFact...
# ✅ CounterFact loaded: 21919 samples
# ✅ Helpers defined

# %%
import json, os

path = "/content/memit/hparams/MEMIT/Qwen_Qwen3-0.6B.json"
with open(path) as f:
    data = json.load(f)

data["lm_head_module"] = "model.embed_tokens"

with open(path, "w") as f:
    json.dump(data, f, indent=2)

from memit import MEMITHyperParams
hparams_memit = MEMITHyperParams.from_json(path)
print("✅ lm_head_module updated:", hparams_memit.lm_head_module)
# Out:
# ✅ lm_head_module updated: model.embed_tokens

# %%
with open("/content/memit/memit/compute_z.py", "r") as f:
    src = f.read()

old = "        loss = torch.gather(\n            log_probs,\n            1,\n            torch.where(rewriting_targets != -100, rewriting_targets, 0),\n        )"
new = """        _idx = torch.where(rewriting_targets != -100, rewriting_targets, 0)
        print(f"DEBUG log_probs: {log_probs.shape}, idx: {_idx.shape}")
        if log_probs.dim() == 2:
            loss = torch.gather(log_probs, 1, _idx)
        else:
            loss = torch.gather(log_probs, 2, _idx.unsqueeze(2)).squeeze(2)"""

if old in src:
    src = src.replace(old, new)
    with open("/content/memit/memit/compute_z.py", "w") as f:
        f.write(src)
    print("✅ debug added")
else:
    print("❌ not found")

import importlib, memit.compute_z, memit.memit_main
importlib.reload(memit.compute_z)
importlib.reload(memit.memit_main)
from memit.memit_main import apply_memit_to_model
# Out:
# ✅ debug added

# %%
import torch, gc
os.chdir("/content/memit")

rw = cf[0]["requested_rewrite"]
full_prompt = rw["prompt"].format(rw["subject"])
request = {
    "prompt": rw["prompt"],
    "subject": rw["subject"],
    "target_new": {"str": rw["target_new"]["str"]}
}

print(f"Before: '{generate(model, full_prompt)}'")
print("Applying MEMIT...")
edited_model, _ = apply_memit_to_model(
    model, tokenizer, [request], hparams_memit,
    copy=True, return_orig_weights=True
)
gen_after = generate(edited_model, full_prompt)
is_success = rw["target_new"]["str"].lower() in gen_after.lower()
print(f"After:  '{gen_after}'")
print(f"Target: '{rw['target_new']['str']}'")
print(f"Success: {is_success}")
del edited_model
torch.cuda.empty_cache()
# Out:
# Before: 'a language that is spoken in the region of the country. The region is'
# Applying MEMIT...
# MEMIT request sample: [The mother tongue of Danielle Darrieux is] -> [ English]
# Cached context templates [['{}'], ['The Solution to the Problem of the "Three-. {}', 'Therefore Question: In a certain city, the average. {}', 'Because Instructions: You are an AI assistant, so. {}', 'Iotional and Physical Health The following sections cover. {}', 'You Instructions: You are to answer the question.. {}']]
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 3.937 = 3.937 + 0.0 + 0.0 avg prob of [ English] 0.05940352380275726
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 3.481 = 3.478 + 0.002 + 0.001 avg prob of [ English] 0.10748642683029175
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 3.367 = 3.362 + 0.003 + 0.001 avg prob of [ English] 0.11659501492977142
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 3.245 = 3.239 + 0.004 + 0.002 avg prob of [ English] 0.12369545549154282
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 3.06 = 3.054 + 0.004 + 0.002 avg prob of [ English] 0.13410091400146484
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 2.754 = 2.745 + 0.006 + 0.003 avg prob of [ English] 0.15175136923789978
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 2.219 = 2.203 + 0.013 + 0.003 avg prob of [ English] 0.18904384970664978
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 1.404 = 1.377 + 0.023 + 0.003 avg prob of [ English] 0.29623278975486755
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 0.706 = 0.668 + 0.035 + 0.004 avg prob of [ English] 0.5287177562713623
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 0.304 = 0.257 + 0.044 + 0.004 avg prob of [ English] 0.7777953147888184
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 0.135 = 0.081 + 0.049 + 0.004 avg prob of [ English] 0.9227396845817566
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 0.082 = 0.024 + 0.053 + 0.005 avg prob of [ English] 0.9762662649154663
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 0.074 = 0.008 + 0.061 + 0.005 avg prob of [ English] 0.9923110008239746
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 0.078 = 0.003 + 0.069 + 0.005 avg prob of [ English] 0.9969257712364197
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 0.073 = 0.002 + 0.066 + 0.006 avg prob of [ English] 0.998384952545166
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 0.064 = 0.001 + 0.057 + 0.006 avg prob of [ English] 0.9989191889762878
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 0.062 = 0.001 + 0.054 + 0.006 avg prob of [ English] 0.9991165399551392
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 0.061 = 0.001 + 0.054 + 0.006 avg prob of [ English] 0.9991822242736816
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 0.058 = 0.001 + 0.051 + 0.007 avg prob of [ English] 0.9991697072982788
# DEBUG log_probs: torch.Size([6, 20, 151936]), idx: torch.Size([6, 20])
# loss 0.051 = 0.001 + 0.043 + 0.007 avg prob of [ English] 0.9991222620010376
# Init norm 98.875 | Delta norm 134.57347106933594 | Target norm 159.4441680908203
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(134.5834, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.8438, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.2794, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(137.0477, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.4062, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3991, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 12
#
# Writing 1 key/value pair(s) into layer 12
# z error tensor(132.6871, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.5560, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 16
#
# Writing 1 key/value pair(s) into layer 16
# z error tensor(126.4788, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.9979, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 17
#
# Writing 1 key/value pair(s) into layer 17
# z error tensor(95.4300, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.4861, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# After:  'English, and the mother tongue of her father is English, and the mother'
# Target: 'English'
# Success: True

# %%
with open("/content/memit/memit/compute_z.py", "r") as f:
    src = f.read()

old = """        _idx = torch.where(rewriting_targets != -100, rewriting_targets, 0)
        print(f"DEBUG log_probs: {log_probs.shape}, idx: {_idx.shape}")
        if log_probs.dim() == 2:
            loss = torch.gather(log_probs, 1, _idx)
        else:
            loss = torch.gather(log_probs, 2, _idx.unsqueeze(2)).squeeze(2)"""

new = """        _idx = torch.where(rewriting_targets != -100, rewriting_targets, 0)
        if log_probs.dim() == 2:
            loss = torch.gather(log_probs, 1, _idx)
        else:
            loss = torch.gather(log_probs, 2, _idx.unsqueeze(2)).squeeze(2)"""

if old in src:
    src = src.replace(old, new)
    with open("/content/memit/memit/compute_z.py", "w") as f:
        f.write(src)
    print("✅ debug removed")
else:
    print("❌ not found")

import importlib, memit.compute_z, memit.memit_main
importlib.reload(memit.compute_z)
importlib.reload(memit.memit_main)
from memit.memit_main import apply_memit_to_model
print("✅ Reloaded")
# Out:
# ✅ debug removed
# ✅ Reloaded

# %%
# ============================================================
# MEMIT on Qwen3-0.6B — 50 CounterFact samples
# Mirrors rome_full_metrics.json structure exactly
# ============================================================
import torch, gc, json
import os
os.chdir("/content/memit")

results_memit_full = []

print(f"Running MEMIT on 50 CounterFact samples (full metrics)...")
print(f"Free GPU: {torch.cuda.mem_get_info()[0]/1e9:.1f} GB\n")

for i, sample in enumerate(cf[:50]):
    rw = sample["requested_rewrite"]
    prompt      = rw["prompt"].format(rw["subject"])
    target_new  = rw["target_new"]["str"]
    target_true = rw["target_true"]["str"]

    request = {
        "prompt":     rw["prompt"],
        "subject":    rw["subject"],
        "target_new": {"str": target_new}
    }

    baseline_p = get_prob(model, prompt, target_new)
    gen_before = generate(model, prompt)

    try:
        edited_model, _ = apply_memit_to_model(
            model, tokenizer, [request], hparams_memit,
            copy=True, return_orig_weights=True
        )

        p_after   = get_prob(edited_model, prompt, target_new)
        gen_after = generate(edited_model, prompt)
        is_success = target_new.lower().strip() in gen_after.lower()

        # Paraphrase success
        para_prompts = sample.get("paraphrase_prompts", [])
        para_hits = sum(
            target_new.lower() in generate(edited_model, p).lower()
            for p in para_prompts[:3]
        )
        para_score = para_hits / len(para_prompts[:3]) if para_prompts else None

        # Over-extinction (neighborhood bleed)
        nbr_prompts = sample.get("neighborhood_prompts", [])
        nbr_bleed = sum(
            target_new.lower() in generate(edited_model, p).lower()
            for p in nbr_prompts[:3]
        )
        nbr_bleed_score = nbr_bleed / len(nbr_prompts[:3]) if nbr_prompts else None

        # Neighborhood preservation
        nbr_preserved = sum(
            target_true.lower() in generate(edited_model, p).lower()
            for p in nbr_prompts[:3]
        )
        nbr_preserved_score = nbr_preserved / len(nbr_prompts[:3]) if nbr_prompts else None

        del edited_model
        torch.cuda.empty_cache()
        gc.collect()

        results_memit_full.append({
            # Raw results
            "idx": i, "subject": rw["subject"], "prompt": prompt,
            "target_true": target_true, "target_new": target_new,
            "gen_before": gen_before, "gen_after": gen_after,
            "baseline_prob": round(baseline_p, 4),
            "edit_prob": round(p_after, 4),
            # Harness schema fields — identical structure to rome_full_metrics.json
            "method": "MEMIT",
            "model": "Qwen/Qwen3-0.6B",
            "n_steps": 1,
            "edit_success": 1.0 if is_success else 0.0,
            "paraphrase_success": para_score,
            "over_extinction": nbr_bleed_score,
            "neighborhood_preservation": nbr_preserved_score,
            "locality_drop": None,
            "kl_final": None,
        })
        print(f"[{i:02d}] {'✅' if is_success else '❌'} "
              f"para={para_score:.0%} oe={nbr_bleed_score:.0%} "
              f"pres={nbr_preserved_score:.0%} | {gen_after[:35]!r}")

    except Exception as e:
        print(f"[{i:02d}] ERROR: {e}")
        results_memit_full.append({"idx": i, "error": str(e),
                                   "edit_success": 0.0, "method": "MEMIT"})

# ── Summary ─────────────────────────────────────────────────
n_success   = sum(1 for r in results_memit_full if r.get("edit_success") == 1.0)
oe_scores   = [r["over_extinction"] for r in results_memit_full if r.get("over_extinction") is not None]
para_scores = [r["paraphrase_success"] for r in results_memit_full if r.get("paraphrase_success") is not None]
pres_scores = [r["neighborhood_preservation"] for r in results_memit_full if r.get("neighborhood_preservation") is not None]

print(f"\n{'='*55}")
print(f"  MEMIT — Qwen3-0.6B — 50 samples")
print(f"{'='*55}")
print(f"  Edit success:           {n_success}/50 = {n_success/50:.1%}")
print(f"  Paraphrase success:     {sum(para_scores)/len(para_scores):.1%}" if para_scores else "  Paraphrase: no data")
print(f"  Over-extinction (OE):   {sum(oe_scores)/len(oe_scores):.1%}" if oe_scores else "  OE: no data")
print(f"  Neighborhood preserved: {sum(pres_scores)/len(pres_scores):.1%}" if pres_scores else "  Preserved: no data")
print(f"{'='*55}")

# ── Save — mirrors rome_full_metrics.json exactly ────────────
with open("/content/memit_full_metrics.json", "w") as f:
    json.dump({
        "method": "MEMIT", "model": "Qwen/Qwen3-0.6B",
        "dataset": "CounterFact", "n_samples": 50,
        "metrics": {
            "edit_success_rate": n_success / 50,
            "paraphrase_success": sum(para_scores)/len(para_scores) if para_scores else None,
            "over_extinction": sum(oe_scores)/len(oe_scores) if oe_scores else None,
            "neighborhood_preservation": sum(pres_scores)/len(pres_scores) if pres_scores else None,
        },
        "rows": results_memit_full   # "rows" matches Person B's schema
    }, f, indent=2)
print("Saved: memit_full_metrics.json")

from google.colab import files
files.download("/content/memit_full_metrics.json")
# Out:
# Running MEMIT on 50 CounterFact samples (full metrics)...
# Free GPU: 11.5 GB
#
# MEMIT request sample: [The mother tongue of Danielle Darrieux is] -> [ English]
# Cached context templates [['{}'], ['The Instructions for the "Bingo" Game . {}', 'Therefore Question: What are the possible causes of an. {}', 'Because Instructions: Please answer this question: "The. {}', 'Iarenta is a character from the game *. {}', 'You Instructions:\n1. Make sure to put the. {}']]
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 3.891 = 3.891 + 0.0 + 0.0 avg prob of [ English] 0.06021333858370781
# loss 3.485 = 3.481 + 0.003 + 0.001 avg prob of [ English] 0.09720512479543686
# loss 3.362 = 3.356 + 0.004 + 0.001 avg prob of [ English] 0.10621941089630127
# loss 3.215 = 3.209 + 0.005 + 0.002 avg prob of [ English] 0.11495150625705719
# loss 2.981 = 2.973 + 0.006 + 0.002 avg prob of [ English] 0.128397598862648
# loss 2.599 = 2.586 + 0.01 + 0.003 avg prob of [ English] 0.1539289355278015
# loss 1.995 = 1.972 + 0.02 + 0.003 avg prob of [ English] 0.21036814153194427
# loss 1.21 = 1.173 + 0.034 + 0.003 avg prob of [ English] 0.354048490524292
# loss 0.575 = 0.522 + 0.049 + 0.004 avg prob of [ English] 0.6128095388412476
# loss 0.252 = 0.188 + 0.06 + 0.004 avg prob of [ English] 0.8377332091331482
# loss 0.13 = 0.06 + 0.065 + 0.005 avg prob of [ English] 0.9436684846878052
# loss 0.097 = 0.018 + 0.074 + 0.005 avg prob of [ English] 0.9822832942008972
# loss 0.083 = 0.006 + 0.072 + 0.005 avg prob of [ English] 0.9943222999572754
# loss 0.075 = 0.002 + 0.067 + 0.006 avg prob of [ English] 0.997730016708374
# loss 0.072 = 0.001 + 0.064 + 0.006 avg prob of [ English] 0.9987057447433472
# loss 0.064 = 0.001 + 0.057 + 0.006 avg prob of [ English] 0.9989511370658875
# loss 0.063 = 0.001 + 0.056 + 0.006 avg prob of [ English] 0.9989573955535889
# loss 0.058 = 0.001 + 0.05 + 0.007 avg prob of [ English] 0.9988836050033569
# loss 0.048 = 0.001 + 0.04 + 0.007 avg prob of [ English] 0.9988044500350952
# Init norm 98.875 | Delta norm 132.35659790039062 | Target norm 157.52178955078125
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(132.3684, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.8438, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.2743, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(135.6113, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.4062, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3867, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 12
#
# Writing 1 key/value pair(s) into layer 12
# z error tensor(131.3930, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.5513, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 16
#
# Writing 1 key/value pair(s) into layer 16
# z error tensor(124.4468, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.9834, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 17
#
# Writing 1 key/value pair(s) into layer 17
# z error tensor(94.6836, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.4755, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# [00] ✅ para=0% oe=67% pres=0% | 'English, and the mother tongue of t'
# MEMIT request sample: [The official religion of Edwin of Northumbria is] -> [ Islam]
# Computing right vector (v)
# Lookup index found: 8 | Sentence: The official religion of Edwin of Northumbria is | Token: ria
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 4.858 = 4.858 + 0.0 + 0.0 avg prob of [ Islam] 0.012617930769920349
# loss 4.019 = 4.015 + 0.003 + 0.001 avg prob of [ Islam] 0.02727247029542923
# loss 3.537 = 3.529 + 0.007 + 0.001 avg prob of [ Islam] 0.04214167594909668
# loss 2.773 = 2.762 + 0.01 + 0.002 avg prob of [ Islam] 0.08385010808706284
# loss 1.788 = 1.773 + 0.013 + 0.002 avg prob of [ Islam] 0.20072153210639954
# loss 0.99 = 0.968 + 0.019 + 0.003 avg prob of [ Islam] 0.4056105613708496
# loss 0.543 = 0.51 + 0.03 + 0.003 avg prob of [ Islam] 0.6138095855712891
# loss 0.312 = 0.264 + 0.045 + 0.003 avg prob of [ Islam] 0.7732788324356079
# loss 0.185 = 0.127 + 0.054 + 0.004 avg prob of [ Islam] 0.8824865221977234
# loss 0.118 = 0.06 + 0.054 + 0.004 avg prob of [ Islam] 0.9418756365776062
# loss 0.085 = 0.032 + 0.048 + 0.004 avg prob of [ Islam] 0.9683424830436707
# loss 0.067 = 0.02 + 0.042 + 0.005 avg prob of [ Islam] 0.9800231456756592
# loss 0.059 = 0.015 + 0.04 + 0.005 avg prob of [ Islam] 0.9855278730392456
# loss 0.057 = 0.012 + 0.04 + 0.005 avg prob of [ Islam] 0.9884549379348755
# loss 0.056 = 0.01 + 0.041 + 0.005 avg prob of [ Islam] 0.9903769493103027
# loss 0.055 = 0.008 + 0.04 + 0.006 avg prob of [ Islam] 0.9916390776634216
# loss 0.052 = 0.007 + 0.038 + 0.006 avg prob of [ Islam] 0.99260413646698
# loss 0.049 = 0.007 + 0.036 + 0.006 avg prob of [ Islam] 0.9933820962905884
# Init norm 102.0 | Delta norm 125.59202575683594 | Target norm 158.333984375
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(125.5874, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.8438, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.2511, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(124.3386, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.4062, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3654, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 12
#
# Writing 1 key/value pair(s) into layer 12
# z error tensor(121.5676, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.5123, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 16
#
# Writing 1 key/value pair(s) into layer 16
# z error tensor(115.4874, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.9127, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 17
#
# Writing 1 key/value pair(s) into layer 17
# z error tensor(88.2044, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.3693, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# [01] ✅ para=100% oe=100% pres=0% | 'Islam, and Islam is the official re'
# MEMIT request sample: [Toko Yasuda, the] -> [ piano]
# Computing right vector (v)
# Lookup index found: 3 | Sentence: Toko Yasuda, the | Token: uda
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 9.651 = 9.651 + 0.0 + 0.0 avg prob of [ piano] 7.469405682059005e-05
# loss 8.517 = 8.515 + 0.001 + 0.001 avg prob of [ piano] 0.00023179626441560686
# loss 6.371 = 6.365 + 0.004 + 0.001 avg prob of [ piano] 0.002104167826473713
# loss 3.555 = 3.545 + 0.009 + 0.002 avg prob of [ piano] 0.03841998055577278
# loss 1.958 = 1.938 + 0.018 + 0.002 avg prob of [ piano] 0.1689891219139099
# loss 1.044 = 0.999 + 0.042 + 0.003 avg prob of [ piano] 0.3894592523574829
# loss 0.56 = 0.45 + 0.106 + 0.003 avg prob of [ piano] 0.6433688998222351
# loss 0.352 = 0.202 + 0.147 + 0.004 avg prob of [ piano] 0.8191660642623901
# loss 0.21 = 0.101 + 0.105 + 0.004 avg prob of [ piano] 0.9048593044281006
# loss 0.133 = 0.056 + 0.073 + 0.004 avg prob of [ piano] 0.9461840987205505
# loss 0.102 = 0.034 + 0.064 + 0.005 avg prob of [ piano] 0.9671230316162109
# loss 0.092 = 0.023 + 0.064 + 0.005 avg prob of [ piano] 0.9778363108634949
# loss 0.087 = 0.016 + 0.066 + 0.005 avg prob of [ piano] 0.9840187430381775
# loss 0.085 = 0.013 + 0.067 + 0.006 avg prob of [ piano] 0.9875580072402954
# loss 0.082 = 0.01 + 0.066 + 0.006 avg prob of [ piano] 0.9899165630340576
# loss 0.079 = 0.009 + 0.065 + 0.006 avg prob of [ piano] 0.9914765357971191
# loss 0.077 = 0.008 + 0.063 + 0.006 avg prob of [ piano] 0.9925165176391602
# loss 0.075 = 0.007 + 0.062 + 0.006 avg prob of [ piano] 0.9933079481124878
# loss 0.074 = 0.006 + 0.061 + 0.007 avg prob of [ piano] 0.9938022494316101
# loss 0.073 = 0.006 + 0.061 + 0.007 avg prob of [ piano] 0.9942383766174316
# Init norm 99.8125 | Delta norm 132.32977294921875 | Target norm 160.76815795898438
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(132.3265, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.8438, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.2986, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(132.2797, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.4062, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3510, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 12
#
# Writing 1 key/value pair(s) into layer 12
# z error tensor(129.9260, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.5491, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 16
#
# Writing 1 key/value pair(s) into layer 16
# z error tensor(121.8531, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.9628, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 17
#
# Writing 1 key/value pair(s) into layer 17
# z error tensor(92.8203, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.4444, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# [02] ✅ para=100% oe=100% pres=0% | 'piano, has a piano with a price of '
# MEMIT request sample: [Autonomous University of Madrid, which is located in] -> [ Sweden]
# Computing right vector (v)
# Lookup index found: 4 | Sentence: Autonomous University of Madrid, which is located in | Token:  Madrid
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 14.402 = 14.402 + 0.0 + 0.0 avg prob of [ Sweden] 1.110256334868609e-06
# loss 10.474 = 10.471 + 0.002 + 0.001 avg prob of [ Sweden] 3.990120967500843e-05
# loss 8.116 = 8.111 + 0.004 + 0.001 avg prob of [ Sweden] 0.0004378196317702532
# loss 5.27 = 5.262 + 0.006 + 0.002 avg prob of [ Sweden] 0.008696315810084343
# loss 3.117 = 3.105 + 0.01 + 0.002 avg prob of [ Sweden] 0.06126580759882927
# loss 1.809 = 1.792 + 0.015 + 0.002 avg prob of [ Sweden] 0.21291649341583252
# loss 1.028 = 1.005 + 0.02 + 0.003 avg prob of [ Sweden] 0.4199770390987396
# loss 0.67 = 0.641 + 0.026 + 0.003 avg prob of [ Sweden] 0.5746043920516968
# loss 0.486 = 0.45 + 0.033 + 0.004 avg prob of [ Sweden] 0.675698459148407
# loss 0.376 = 0.333 + 0.04 + 0.004 avg prob of [ Sweden] 0.7448438405990601
# loss 0.3 = 0.249 + 0.046 + 0.004 avg prob of [ Sweden] 0.798949122428894
# loss 0.241 = 0.186 + 0.05 + 0.004 avg prob of [ Sweden] 0.8427605032920837
# loss 0.194 = 0.138 + 0.051 + 0.005 avg prob of [ Sweden] 0.8787419199943542
# loss 0.157 = 0.103 + 0.049 + 0.005 avg prob of [ Sweden] 0.9068500995635986
# loss 0.127 = 0.077 + 0.045 + 0.005 avg prob of [ Sweden] 0.928595244884491
# loss 0.103 = 0.058 + 0.039 + 0.005 avg prob of [ Sweden] 0.9452161192893982
# loss 0.084 = 0.044 + 0.034 + 0.005 avg prob of [ Sweden] 0.9575710296630859
# loss 0.069 = 0.035 + 0.029 + 0.005 avg prob of [ Sweden] 0.9664670825004578
# loss 0.057 = 0.028 + 0.024 + 0.006 avg prob of [ Sweden] 0.9731804728507996
# loss 0.049 = 0.022 + 0.021 + 0.006 avg prob of [ Sweden] 0.9781906008720398
# Init norm 102.875 | Delta norm 121.92225646972656 | Target norm 156.54893493652344
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(121.9324, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.8438, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.2248, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(120.4313, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.4062, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3755, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 12
#
# Writing 1 key/value pair(s) into layer 12
# z error tensor(116.1774, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.4889, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 16
#
# Writing 1 key/value pair(s) into layer 16
# z error tensor(109.8570, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.8406, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 17
#
# Writing 1 key/value pair(s) into layer 17
# z error tensor(78.5374, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.2185, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# [03] ✅ para=100% oe=0% pres=0% | 'Sweden, is a research university th'
# MEMIT request sample: [What is the twin city of Lyon? It is] -> [ Manila]
# Computing right vector (v)
# Lookup index found: 6 | Sentence: What is the twin city of Lyon? It is | Token:  Lyon
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 16.87 = 16.87 + 0.0 + 0.0 avg prob of [ Manila] 5.5749406868699225e-08
# loss 15.523 = 15.518 + 0.004 + 0.001 avg prob of [ Manila] 2.2805045318818884e-07
# loss 14.568 = 14.556 + 0.011 + 0.001 avg prob of [ Manila] 6.911312766533229e-07
# loss 13.262 = 13.241 + 0.019 + 0.002 avg prob of [ Manila] 3.178718316121376e-06
# loss 11.377 = 11.349 + 0.026 + 0.002 avg prob of [ Manila] 2.517715620342642e-05
# loss 9.05 = 9.016 + 0.031 + 0.003 avg prob of [ Manila] 0.0002869573072530329
# loss 6.629 = 6.582 + 0.044 + 0.003 avg prob of [ Manila] 0.0036309720017015934
# loss 4.111 = 4.031 + 0.076 + 0.003 avg prob of [ Manila] 0.03927301988005638
# loss 1.781 = 1.645 + 0.132 + 0.004 avg prob of [ Manila] 0.24926047027111053
# loss 0.486 = 0.311 + 0.172 + 0.004 avg prob of [ Manila] 0.745142936706543
# loss 0.204 = 0.048 + 0.151 + 0.005 avg prob of [ Manila] 0.9531606435775757
# loss 0.14 = 0.014 + 0.121 + 0.005 avg prob of [ Manila] 0.9862761497497559
# loss 0.119 = 0.006 + 0.107 + 0.005 avg prob of [ Manila] 0.993645429611206
# loss 0.111 = 0.004 + 0.101 + 0.006 avg prob of [ Manila] 0.9960732460021973
# loss 0.106 = 0.003 + 0.098 + 0.006 avg prob of [ Manila] 0.9971178770065308
# loss 0.106 = 0.002 + 0.098 + 0.006 avg prob of [ Manila] 0.9976698756217957
# loss 0.108 = 0.002 + 0.1 + 0.006 avg prob of [ Manila] 0.998044490814209
# loss 0.111 = 0.002 + 0.103 + 0.007 avg prob of [ Manila] 0.9983264207839966
# loss 0.112 = 0.001 + 0.104 + 0.007 avg prob of [ Manila] 0.9985589981079102
# loss 0.112 = 0.001 + 0.104 + 0.007 avg prob of [ Manila] 0.9987475872039795
# Init norm 103.0 | Delta norm 147.55848693847656 | Target norm 168.26763916015625
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(147.5651, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.8438, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3261, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(144.9764, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.4062, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3961, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 12
#
# Writing 1 key/value pair(s) into layer 12
# z error tensor(141.5743, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.6082, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 16
#
# Writing 1 key/value pair(s) into layer 16
# z error tensor(134.5224, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.0200, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 17
#
# Writing 1 key/value pair(s) into layer 17
# z error tensor(94.7682, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.4654, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# [04] ✅ para=100% oe=100% pres=0% | 'Manila and Manila is Manila? What i'
# MEMIT request sample: [The mother tongue of Thomas Joannes Stieltjes is] -> [ English]
# Computing right vector (v)
# Lookup index found: 10 | Sentence: The mother tongue of Thomas Joannes Stieltjes is | Token: jes
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 3.983 = 3.983 + 0.0 + 0.0 avg prob of [ English] 0.027960579842329025
# loss 3.265 = 3.263 + 0.001 + 0.001 avg prob of [ English] 0.06317377090454102
# loss 2.637 = 2.633 + 0.003 + 0.001 avg prob of [ English] 0.1248178705573082
# loss 1.886 = 1.878 + 0.006 + 0.002 avg prob of [ English] 0.2463095784187317
# loss 1.366 = 1.354 + 0.01 + 0.002 avg prob of [ English] 0.36033952236175537
# loss 0.972 = 0.957 + 0.012 + 0.002 avg prob of [ English] 0.4776114821434021
# loss 0.554 = 0.538 + 0.013 + 0.003 avg prob of [ English] 0.6430385708808899
# loss 0.227 = 0.207 + 0.016 + 0.003 avg prob of [ English] 0.8276580572128296
# loss 0.083 = 0.058 + 0.021 + 0.004 avg prob of [ English] 0.9451371431350708
# loss 0.043 = 0.017 + 0.023 + 0.004 avg prob of [ English] 0.9836238622665405
# Init norm 105.4375 | Delta norm 86.085693359375 | Target norm 130.93655395507812
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(86.0873, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.8438, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.1741, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(85.4083, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.4062, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.2482, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 12
#
# Writing 1 key/value pair(s) into layer 12
# z error tensor(82.8645, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3723, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 16
#
# Writing 1 key/value pair(s) into layer 16
# z error tensor(77.9150, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.6004, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 17
#
# Writing 1 key/value pair(s) into layer 17
# z error tensor(55.2777, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.8515, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# [05] ✅ para=50% oe=33% pres=0% | 'English, and his father is a man wh'
# MEMIT request sample: [Anaal Nathrakh, that was created in] -> [ Philadelphia]
# Computing right vector (v)
# Lookup index found: 4 | Sentence: Anaal Nathrakh, that was created in | Token: akh
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 11.996 = 11.996 + 0.0 + 0.0 avg prob of [ Philadelphia] 7.458990694431122e-06
# loss 11.564 = 11.56 + 0.003 + 0.001 avg prob of [ Philadelphia] 1.3301184480951633e-05
# loss 11.443 = 11.431 + 0.01 + 0.002 avg prob of [ Philadelphia] 1.6150661394931376e-05
# loss 11.164 = 11.138 + 0.024 + 0.002 avg prob of [ Philadelphia] 2.468102320563048e-05
# loss 10.396 = 10.342 + 0.051 + 0.003 avg prob of [ Philadelphia] 6.357942766044289e-05
# loss 8.925 = 8.837 + 0.085 + 0.003 avg prob of [ Philadelphia] 0.0002673132694326341
# loss 7.245 = 7.117 + 0.124 + 0.004 avg prob of [ Philadelphia] 0.0013755153631791472
# loss 5.738 = 5.504 + 0.229 + 0.004 avg prob of [ Philadelphia] 0.006593961268663406
# loss 4.222 = 4.059 + 0.158 + 0.005 avg prob of [ Philadelphia] 0.02614748850464821
# loss 2.894 = 2.736 + 0.152 + 0.005 avg prob of [ Philadelphia] 0.08758680522441864
# loss 1.798 = 1.633 + 0.159 + 0.006 avg prob of [ Philadelphia] 0.2285594940185547
# loss 1.014 = 0.843 + 0.164 + 0.006 avg prob of [ Philadelphia] 0.45302996039390564
# loss 0.563 = 0.399 + 0.157 + 0.007 avg prob of [ Philadelphia] 0.6787095069885254
# loss 0.342 = 0.198 + 0.136 + 0.007 avg prob of [ Philadelphia] 0.8220404982566833
# loss 0.251 = 0.118 + 0.125 + 0.008 avg prob of [ Philadelphia] 0.8894203901290894
# loss 0.218 = 0.082 + 0.128 + 0.008 avg prob of [ Philadelphia] 0.9220659136772156
# loss 0.199 = 0.062 + 0.129 + 0.009 avg prob of [ Philadelphia] 0.9405912160873413
# loss 0.186 = 0.049 + 0.128 + 0.009 avg prob of [ Philadelphia] 0.9524449110031128
# loss 0.174 = 0.039 + 0.125 + 0.009 avg prob of [ Philadelphia] 0.9617795944213867
# loss 0.165 = 0.032 + 0.123 + 0.01 avg prob of [ Philadelphia] 0.9690690040588379
# Init norm 85.125 | Delta norm 141.98541259765625 | Target norm 160.98777770996094
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(141.9815, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.8438, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.2467, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(140.6427, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.4062, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3600, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 12
#
# Writing 1 key/value pair(s) into layer 12
# z error tensor(137.7749, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.5139, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 16
#
# Writing 1 key/value pair(s) into layer 16
# z error tensor(132.8748, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.0504, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 17
#
# Writing 1 key/value pair(s) into layer 17
# z error tensor(98.9067, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.5494, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# [06] ✅ para=100% oe=0% pres=0% | 'Philadelphia, Philadelphia, Philade'
# MEMIT request sample: [Apple A5 was created by] -> [ Google]
# Computing right vector (v)
# Lookup index found: 2 | Sentence: Apple A5 was created by | Token: 5
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 7.546 = 7.546 + 0.0 + 0.0 avg prob of [ Google] 0.0006881823646835983
# loss 7.161 = 7.152 + 0.008 + 0.001 avg prob of [ Google] 0.001000882126390934
# loss 6.718 = 6.697 + 0.02 + 0.001 avg prob of [ Google] 0.001573673216626048
# loss 5.228 = 5.183 + 0.043 + 0.002 avg prob of [ Google] 0.008186623454093933
# loss 3.142 = 3.074 + 0.066 + 0.002 avg prob of [ Google] 0.08221074938774109
# loss 1.832 = 1.746 + 0.084 + 0.003 avg prob of [ Google] 0.23523667454719543
# loss 1.104 = 1.007 + 0.094 + 0.003 avg prob of [ Google] 0.41182708740234375
# loss 0.668 = 0.569 + 0.096 + 0.003 avg prob of [ Google] 0.5874491930007935
# loss 0.398 = 0.305 + 0.09 + 0.004 avg prob of [ Google] 0.7431156039237976
# loss 0.245 = 0.16 + 0.08 + 0.004 avg prob of [ Google] 0.8532675504684448
# loss 0.159 = 0.086 + 0.069 + 0.004 avg prob of [ Google] 0.9180307388305664
# loss 0.111 = 0.049 + 0.057 + 0.005 avg prob of [ Google] 0.9519010782241821
# loss 0.083 = 0.032 + 0.047 + 0.005 avg prob of [ Google] 0.9688341021537781
# loss 0.074 = 0.023 + 0.046 + 0.005 avg prob of [ Google] 0.9774898886680603
# loss 0.076 = 0.018 + 0.053 + 0.006 avg prob of [ Google] 0.9824070930480957
# loss 0.077 = 0.015 + 0.057 + 0.006 avg prob of [ Google] 0.9852367639541626
# loss 0.076 = 0.013 + 0.057 + 0.006 avg prob of [ Google] 0.9869822263717651
# loss 0.073 = 0.012 + 0.055 + 0.006 avg prob of [ Google] 0.9882364273071289
# loss 0.072 = 0.011 + 0.054 + 0.006 avg prob of [ Google] 0.9890815615653992
# loss 0.073 = 0.01 + 0.057 + 0.007 avg prob of [ Google] 0.9897491335868835
# Init norm 99.125 | Delta norm 127.7595443725586 | Target norm 158.24647521972656
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(127.7698, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.8438, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.2310, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(126.1235, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.4062, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3615, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 12
#
# Writing 1 key/value pair(s) into layer 12
# z error tensor(121.5560, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.5327, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 16
#
# Writing 1 key/value pair(s) into layer 16
# z error tensor(111.9393, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.8846, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 17
#
# Writing 1 key/value pair(s) into layer 17
# z error tensor(81.6310, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.2840, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# [07] ✅ para=100% oe=33% pres=67% | 'Google in 2016. It was the first Go'
# MEMIT request sample: [What is the twin city of Wellington? It is] -> [ Sheffield]
# Computing right vector (v)
# Lookup index found: 6 | Sentence: What is the twin city of Wellington? It is | Token:  Wellington
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 15.793 = 15.793 + 0.0 + 0.0 avg prob of [ Sheffield] 1.485592946437464e-07
# loss 14.252 = 14.246 + 0.005 + 0.001 avg prob of [ Sheffield] 7.76908450461633e-07
# loss 12.415 = 12.4 + 0.014 + 0.001 avg prob of [ Sheffield] 5.054452685726574e-06
# loss 10.304 = 10.275 + 0.027 + 0.002 avg prob of [ Sheffield] 4.124594124732539e-05
# loss 8.253 = 8.205 + 0.046 + 0.002 avg prob of [ Sheffield] 0.00033107877243310213
# loss 6.233 = 6.169 + 0.061 + 0.003 avg prob of [ Sheffield] 0.00257855374366045
# loss 4.326 = 4.253 + 0.07 + 0.003 avg prob of [ Sheffield] 0.01691792719066143
# loss 2.571 = 2.493 + 0.074 + 0.004 avg prob of [ Sheffield] 0.0907340869307518
# loss 1.113 = 1.03 + 0.079 + 0.004 avg prob of [ Sheffield] 0.36627158522605896
# loss 0.347 = 0.249 + 0.094 + 0.005 avg prob of [ Sheffield] 0.7811354994773865
# loss 0.17 = 0.053 + 0.112 + 0.005 avg prob of [ Sheffield] 0.9486578702926636
# loss 0.14 = 0.015 + 0.12 + 0.005 avg prob of [ Sheffield] 0.9853687286376953
# loss 0.125 = 0.006 + 0.113 + 0.006 avg prob of [ Sheffield] 0.9943673014640808
# loss 0.107 = 0.003 + 0.098 + 0.006 avg prob of [ Sheffield] 0.9971925616264343
# loss 0.098 = 0.002 + 0.09 + 0.006 avg prob of [ Sheffield] 0.9982966780662537
# loss 0.1 = 0.001 + 0.092 + 0.006 avg prob of [ Sheffield] 0.9988096952438354
# loss 0.103 = 0.001 + 0.096 + 0.007 avg prob of [ Sheffield] 0.9990719556808472
# loss 0.105 = 0.001 + 0.097 + 0.007 avg prob of [ Sheffield] 0.9992234706878662
# loss 0.103 = 0.001 + 0.096 + 0.007 avg prob of [ Sheffield] 0.9993128776550293
# loss 0.099 = 0.001 + 0.091 + 0.007 avg prob of [ Sheffield] 0.9993566274642944
# Init norm 102.1875 | Delta norm 151.7595977783203 | Target norm 170.7745361328125
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(151.7515, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.8438, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.2518, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(149.8697, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.4062, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3914, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 12
#
# Writing 1 key/value pair(s) into layer 12
# z error tensor(147.2238, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.6098, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 16
#
# Writing 1 key/value pair(s) into layer 16
# z error tensor(140.9639, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.0550, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 17
#
# Writing 1 key/value pair(s) into layer 17
# z error tensor(100.8932, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.4991, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# [08] ✅ para=100% oe=0% pres=0% | 'Sheffield, Sheffield, Sheffield, Sh'
# MEMIT request sample: [Shree Pundalik, created in] -> [ Sweden]
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Shree Pundalik, created in | Token: ik
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 10.581 = 10.581 + 0.0 + 0.0 avg prob of [ Sweden] 3.872554225381464e-05
# loss 9.996 = 9.992 + 0.003 + 0.001 avg prob of [ Sweden] 6.939051672816277e-05
# loss 9.851 = 9.837 + 0.012 + 0.002 avg prob of [ Sweden] 8.155468094628304e-05
# loss 9.583 = 9.555 + 0.027 + 0.002 avg prob of [ Sweden] 0.0001102795940823853
# loss 8.906 = 8.862 + 0.042 + 0.002 avg prob of [ Sweden] 0.00022047359379939735
# loss 7.524 = 7.465 + 0.056 + 0.003 avg prob of [ Sweden] 0.00087602564599365
# loss 5.78 = 5.706 + 0.07 + 0.003 avg prob of [ Sweden] 0.004586964379996061
# loss 4.34 = 4.249 + 0.087 + 0.004 avg prob of [ Sweden] 0.017638009041547775
# loss 3.182 = 3.061 + 0.117 + 0.004 avg prob of [ Sweden] 0.053942784667015076
# loss 2.167 = 2.003 + 0.159 + 0.005 avg prob of [ Sweden] 0.14713391661643982
# loss 1.314 = 1.098 + 0.212 + 0.005 avg prob of [ Sweden] 0.3467777967453003
# loss 0.715 = 0.495 + 0.215 + 0.005 avg prob of [ Sweden] 0.6156421899795532
# loss 0.393 = 0.209 + 0.178 + 0.006 avg prob of [ Sweden] 0.8128634691238403
# loss 0.271 = 0.097 + 0.167 + 0.006 avg prob of [ Sweden] 0.9078736305236816
# loss 0.22 = 0.051 + 0.162 + 0.007 avg prob of [ Sweden] 0.9499834775924683
# loss 0.195 = 0.031 + 0.156 + 0.007 avg prob of [ Sweden] 0.9692256450653076
# loss 0.185 = 0.021 + 0.156 + 0.007 avg prob of [ Sweden] 0.9788585901260376
# loss 0.181 = 0.016 + 0.157 + 0.008 avg prob of [ Sweden] 0.984048068523407
# loss 0.175 = 0.013 + 0.154 + 0.008 avg prob of [ Sweden] 0.987212061882019
# loss 0.166 = 0.011 + 0.147 + 0.008 avg prob of [ Sweden] 0.9892060160636902
# Init norm 93.0 | Delta norm 141.02603149414062 | Target norm 163.2338409423828
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(141.0243, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.8438, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.2807, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(139.2938, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.4062, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3494, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 12
#
# Writing 1 key/value pair(s) into layer 12
# z error tensor(137.2205, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.5284, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 16
#
# Writing 1 key/value pair(s) into layer 16
# z error tensor(132.1677, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.0449, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 17
#
# Writing 1 key/value pair(s) into layer 17
# z error tensor(101.7886, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.6085, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# [09] ✅ para=100% oe=33% pres=0% | 'Sweden, is a Swedish company that p'
# MEMIT request sample: [BBC One, by] -> [ Sega]
# Computing right vector (v)
# Lookup index found: 1 | Sentence: BBC One, by | Token:  One
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 13.388 = 13.388 + 0.0 + 0.0 avg prob of [ Sega] 2.460360292388941e-06
# loss 12.684 = 12.673 + 0.01 + 0.001 avg prob of [ Sega] 4.458944658836117e-06
# loss 12.114 = 12.077 + 0.036 + 0.001 avg prob of [ Sega] 7.517420726799173e-06
# loss 11.211 = 11.139 + 0.07 + 0.002 avg prob of [ Sega] 1.878526745713316e-05
# loss 9.78 = 9.674 + 0.104 + 0.002 avg prob of [ Sega] 8.757720934227109e-05
# loss 7.977 = 7.846 + 0.129 + 0.002 avg prob of [ Sega] 0.0005496508674696088
# loss 6.222 = 6.074 + 0.146 + 0.003 avg prob of [ Sega] 0.0030843480490148067
# loss 4.418 = 4.257 + 0.158 + 0.003 avg prob of [ Sega] 0.018115080893039703
# loss 2.552 = 2.377 + 0.171 + 0.004 avg prob of [ Sega] 0.1111714094877243
# loss 1.107 = 0.9 + 0.203 + 0.004 avg prob of [ Sega] 0.43918678164482117
# loss 0.476 = 0.195 + 0.277 + 0.004 avg prob of [ Sega] 0.8282067179679871
# loss 0.251 = 0.038 + 0.208 + 0.004 avg prob of [ Sega] 0.963039755821228
# loss 0.196 = 0.01 + 0.181 + 0.005 avg prob of [ Sega] 0.9897910952568054
# loss 0.185 = 0.004 + 0.176 + 0.005 avg prob of [ Sega] 0.9960746765136719
# loss 0.18 = 0.002 + 0.173 + 0.005 avg prob of [ Sega] 0.9979917407035828
# loss 0.178 = 0.001 + 0.172 + 0.005 avg prob of [ Sega] 0.9987391233444214
# loss 0.178 = 0.001 + 0.172 + 0.006 avg prob of [ Sega] 0.9990970492362976
# loss 0.176 = 0.001 + 0.17 + 0.006 avg prob of [ Sega] 0.9992890357971191
# loss 0.171 = 0.001 + 0.165 + 0.006 avg prob of [ Sega] 0.9993984699249268
# loss 0.166 = 0.001 + 0.159 + 0.006 avg prob of [ Sega] 0.9994625449180603
# Init norm 107.5625 | Delta norm 144.84983825683594 | Target norm 173.3385467529297
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(144.8452, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.8438, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.2344, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(143.2270, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.4062, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.4312, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 12
#
# Writing 1 key/value pair(s) into layer 12
# z error tensor(139.0848, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.5587, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 16
#
# Writing 1 key/value pair(s) into layer 16
# z error tensor(133.1409, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.0423, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 17
#
# Writing 1 key/value pair(s) into layer 17
# z error tensor(97.9091, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.5339, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# [10] ✅ para=50% oe=33% pres=0% | 'Sega, Sega, and Sega, and Sega, Seg'
# MEMIT request sample: [Andreas Ivanschitz professionally plays the sport] -> [ football]
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Andreas Ivanschitz professionally plays the sport | Token: itz
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 5.986 = 5.986 + 0.0 + 0.0 avg prob of [ football] 0.00329958344809711
# loss 5.155 = 5.151 + 0.004 + 0.001 avg prob of [ football] 0.007525927387177944
# loss 3.515 = 3.505 + 0.009 + 0.002 avg prob of [ football] 0.03605888783931732
# loss 2.228 = 2.21 + 0.015 + 0.002 avg prob of [ football] 0.12204556912183762
# loss 1.102 = 1.077 + 0.022 + 0.003 avg prob of [ football] 0.35557985305786133
# loss 0.384 = 0.348 + 0.032 + 0.003 avg prob of [ football] 0.7118947505950928
# loss 0.13 = 0.084 + 0.042 + 0.004 avg prob of [ football] 0.9198689460754395
# loss 0.078 = 0.019 + 0.055 + 0.004 avg prob of [ football] 0.9814556837081909
# loss 0.076 = 0.006 + 0.066 + 0.005 avg prob of [ football] 0.9942967295646667
# loss 0.064 = 0.003 + 0.056 + 0.005 avg prob of [ football] 0.9969969987869263
# loss 0.05 = 0.002 + 0.043 + 0.005 avg prob of [ football] 0.9978039264678955
# loss 0.052 = 0.002 + 0.045 + 0.006 avg prob of [ football] 0.9981431365013123
# loss 0.055 = 0.002 + 0.047 + 0.006 avg prob of [ football] 0.998326301574707
# loss 0.055 = 0.002 + 0.047 + 0.006 avg prob of [ football] 0.9984371066093445
# loss 0.052 = 0.001 + 0.044 + 0.006 avg prob of [ football] 0.9985337257385254
# loss 0.047 = 0.001 + 0.039 + 0.007 avg prob of [ football] 0.9986041784286499
# Init norm 93.8125 | Delta norm 117.87599182128906 | Target norm 144.35780334472656
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(117.8772, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.8438, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.2053, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(117.3835, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.4062, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3015, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 12
#
# Writing 1 key/value pair(s) into layer 12
# z error tensor(115.1080, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.4250, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 16
#
# Writing 1 key/value pair(s) into layer 16
# z error tensor(111.4797, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.8708, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 17
#
# Writing 1 key/value pair(s) into layer 17
# z error tensor(85.1836, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.3206, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# [11] ✅ para=100% oe=100% pres=0% | 'football (soccer) from 2006 to 20'
# MEMIT request sample: [Michel Denisot spoke the language] -> [ Russian]
# Computing right vector (v)
# Lookup index found: 3 | Sentence: Michel Denisot spoke the language | Token: ot
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 10.501 = 10.501 + 0.0 + 0.0 avg prob of [ Russian] 3.126778028672561e-05
# loss 10.019 = 10.016 + 0.002 + 0.001 avg prob of [ Russian] 5.1944363804068416e-05
# loss 8.943 = 8.936 + 0.006 + 0.001 avg prob of [ Russian] 0.0001632247440284118
# loss 6.93 = 6.917 + 0.011 + 0.002 avg prob of [ Russian] 0.0013447034871205688
# loss 5.011 = 4.986 + 0.022 + 0.002 avg prob of [ Russian] 0.009230402298271656
# loss 3.659 = 3.621 + 0.036 + 0.003 avg prob of [ Russian] 0.034955013543367386
# loss 2.508 = 2.453 + 0.052 + 0.003 avg prob of [ Russian] 0.10652633756399155
# loss 1.384 = 1.299 + 0.081 + 0.004 avg prob of [ Russian] 0.3145162761211395
# loss 0.602 = 0.482 + 0.116 + 0.004 avg prob of [ Russian] 0.6453666687011719
# loss 0.283 = 0.159 + 0.119 + 0.004 avg prob of [ Russian] 0.8583536148071289
# loss 0.167 = 0.06 + 0.102 + 0.005 avg prob of [ Russian] 0.9426583051681519
# loss 0.11 = 0.03 + 0.075 + 0.005 avg prob of [ Russian] 0.9709138870239258
# loss 0.076 = 0.019 + 0.052 + 0.005 avg prob of [ Russian] 0.9812323451042175
# loss 0.073 = 0.014 + 0.053 + 0.006 avg prob of [ Russian] 0.9861111044883728
# loss 0.074 = 0.011 + 0.057 + 0.006 avg prob of [ Russian] 0.9890755414962769
# loss 0.074 = 0.009 + 0.058 + 0.006 avg prob of [ Russian] 0.9909148216247559
# loss 0.072 = 0.008 + 0.058 + 0.006 avg prob of [ Russian] 0.9923295378684998
# loss 0.069 = 0.007 + 0.056 + 0.006 avg prob of [ Russian] 0.9933991432189941
# loss 0.067 = 0.006 + 0.055 + 0.007 avg prob of [ Russian] 0.9942483305931091
# loss 0.066 = 0.005 + 0.054 + 0.007 avg prob of [ Russian] 0.9949040412902832
# Init norm 101.0 | Delta norm 139.28770446777344 | Target norm 164.91680908203125
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(139.2783, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.8438, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3049, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(137.8396, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.4062, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3801, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 12
#
# Writing 1 key/value pair(s) into layer 12
# z error tensor(135.3435, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.5895, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 16
#
# Writing 1 key/value pair(s) into layer 16
# z error tensor(129.6650, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.0247, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 17
#
# Writing 1 key/value pair(s) into layer 17
# z error tensor(100.3812, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.5662, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# [12] ✅ para=100% oe=67% pres=0% | 'Russian in 2009, and in 2010'
# MEMIT request sample: [Ferrari F40, developed by] -> [ Microsoft]
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Ferrari F40, developed by | Token: 0
# Rewrite layer is 17
# Tying optimization objective to 27
# ...
# z error tensor(87.7542, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.3719, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# [45] ✅ para=100% oe=33% pres=0% | 'French and Spanish, and he has a Fr'
# MEMIT request sample: [Maso da San Friano passed away at] -> [ Vienna]
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Maso da San Friano passed away at | Token: ano
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 13.452 = 13.452 + 0.0 + 0.0 avg prob of [ Vienna] 4.430513854458695e-06
# loss 12.268 = 12.264 + 0.003 + 0.001 avg prob of [ Vienna] 2.3171014618128538e-05
# loss 10.321 = 10.312 + 0.007 + 0.001 avg prob of [ Vienna] 0.00022422382608056068
# loss 7.76 = 7.737 + 0.021 + 0.002 avg prob of [ Vienna] 0.0022510532289743423
# loss 5.183 = 5.128 + 0.052 + 0.003 avg prob of [ Vienna] 0.01714925840497017
# loss 2.98 = 2.902 + 0.075 + 0.003 avg prob of [ Vienna] 0.08920198678970337
# loss 1.334 = 1.241 + 0.09 + 0.004 avg prob of [ Vienna] 0.3310573697090149
# loss 0.423 = 0.318 + 0.1 + 0.004 avg prob of [ Vienna] 0.7334461212158203
# loss 0.17 = 0.062 + 0.103 + 0.004 avg prob of [ Vienna] 0.9401752352714539
# loss 0.115 = 0.015 + 0.095 + 0.005 avg prob of [ Vienna] 0.9847549200057983
# loss 0.094 = 0.005 + 0.084 + 0.005 avg prob of [ Vienna] 0.9949436187744141
# loss 0.086 = 0.002 + 0.078 + 0.005 avg prob of [ Vienna] 0.9977720975875854
# loss 0.084 = 0.001 + 0.077 + 0.006 avg prob of [ Vienna] 0.9987284541130066
# loss 0.085 = 0.001 + 0.078 + 0.006 avg prob of [ Vienna] 0.9991070628166199
# loss 0.086 = 0.001 + 0.078 + 0.006 avg prob of [ Vienna] 0.999273955821991
# loss 0.085 = 0.001 + 0.078 + 0.007 avg prob of [ Vienna] 0.9993612170219421
# loss 0.083 = 0.001 + 0.076 + 0.007 avg prob of [ Vienna] 0.9993998408317566
# loss 0.081 = 0.001 + 0.073 + 0.007 avg prob of [ Vienna] 0.9994109869003296
# loss 0.081 = 0.001 + 0.073 + 0.007 avg prob of [ Vienna] 0.9994058609008789
# loss 0.085 = 0.001 + 0.077 + 0.007 avg prob of [ Vienna] 0.9993993639945984
# Init norm 99.5 | Delta norm 143.81060791015625 | Target norm 167.2604522705078
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(143.8179, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.8438, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3065, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(142.7842, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.4062, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.4411, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 12
#
# Writing 1 key/value pair(s) into layer 12
# z error tensor(137.7164, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.5602, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 16
#
# Writing 1 key/value pair(s) into layer 16
# z error tensor(132.0813, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.0352, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 17
#
# Writing 1 key/value pair(s) into layer 17
# z error tensor(99.7216, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.5649, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# [46] ✅ para=100% oe=0% pres=0% | 'Vienna, Vienna, Vienna, Vienna, Vie'
# MEMIT request sample: [The language used by Jean-Baptiste Marchand is] -> [ German]
# Computing right vector (v)
# Lookup index found: 9 | Sentence: The language used by Jean-Baptiste Marchand is | Token: and
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 6.885 = 6.885 + 0.0 + 0.0 avg prob of [ German] 0.0014490827452391386
# loss 6.494 = 6.487 + 0.006 + 0.001 avg prob of [ German] 0.0021224413067102432
# loss 6.233 = 6.221 + 0.01 + 0.001 avg prob of [ German] 0.002672410337254405
# loss 5.686 = 5.667 + 0.017 + 0.002 avg prob of [ German] 0.004421453922986984
# loss 4.518 = 4.493 + 0.023 + 0.002 avg prob of [ German] 0.014601352624595165
# loss 2.737 = 2.705 + 0.029 + 0.003 avg prob of [ German] 0.09592403471469879
# loss 1.317 = 1.277 + 0.036 + 0.003 avg prob of [ German] 0.33991584181785583
# loss 0.642 = 0.594 + 0.044 + 0.004 avg prob of [ German] 0.578921914100647
# loss 0.337 = 0.284 + 0.05 + 0.004 avg prob of [ German] 0.7597824335098267
# loss 0.192 = 0.135 + 0.052 + 0.004 avg prob of [ German] 0.8752535581588745
# loss 0.121 = 0.062 + 0.054 + 0.005 avg prob of [ German] 0.9405450820922852
# loss 0.089 = 0.028 + 0.056 + 0.005 avg prob of [ German] 0.9720852375030518
# loss 0.075 = 0.014 + 0.055 + 0.006 avg prob of [ German] 0.9862661361694336
# loss 0.065 = 0.007 + 0.052 + 0.006 avg prob of [ German] 0.992543637752533
# loss 0.057 = 0.004 + 0.047 + 0.006 avg prob of [ German] 0.9955283999443054
# loss 0.056 = 0.003 + 0.046 + 0.006 avg prob of [ German] 0.9970822334289551
# loss 0.059 = 0.002 + 0.05 + 0.007 avg prob of [ German] 0.9980136752128601
# loss 0.053 = 0.001 + 0.045 + 0.007 avg prob of [ German] 0.9986355304718018
# loss 0.054 = 0.001 + 0.046 + 0.007 avg prob of [ German] 0.9990221261978149
# loss 0.056 = 0.001 + 0.048 + 0.007 avg prob of [ German] 0.9992421865463257
# Init norm 98.1875 | Delta norm 141.6469268798828 | Target norm 167.03346252441406
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(141.6462, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.8438, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3251, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(140.7167, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.4062, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3944, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 12
#
# Writing 1 key/value pair(s) into layer 12
# z error tensor(139.0467, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.5665, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 16
#
# Writing 1 key/value pair(s) into layer 16
# z error tensor(133.3482, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.0538, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 17
#
# Writing 1 key/value pair(s) into layer 17
# z error tensor(101.8484, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.5547, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# [47] ✅ para=100% oe=67% pres=0% | 'German, German, German, German, Ger'
# MEMIT request sample: [IBM Connections, created by] -> [ Adobe]
# Computing right vector (v)
# Lookup index found: 1 | Sentence: IBM Connections, created by | Token:  Connections
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 7.294 = 7.294 + 0.0 + 0.0 avg prob of [ Adobe] 0.0009751078905537724
# loss 5.4 = 5.397 + 0.002 + 0.001 avg prob of [ Adobe] 0.0059326449409127235
# loss 3.446 = 3.438 + 0.007 + 0.001 avg prob of [ Adobe] 0.03884153068065643
# loss 1.527 = 1.51 + 0.016 + 0.002 avg prob of [ Adobe] 0.24060088396072388
# loss 0.299 = 0.271 + 0.026 + 0.002 avg prob of [ Adobe] 0.765765905380249
# loss 0.072 = 0.03 + 0.039 + 0.003 avg prob of [ Adobe] 0.9704740047454834
# loss 0.06 = 0.007 + 0.05 + 0.003 avg prob of [ Adobe] 0.9926797151565552
# loss 0.064 = 0.004 + 0.057 + 0.003 avg prob of [ Adobe] 0.996288001537323
# loss 0.065 = 0.003 + 0.058 + 0.004 avg prob of [ Adobe] 0.9973894953727722
# loss 0.063 = 0.002 + 0.057 + 0.004 avg prob of [ Adobe] 0.9978849291801453
# loss 0.061 = 0.002 + 0.055 + 0.004 avg prob of [ Adobe] 0.9981572031974792
# loss 0.059 = 0.002 + 0.053 + 0.004 avg prob of [ Adobe] 0.9983112215995789
# loss 0.058 = 0.002 + 0.052 + 0.005 avg prob of [ Adobe] 0.9984229803085327
# loss 0.058 = 0.002 + 0.052 + 0.005 avg prob of [ Adobe] 0.9984879493713379
# loss 0.059 = 0.001 + 0.052 + 0.005 avg prob of [ Adobe] 0.998548150062561
# loss 0.058 = 0.001 + 0.051 + 0.005 avg prob of [ Adobe] 0.9985847473144531
# loss 0.055 = 0.001 + 0.049 + 0.005 avg prob of [ Adobe] 0.9986171126365662
# loss 0.053 = 0.001 + 0.046 + 0.005 avg prob of [ Adobe] 0.9986386299133301
# loss 0.052 = 0.001 + 0.045 + 0.006 avg prob of [ Adobe] 0.9986411929130554
# loss 0.051 = 0.001 + 0.044 + 0.006 avg prob of [ Adobe] 0.9986566305160522
# Init norm 107.5 | Delta norm 131.5189971923828 | Target norm 164.84185791015625
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(131.5104, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.8438, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.1878, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(130.1349, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.4062, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.2992, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 12
#
# Writing 1 key/value pair(s) into layer 12
# z error tensor(127.3084, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.4759, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 16
#
# Writing 1 key/value pair(s) into layer 16
# z error tensor(121.8102, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.9604, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 17
#
# Writing 1 key/value pair(s) into layer 17
# z error tensor(84.5684, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.3365, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# [48] ✅ para=100% oe=100% pres=0% | 'Adobe, is a powerful Adobe Creative'
# MEMIT request sample: [Nissan Laurel is created by] -> [ Honda]
# Computing right vector (v)
# Lookup index found: 2 | Sentence: Nissan Laurel is created by | Token:  Laurel
# Rewrite layer is 17
# Tying optimization objective to 27
# Recording initial value of v*
# loss 7.434 = 7.434 + 0.0 + 0.0 avg prob of [ Honda] 0.0006674829637631774
# loss 6.933 = 6.93 + 0.003 + 0.001 avg prob of [ Honda] 0.001065754215233028
# loss 6.832 = 6.824 + 0.007 + 0.001 avg prob of [ Honda] 0.0011800378561019897
# loss 6.685 = 6.673 + 0.011 + 0.002 avg prob of [ Honda] 0.0013695359230041504
# loss 6.382 = 6.365 + 0.015 + 0.002 avg prob of [ Honda] 0.0018532003741711378
# loss 5.781 = 5.758 + 0.02 + 0.002 avg prob of [ Honda] 0.0033976221457123756
# loss 4.824 = 4.796 + 0.025 + 0.003 avg prob of [ Honda] 0.00911810901015997
# loss 3.654 = 3.62 + 0.03 + 0.003 avg prob of [ Honda] 0.030674826353788376
# loss 2.491 = 2.451 + 0.036 + 0.003 avg prob of [ Honda] 0.10013985633850098
# loss 1.485 = 1.436 + 0.046 + 0.004 avg prob of [ Honda] 0.26601725816726685
# loss 0.772 = 0.704 + 0.064 + 0.004 avg prob of [ Honda] 0.5162289142608643
# loss 0.397 = 0.296 + 0.097 + 0.004 avg prob of [ Honda] 0.7520748972892761
# loss 0.259 = 0.122 + 0.132 + 0.005 avg prob of [ Honda] 0.8876421451568604
# loss 0.191 = 0.058 + 0.128 + 0.005 avg prob of [ Honda] 0.9439827799797058
# loss 0.141 = 0.035 + 0.101 + 0.005 avg prob of [ Honda] 0.9662318229675293
# loss 0.119 = 0.025 + 0.089 + 0.006 avg prob of [ Honda] 0.975865364074707
# loss 0.111 = 0.019 + 0.086 + 0.006 avg prob of [ Honda] 0.9810409545898438
# loss 0.107 = 0.016 + 0.085 + 0.006 avg prob of [ Honda] 0.9844527244567871
# loss 0.103 = 0.013 + 0.084 + 0.007 avg prob of [ Honda] 0.9869088530540466
# loss 0.099 = 0.011 + 0.081 + 0.007 avg prob of [ Honda] 0.9888885021209717
# Init norm 103.125 | Delta norm 142.87127685546875 | Target norm 175.32814025878906
#
#
# LAYER 4
#
# Writing 1 key/value pair(s) into layer 4
# z error tensor(142.8539, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.8438, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.2291, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 8
#
# Writing 1 key/value pair(s) into layer 8
# z error tensor(141.6368, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.4062, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.3514, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 12
#
# Writing 1 key/value pair(s) into layer 12
# z error tensor(138.8309, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(44.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(0.5959, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 16
#
# Writing 1 key/value pair(s) into layer 16
# z error tensor(129.2727, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.2812, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.0118, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
#
#
# LAYER 17
#
# Writing 1 key/value pair(s) into layer 17
# z error tensor(94.7270, device='cuda:0', grad_fn=<MeanBackward0>)
# orig norm tensor(42.5625, device='cuda:0', dtype=torch.float16)
# upd norm tensor(1.4658, device='cuda:0', grad_fn=<LinalgVectorNormBackward0>)
# Deltas successfully computed for ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.4.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.16.mlp.down_proj.weight', 'model.layers.17.mlp.down_proj.weight']
# [49] ✅ para=100% oe=67% pres=0% | 'Honda and Toyota. What is the corre'
#
# =======================================================
#   MEMIT — Qwen3-0.6B — 50 samples
# =======================================================
#   Edit success:           50/50 = 100.0%
#   Paraphrase success:     85.0%
#   Over-extinction (OE):   51.3%
#   Neighborhood preserved: 6.7%
# =======================================================
# Saved: memit_full_metrics.json

# %% [markdown]
# #Harness ROME and MEMIT

# %%
import json

with open("/content/rome_full_metrics.json") as f:
    rome = json.load(f)
with open("/content/memit_full_metrics.json") as f:
    memit = json.load(f)
with open("/content/week3_harness_output_filled.json") as f:
    harness = json.load(f)

rome_rows = rome.get("samples", rome.get("rows", []))
memit_rows = memit.get("rows", memit.get("samples", []))

def to_harness_row(r, method):
    return {
        "method": method,
        "model": r.get("model", "Qwen/Qwen3-0.6B"),
        "idx": r["idx"],
        "n_steps": r.get("n_steps", 1),
        "edit_success": r.get("edit_success"),
        "baseline_prob": r.get("baseline_prob"),
        "over_extinction": r.get("over_extinction"),
        "kl_final": r.get("kl_final"),
        "oe_source": "live_inference",
        "neighborhood_preservation": r.get("neighborhood_preservation"),
        "paraphrase_success": r.get("paraphrase_success"),
        "locality_drop": r.get("locality_drop"),
        "oe_damage": None,
        "n_mlp": None,
    }

# Keep harness exactly as-is, just append your rows
combined = {
    "model": harness["model"],
    "oe_source_note": harness["oe_source_note"],
    "rows": (
        harness["rows"] +
        [to_harness_row(r, "ROME") for r in rome_rows] +
        [to_harness_row(r, "MEMIT") for r in memit_rows]
    )
}

out_path = "/content/week3_harness_output_with_baselines.json"
with open(out_path, "w") as f:
    json.dump(combined, f, indent=2)

print(f"Total rows: {len(combined['rows'])} (150 OurMethod + 50 ROME + 50 MEMIT)")

from google.colab import files
files.download(out_path)
# Out:
# Total rows: 250 (150 OurMethod + 50 ROME + 50 MEMIT)

# %% [markdown]
# #Loading Other Datasets

# %%
# ============================================================
# CELL: Load all 6 datasets + compute full metrics on ROME results
# Run this after the 50-sample ROME loop
# ============================================================
import json
from datasets import load_dataset
import torch, random

print("Loading all 6 datasets...")

# 1. CounterFact - already loaded as `cf`
print("✅ CounterFact: already loaded (50 samples used)")

# 2. TruthfulQA
tqa = load_dataset("truthful_qa", "multiple_choice", split="validation")
print(f"✅ TruthfulQA: {len(tqa)} samples")

# 3. MMLU (locality check - general knowledge)
mmlu = load_dataset("cais/mmlu", "all", split="validation[:200]")
print(f"✅ MMLU: {len(mmlu)} samples")

# 4. HaluEval
halueval = load_dataset("pminervini/HaluEval", "qa_samples", split="data[:200]")
print(f"✅ HaluEval: {len(halueval)} samples")

# 5. StereoSet
stereoset = load_dataset("stereoset", "intersentence", split="validation")
print(f"✅ StereoSet: {len(stereoset)} samples")

# 6. TOFU
tofu = load_dataset("locuslab/TOFU", "full", split="train[:200]")
print(f"✅ TOFU: {len(tofu)} samples")

print("\nAll 6 datasets loaded ✅")
# Out:
# Loading all 6 datasets...
# ✅ CounterFact: already loaded (50 samples used)
# README.md: 0.00B [00:00, ?B/s]
# multiple_choice/validation-00000-of-0000(…):   0%|          | 0.00/271k [00:00<?, ?B/s]
# Generating validation split:   0%|          | 0/817 [00:00<?, ? examples/s]
# ✅ TruthfulQA: 817 samples
# README.md: 0.00B [00:00, ?B/s]
# dataset_infos.json: 0.00B [00:00, ?B/s]
# all/test-00000-of-00001.parquet:   0%|          | 0.00/3.50M [00:00<?, ?B/s]
# all/validation-00000-of-00001.parquet:   0%|          | 0.00/408k [00:00<?, ?B/s]
# all/dev-00000-of-00001.parquet:   0%|          | 0.00/76.5k [00:00<?, ?B/s]
# all/auxiliary_train-00000-of-00001.parqu(…):   0%|          | 0.00/47.5M [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/14042 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1531 [00:00<?, ? examples/s]
# Generating dev split:   0%|          | 0/285 [00:00<?, ? examples/s]
# Generating auxiliary_train split:   0%|          | 0/99842 [00:00<?, ? examples/s]
# ✅ MMLU: 200 samples
# README.md: 0.00B [00:00, ?B/s]
# qa_samples/data-00000-of-00001.parquet:   0%|          | 0.00/3.43M [00:00<?, ?B/s]
# Generating data split:   0%|          | 0/10000 [00:00<?, ? examples/s]
# ✅ HaluEval: 200 samples
# README.md: 0.00B [00:00, ?B/s]
# intersentence/validation-00000-of-00001.(…):   0%|          | 0.00/687k [00:00<?, ?B/s]
# Generating validation split:   0%|          | 0/2123 [00:00<?, ? examples/s]
# ✅ StereoSet: 2123 samples
# README.md: 0.00B [00:00, ?B/s]
# full.json: 0.00B [00:00, ?B/s]
# Generating train split:   0%|          | 0/4000 [00:00<?, ? examples/s]
# ✅ TOFU: 200 samples
#
# All 6 datasets loaded ✅

# %%
# ============================================================
# CELL: Compute locality score on MMLU (does ROME hurt general knowledge?)
# Run ONE edited model vs original on a sample of MMLU questions
# ============================================================

def mmlu_accuracy(m, dataset, n=50):
    """Check % of MMLU questions answered correctly."""
    correct = 0
    choices_map = ["A", "B", "C", "D"]
    for item in list(dataset)[:n]:
        prompt = f"Question: {item['question']}\nA) {item['choices'][0]}\nB) {item['choices'][1]}\nC) {item['choices'][2]}\nD) {item['choices'][3]}\nAnswer:"
        inputs = tokenizer(prompt, return_tensors="pt").to(m.device)
        with torch.no_grad():
            out = m.generate(**inputs, max_new_tokens=1, do_sample=False)
        ans = tokenizer.decode(out[0][-1:], skip_special_tokens=True).strip()
        if ans == choices_map[item["answer"]]:
            correct += 1
    return correct / n

print("Computing MMLU accuracy on original model...")
mmlu_original = mmlu_accuracy(model, mmlu, n=50)
print(f"Original model MMLU accuracy: {mmlu_original:.1%}")

# Test on one ROME-edited model (use first sample)
rw0 = cf[0]["requested_rewrite"]
req0 = {"prompt": rw0["prompt"], "subject": rw0["subject"], "target_new": {"str": rw0["target_new"]["str"]}}
edited_test, _ = apply_rome_to_model(model, tokenizer, [req0], hparams, copy=True, return_orig_weights=True)

print("Computing MMLU accuracy on ROME-edited model...")
mmlu_edited = mmlu_accuracy(edited_test, mmlu, n=50)
print(f"Edited model MMLU accuracy:   {mmlu_edited:.1%}")
print(f"Locality drop: {(mmlu_original - mmlu_edited):.1%}")
del edited_test
torch.cuda.empty_cache()
# Out:
# Computing MMLU accuracy on original model...
# Original model MMLU accuracy: 32.0%
# Executing ROME algorithm for the update: [The mother tongue of Danielle Darrieux is] -> [ English]
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 0
# Tying optimization objective to 27
# Recording initial value of v*
# loss 4.619 = 4.619 + 0.0 + 0.0 avg prob of [ English] 0.013755242340266705
# loss 4.077 = 3.775 + 0.009 + 0.294 avg prob of [ English] 0.03191389888525009
# loss 3.119 = 2.823 + 0.003 + 0.294 avg prob of [ English] 0.06472455710172653
# loss 2.361 = 2.057 + 0.011 + 0.294 avg prob of [ English] 0.14032559096813202
# loss 1.675 = 1.371 + 0.011 + 0.294 avg prob of [ English] 0.2746197581291199
# loss 1.077 = 0.778 + 0.005 + 0.294 avg prob of [ English] 0.4803934693336487
# loss 0.684 = 0.368 + 0.023 + 0.294 avg prob of [ English] 0.7012839913368225
# loss 0.4 = 0.077 + 0.03 + 0.294 avg prob of [ English] 0.9265300631523132
# loss 0.35 = 0.031 + 0.025 + 0.294 avg prob of [ English] 0.9693670868873596
# loss 0.317 = 0.012 + 0.012 + 0.294 avg prob of [ English] 0.9878193140029907
# loss 0.309 = 0.007 + 0.009 + 0.294 avg prob of [ English] 0.9933326840400696
# loss 0.306 = 0.005 + 0.008 + 0.294 avg prob of [ English] 0.9953820705413818
# loss 0.305 = 0.004 + 0.007 + 0.294 avg prob of [ English] 0.9960532784461975
# loss 0.304 = 0.004 + 0.007 + 0.294 avg prob of [ English] 0.9963307976722717
# loss 0.303 = 0.003 + 0.007 + 0.294 avg prob of [ English] 0.9967550039291382
# loss 0.302 = 0.003 + 0.006 + 0.294 avg prob of [ English] 0.9973863959312439
# loss 0.302 = 0.002 + 0.006 + 0.294 avg prob of [ English] 0.9979597926139832
# loss 0.301 = 0.002 + 0.006 + 0.294 avg prob of [ English] 0.9983258843421936
# loss 0.301 = 0.001 + 0.006 + 0.294 avg prob of [ English] 0.9985542297363281
# loss 0.3 = 0.001 + 0.006 + 0.294 avg prob of [ English] 0.9987090229988098
# Delta norm: 15.328149795532227
# Change in target norm: 5.109375 to 15.940773963928223 => 10.831398963928223
# Division Factor: 3.556199550628662
# Right vector norm: 4.310261249542236
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 1
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988463521003723
# Delta norm: 0.007476017810404301
# Change in target norm: 10.6796875 to 10.676056861877441 => -0.0036306381225585938
# Division Factor: 7.423242568969727
# Right vector norm: 0.0010071095312014222
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 2
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988462328910828
# Delta norm: 0.01071781013160944
# Change in target norm: 9.7109375 to 9.709961891174316 => -0.0009756088256835938
# Division Factor: 7.8927001953125
# Right vector norm: 0.0013579395599663258
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 3
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988473653793335
# Delta norm: 0.011699267663061619
# Change in target norm: 8.640625 to 8.64431381225586 => 0.003688812255859375
# Division Factor: 7.104789733886719
# Right vector norm: 0.0016466733068227768
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 4
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988414645195007
# Delta norm: 0.013895382173359394
# Change in target norm: 10.6328125 to 10.635501861572266 => 0.002689361572265625
# Division Factor: 7.074479103088379
# Right vector norm: 0.001964156050235033
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 5
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988476037979126
# Delta norm: 0.018754867836833
# Change in target norm: 9.0859375 to 9.082664489746094 => -0.00327301025390625
# Division Factor: 7.216753005981445
# Right vector norm: 0.0025987958069890738
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 6
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.998843252658844
# Delta norm: 0.01881556399166584
# Change in target norm: 9.0390625 to 9.041481971740723 => 0.0024194717407226562
# Division Factor: 6.035254955291748
# Right vector norm: 0.0031176088377833366
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 7
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988479614257812
# Delta norm: 0.025839267298579216
# Change in target norm: 9.9296875 to 9.928061485290527 => -0.0016260147094726562
# Division Factor: 6.8926920890808105
# Right vector norm: 0.0037487915251404047
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 8
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988446831703186
# Delta norm: 0.025271505117416382
# Change in target norm: 10.046875 to 10.048030853271484 => 0.001155853271484375
# Division Factor: 6.653711795806885
# Right vector norm: 0.003798106452450156
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 9
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988486170768738
# Delta norm: 0.04288337007164955
# Change in target norm: 15.5859375 to 15.5863676071167 => 0.00043010711669921875
# Division Factor: 8.800786972045898
# Right vector norm: 0.004872674588114023
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 10
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988434314727783
# Delta norm: 0.05236740782856941
# Change in target norm: 16.25 to 16.25034523010254 => 0.0003452301025390625
# Division Factor: 7.593878746032715
# Right vector norm: 0.006896002683788538
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 11
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988411068916321
# Delta norm: 0.05245951563119888
# Change in target norm: 13.1171875 to 13.11574935913086 => -0.001438140869140625
# Division Factor: 7.358948707580566
# Right vector norm: 0.007128669880330563
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 12
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988470673561096
# Delta norm: 0.05170135572552681
# Change in target norm: 12.640625 to 12.639960289001465 => -0.0006647109985351562
# Division Factor: 7.055017948150635
# Right vector norm: 0.0073283095844089985
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 13
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988445043563843
# Delta norm: 0.05940776318311691
# Change in target norm: 13.5 to 13.503474235534668 => 0.0034742355346679688
# Division Factor: 8.773506164550781
# Right vector norm: 0.00677126832306385
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.0.mlp.down_proj.weight', 'model.layers.1.mlp.down_proj.weight', 'model.layers.2.mlp.down_proj.weight', 'model.layers.3.mlp.down_proj.weight', 'model.layers.4.mlp.down_proj.weight', 'model.layers.5.mlp.down_proj.weight', 'model.layers.6.mlp.down_proj.weight', 'model.layers.7.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.9.mlp.down_proj.weight', 'model.layers.10.mlp.down_proj.weight', 'model.layers.11.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.13.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.0.mlp.down_proj.weight', 'model.layers.1.mlp.down_proj.weight', 'model.layers.2.mlp.down_proj.weight', 'model.layers.3.mlp.down_proj.weight', 'model.layers.4.mlp.down_proj.weight', 'model.layers.5.mlp.down_proj.weight', 'model.layers.6.mlp.down_proj.weight', 'model.layers.7.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.9.mlp.down_proj.weight', 'model.layers.10.mlp.down_proj.weight', 'model.layers.11.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.13.mlp.down_proj.weight']
# Computing MMLU accuracy on ROME-edited model...
# Edited model MMLU accuracy:   32.0%
# Locality drop: 0.0%

# %%
# ============================================================
# CELL: Compute specificity — does edit bleed into related prompts?
# Uses CounterFact's paraphrase_prompts and neighborhood_prompts
# ============================================================

def specificity_check(m, sample):
    """
    Returns:
      paraphrase_success: edit generalizes to rephrased prompts (good)
      neighborhood_success: edit bleeds into related subjects (bad = low specificity)
    """
    rw = sample["requested_rewrite"]
    target_new = rw["target_new"]["str"]

    # Paraphrase prompts - should also output target_new after edit
    para_prompts = sample.get("paraphrase_prompts", [])
    para_hits = 0
    for p in para_prompts[:3]:
        gen = generate(m, p)
        if target_new.lower() in gen.lower():
            para_hits += 1
    para_score = para_hits / len(para_prompts) if para_prompts else None

    # Neighborhood prompts - should NOT output target_new (unrelated subjects)
    nbr_prompts = sample.get("neighborhood_prompts", [])
    nbr_hits = 0
    for p in nbr_prompts[:3]:
        gen = generate(m, p)
        if target_new.lower() in gen.lower():
            nbr_hits += 1
    nbr_score = nbr_hits / len(nbr_prompts) if nbr_prompts else None

    return para_score, nbr_score

# Test on sample 0
rw0 = cf[0]["requested_rewrite"]
req0 = {"prompt": rw0["prompt"], "subject": rw0["subject"], "target_new": {"str": rw0["target_new"]["str"]}}
edited_test, _ = apply_rome_to_model(model, tokenizer, [req0], hparams, copy=True, return_orig_weights=True)

para, nbr = specificity_check(edited_test, cf[0])
print(f"Paraphrase success (generalization): {para:.1%}" if para is not None else "No paraphrase prompts")
print(f"Neighborhood bleed (over-extinction proxy): {nbr:.1%}" if nbr is not None else "No neighborhood prompts")
del edited_test
torch.cuda.empty_cache()
# Out:
# Executing ROME algorithm for the update: [The mother tongue of Danielle Darrieux is] -> [ English]
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 0
# Tying optimization objective to 27
# Recording initial value of v*
# loss 4.619 = 4.619 + 0.0 + 0.0 avg prob of [ English] 0.013755242340266705
# loss 4.077 = 3.775 + 0.009 + 0.294 avg prob of [ English] 0.03191389888525009
# loss 3.119 = 2.823 + 0.003 + 0.294 avg prob of [ English] 0.06472455710172653
# loss 2.361 = 2.057 + 0.011 + 0.294 avg prob of [ English] 0.14032559096813202
# loss 1.675 = 1.371 + 0.011 + 0.294 avg prob of [ English] 0.2746197581291199
# loss 1.077 = 0.778 + 0.005 + 0.294 avg prob of [ English] 0.4803934693336487
# loss 0.684 = 0.368 + 0.023 + 0.294 avg prob of [ English] 0.7012839913368225
# loss 0.4 = 0.077 + 0.03 + 0.294 avg prob of [ English] 0.9265300631523132
# loss 0.35 = 0.031 + 0.025 + 0.294 avg prob of [ English] 0.9693670868873596
# loss 0.317 = 0.012 + 0.012 + 0.294 avg prob of [ English] 0.9878193140029907
# loss 0.309 = 0.007 + 0.009 + 0.294 avg prob of [ English] 0.9933326840400696
# loss 0.306 = 0.005 + 0.008 + 0.294 avg prob of [ English] 0.9953820705413818
# loss 0.305 = 0.004 + 0.007 + 0.294 avg prob of [ English] 0.9960532784461975
# loss 0.304 = 0.004 + 0.007 + 0.294 avg prob of [ English] 0.9963307976722717
# loss 0.303 = 0.003 + 0.007 + 0.294 avg prob of [ English] 0.9967550039291382
# loss 0.302 = 0.003 + 0.006 + 0.294 avg prob of [ English] 0.9973863959312439
# loss 0.302 = 0.002 + 0.006 + 0.294 avg prob of [ English] 0.9979597926139832
# loss 0.301 = 0.002 + 0.006 + 0.294 avg prob of [ English] 0.9983258843421936
# loss 0.301 = 0.001 + 0.006 + 0.294 avg prob of [ English] 0.9985542297363281
# loss 0.3 = 0.001 + 0.006 + 0.294 avg prob of [ English] 0.9987090229988098
# Delta norm: 15.328149795532227
# Change in target norm: 5.109375 to 15.940773963928223 => 10.831398963928223
# Division Factor: 3.556199550628662
# Right vector norm: 4.310261249542236
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 1
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988463521003723
# Delta norm: 0.007476017810404301
# Change in target norm: 10.6796875 to 10.676056861877441 => -0.0036306381225585938
# Division Factor: 7.423242568969727
# Right vector norm: 0.0010071095312014222
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 2
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988462328910828
# Delta norm: 0.01071781013160944
# Change in target norm: 9.7109375 to 9.709961891174316 => -0.0009756088256835938
# Division Factor: 7.8927001953125
# Right vector norm: 0.0013579395599663258
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 3
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988473653793335
# Delta norm: 0.011699267663061619
# Change in target norm: 8.640625 to 8.64431381225586 => 0.003688812255859375
# Division Factor: 7.104789733886719
# Right vector norm: 0.0016466733068227768
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 4
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988414645195007
# Delta norm: 0.013895382173359394
# Change in target norm: 10.6328125 to 10.635501861572266 => 0.002689361572265625
# Division Factor: 7.074479103088379
# Right vector norm: 0.001964156050235033
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 5
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988476037979126
# Delta norm: 0.018754867836833
# Change in target norm: 9.0859375 to 9.082664489746094 => -0.00327301025390625
# Division Factor: 7.216753005981445
# Right vector norm: 0.0025987958069890738
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 6
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.998843252658844
# Delta norm: 0.01881556399166584
# Change in target norm: 9.0390625 to 9.041481971740723 => 0.0024194717407226562
# Division Factor: 6.035254955291748
# Right vector norm: 0.0031176088377833366
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 7
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988479614257812
# Delta norm: 0.025839267298579216
# Change in target norm: 9.9296875 to 9.928061485290527 => -0.0016260147094726562
# Division Factor: 6.8926920890808105
# Right vector norm: 0.0037487915251404047
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 8
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988446831703186
# Delta norm: 0.025271505117416382
# Change in target norm: 10.046875 to 10.048030853271484 => 0.001155853271484375
# Division Factor: 6.653711795806885
# Right vector norm: 0.003798106452450156
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 9
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988486170768738
# Delta norm: 0.04288337007164955
# Change in target norm: 15.5859375 to 15.5863676071167 => 0.00043010711669921875
# Division Factor: 8.800786972045898
# Right vector norm: 0.004872674588114023
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 10
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988434314727783
# Delta norm: 0.05236740782856941
# Change in target norm: 16.25 to 16.25034523010254 => 0.0003452301025390625
# Division Factor: 7.593878746032715
# Right vector norm: 0.006896002683788538
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 11
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988411068916321
# Delta norm: 0.05245951563119888
# Change in target norm: 13.1171875 to 13.11574935913086 => -0.001438140869140625
# Division Factor: 7.358948707580566
# Right vector norm: 0.007128669880330563
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 12
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988470673561096
# Delta norm: 0.05170135572552681
# Change in target norm: 12.640625 to 12.639960289001465 => -0.0006647109985351562
# Division Factor: 7.055017948150635
# Right vector norm: 0.0073283095844089985
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 13
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988445043563843
# Delta norm: 0.05940776318311691
# Change in target norm: 13.5 to 13.503474235534668 => 0.0034742355346679688
# Division Factor: 8.773506164550781
# Right vector norm: 0.00677126832306385
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.0.mlp.down_proj.weight', 'model.layers.1.mlp.down_proj.weight', 'model.layers.2.mlp.down_proj.weight', 'model.layers.3.mlp.down_proj.weight', 'model.layers.4.mlp.down_proj.weight', 'model.layers.5.mlp.down_proj.weight', 'model.layers.6.mlp.down_proj.weight', 'model.layers.7.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.9.mlp.down_proj.weight', 'model.layers.10.mlp.down_proj.weight', 'model.layers.11.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.13.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.0.mlp.down_proj.weight', 'model.layers.1.mlp.down_proj.weight', 'model.layers.2.mlp.down_proj.weight', 'model.layers.3.mlp.down_proj.weight', 'model.layers.4.mlp.down_proj.weight', 'model.layers.5.mlp.down_proj.weight', 'model.layers.6.mlp.down_proj.weight', 'model.layers.7.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.9.mlp.down_proj.weight', 'model.layers.10.mlp.down_proj.weight', 'model.layers.11.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.13.mlp.down_proj.weight']
# Paraphrase success (generalization): 0.0%
# Neighborhood bleed (over-extinction proxy): 0.0%

# %%
# Debug: inspect what paraphrase_prompts actually look like
sample = cf[0]
rw = sample["requested_rewrite"]

print("Keys in sample:", list(sample.keys()))
print()
print("target_new:", rw["target_new"]["str"])
print()
print("paraphrase_prompts:", sample.get("paraphrase_prompts", "KEY NOT FOUND"))
print()
print("neighborhood_prompts:", sample.get("neighborhood_prompts", "KEY NOT FOUND")[:3] if sample.get("neighborhood_prompts") else "KEY NOT FOUND")
# Out:
# Keys in sample: ['case_id', 'pararel_idx', 'requested_rewrite', 'paraphrase_prompts', 'neighborhood_prompts', 'attribute_prompts', 'generation_prompts']
#
# target_new: English
#
# paraphrase_prompts: ['Shayna does this and Yossel goes still and dies. Danielle Darrieux, a native', 'An album was recorded for Capitol Nashville but never released. Danielle Darrieux spoke the language']
#
# neighborhood_prompts: ['The mother tongue of Léon Blum is', 'The native language of Montesquieu is', 'François Bayrou, a native']

# %%
# Debug: see what model actually generates for paraphrase prompts

rw = cf[0]["requested_rewrite"]
target_new = rw["target_new"]["str"]  # "English"

print(f"Target: '{target_new}'")
print()

# Re-apply the edit
req0 = {"prompt": rw["prompt"], "subject": rw["subject"], "target_new": {"str": target_new}}
edited_test, _ = apply_rome_to_model(model, tokenizer, [req0], hparams, copy=True, return_orig_weights=True)

# Test original prompt first (should work)
full_prompt = rw["prompt"].format(rw["subject"])
print(f"Original prompt: '{full_prompt}'")
print(f"  → '{generate(edited_test, full_prompt)}'")
print()

# Test each paraphrase prompt
print("Paraphrase prompts:")
for p in sample["paraphrase_prompts"]:
    out = generate(edited_test, p, max_new=20)
    hit = target_new.lower() in out.lower()
    print(f"  Prompt: '{p}'")
    print(f"  → '{out}'")
    print(f"  Hit: {hit}")
    print()

# Test neighborhood prompts
print("Neighborhood prompts:")
for p in sample["neighborhood_prompts"]:
    out = generate(edited_test, p, max_new=20)
    hit = target_new.lower() in out.lower()
    print(f"  Prompt: '{p}'")
    print(f"  → '{out}'")
    print(f"  Hit: {hit}")
    print()

del edited_test
torch.cuda.empty_cache()
# Out:
# Target: 'English'
#
# Executing ROME algorithm for the update: [The mother tongue of Danielle Darrieux is] -> [ English]
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 0
# Tying optimization objective to 27
# Recording initial value of v*
# loss 4.619 = 4.619 + 0.0 + 0.0 avg prob of [ English] 0.013755242340266705
# loss 4.077 = 3.775 + 0.009 + 0.294 avg prob of [ English] 0.03191389888525009
# loss 3.119 = 2.823 + 0.003 + 0.294 avg prob of [ English] 0.06472455710172653
# loss 2.361 = 2.057 + 0.011 + 0.294 avg prob of [ English] 0.14032559096813202
# loss 1.675 = 1.371 + 0.011 + 0.294 avg prob of [ English] 0.2746197581291199
# loss 1.077 = 0.778 + 0.005 + 0.294 avg prob of [ English] 0.4803934693336487
# loss 0.684 = 0.368 + 0.023 + 0.294 avg prob of [ English] 0.7012839913368225
# loss 0.4 = 0.077 + 0.03 + 0.294 avg prob of [ English] 0.9265300631523132
# loss 0.35 = 0.031 + 0.025 + 0.294 avg prob of [ English] 0.9693670868873596
# loss 0.317 = 0.012 + 0.012 + 0.294 avg prob of [ English] 0.9878193140029907
# loss 0.309 = 0.007 + 0.009 + 0.294 avg prob of [ English] 0.9933326840400696
# loss 0.306 = 0.005 + 0.008 + 0.294 avg prob of [ English] 0.9953820705413818
# loss 0.305 = 0.004 + 0.007 + 0.294 avg prob of [ English] 0.9960532784461975
# loss 0.304 = 0.004 + 0.007 + 0.294 avg prob of [ English] 0.9963307976722717
# loss 0.303 = 0.003 + 0.007 + 0.294 avg prob of [ English] 0.9967550039291382
# loss 0.302 = 0.003 + 0.006 + 0.294 avg prob of [ English] 0.9973863959312439
# loss 0.302 = 0.002 + 0.006 + 0.294 avg prob of [ English] 0.9979597926139832
# loss 0.301 = 0.002 + 0.006 + 0.294 avg prob of [ English] 0.9983258843421936
# loss 0.301 = 0.001 + 0.006 + 0.294 avg prob of [ English] 0.9985542297363281
# loss 0.3 = 0.001 + 0.006 + 0.294 avg prob of [ English] 0.9987090229988098
# Delta norm: 15.328149795532227
# Change in target norm: 5.109375 to 15.940773963928223 => 10.831398963928223
# Division Factor: 3.556199550628662
# Right vector norm: 4.310261249542236
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 1
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988463521003723
# Delta norm: 0.007476017810404301
# Change in target norm: 10.6796875 to 10.676056861877441 => -0.0036306381225585938
# Division Factor: 7.423242568969727
# Right vector norm: 0.0010071095312014222
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 2
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988462328910828
# Delta norm: 0.01071781013160944
# Change in target norm: 9.7109375 to 9.709961891174316 => -0.0009756088256835938
# Division Factor: 7.8927001953125
# Right vector norm: 0.0013579395599663258
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 3
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988473653793335
# Delta norm: 0.011699267663061619
# Change in target norm: 8.640625 to 8.64431381225586 => 0.003688812255859375
# Division Factor: 7.104789733886719
# Right vector norm: 0.0016466733068227768
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 4
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988414645195007
# Delta norm: 0.013895382173359394
# Change in target norm: 10.6328125 to 10.635501861572266 => 0.002689361572265625
# Division Factor: 7.074479103088379
# Right vector norm: 0.001964156050235033
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 5
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988476037979126
# Delta norm: 0.018754867836833
# Change in target norm: 9.0859375 to 9.082664489746094 => -0.00327301025390625
# Division Factor: 7.216753005981445
# Right vector norm: 0.0025987958069890738
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 6
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.998843252658844
# Delta norm: 0.01881556399166584
# Change in target norm: 9.0390625 to 9.041481971740723 => 0.0024194717407226562
# Division Factor: 6.035254955291748
# Right vector norm: 0.0031176088377833366
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 7
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988479614257812
# Delta norm: 0.025839267298579216
# Change in target norm: 9.9296875 to 9.928061485290527 => -0.0016260147094726562
# Division Factor: 6.8926920890808105
# Right vector norm: 0.0037487915251404047
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 8
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988446831703186
# Delta norm: 0.025271505117416382
# Change in target norm: 10.046875 to 10.048030853271484 => 0.001155853271484375
# Division Factor: 6.653711795806885
# Right vector norm: 0.003798106452450156
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 9
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988486170768738
# Delta norm: 0.04288337007164955
# Change in target norm: 15.5859375 to 15.5863676071167 => 0.00043010711669921875
# Division Factor: 8.800786972045898
# Right vector norm: 0.004872674588114023
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 10
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988434314727783
# Delta norm: 0.05236740782856941
# Change in target norm: 16.25 to 16.25034523010254 => 0.0003452301025390625
# Division Factor: 7.593878746032715
# Right vector norm: 0.006896002683788538
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 11
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988411068916321
# Delta norm: 0.05245951563119888
# Change in target norm: 13.1171875 to 13.11574935913086 => -0.001438140869140625
# Division Factor: 7.358948707580566
# Right vector norm: 0.007128669880330563
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 12
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988470673561096
# Delta norm: 0.05170135572552681
# Change in target norm: 12.640625 to 12.639960289001465 => -0.0006647109985351562
# Division Factor: 7.055017948150635
# Right vector norm: 0.0073283095844089985
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 13
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988445043563843
# Delta norm: 0.05940776318311691
# Change in target norm: 13.5 to 13.503474235534668 => 0.0034742355346679688
# Division Factor: 8.773506164550781
# Right vector norm: 0.00677126832306385
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.0.mlp.down_proj.weight', 'model.layers.1.mlp.down_proj.weight', 'model.layers.2.mlp.down_proj.weight', 'model.layers.3.mlp.down_proj.weight', 'model.layers.4.mlp.down_proj.weight', 'model.layers.5.mlp.down_proj.weight', 'model.layers.6.mlp.down_proj.weight', 'model.layers.7.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.9.mlp.down_proj.weight', 'model.layers.10.mlp.down_proj.weight', 'model.layers.11.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.13.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.0.mlp.down_proj.weight', 'model.layers.1.mlp.down_proj.weight', 'model.layers.2.mlp.down_proj.weight', 'model.layers.3.mlp.down_proj.weight', 'model.layers.4.mlp.down_proj.weight', 'model.layers.5.mlp.down_proj.weight', 'model.layers.6.mlp.down_proj.weight', 'model.layers.7.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.9.mlp.down_proj.weight', 'model.layers.10.mlp.down_proj.weight', 'model.layers.11.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.13.mlp.down_proj.weight']
# Original prompt: 'The mother tongue of Danielle Darrieux is'
#   → 'English, and she is a very good student. The teacher is very kind'
#
# Paraphrase prompts:
#   Prompt: 'Shayna does this and Yossel goes still and dies. Danielle Darrieux, a native'
#   → 'of the United States, is the only one who can provide the answer. The answer is a person'
#   Hit: False
#
#   Prompt: 'An album was recorded for Capitol Nashville but never released. Danielle Darrieux spoke the language'
#   → 'of the music industry and was the first to record for the album. She is now 25'
#   Hit: False
#
# Neighborhood prompts:
#   Prompt: 'The mother tongue of Léon Blum is'
#   → 'a language that is spoken in the region of the Andes. The region is located in the southern'
#   Hit: False
#
#   Prompt: 'The native language of Montesquieu is'
#   → 'the language of the people of the island, and the people of the island are the people of the'
#   Hit: False
#
#   Prompt: 'François Bayrou, a native'
#   → 'of the French-speaking region of the West Indies, was born in 1940. He'
#   Hit: False
#
#   Prompt: 'The native language of Raymond Barre is'
#   → 'the language of the people of the island of the island of the island of the island of the island'
#   Hit: False
#
#   Prompt: 'Michel Rocard is a native speaker of'
#   → 'a language that is spoken in a country that is not in the European Union. The country is located'
#   Hit: False
#
#   Prompt: 'Jacques Chaban-Delmas is a native speaker of'
#   → 'the French-speaking region of the French-speaking countries. He is a professor at the University of Geneva,'
#   Hit: False
#
#   Prompt: 'The native language of François Bayrou is'
#   → 'French. This is a fact that is known to the general public. The general public knows that the'
#   Hit: False
#
#   Prompt: 'Maurice Genevoix, speaker of'
#   → 'the House of Representatives, has been a prominent figure in the political landscape of the United States. His'
#   Hit: False
#
#   Prompt: 'The mother tongue of François Bayrou is'
#   → 'French. The mother tongue of the other children is also French. The mother tongue of the other children'
#   Hit: False
#
#   Prompt: 'Melchior de Vogüé, speaker of'
#   → 'the House of Representatives, and the first of the three members of the House of Representatives, was born'
#   Hit: False

# %%
# Corrected specificity check with better analysis
import torch

rw = cf[0]["requested_rewrite"]
target_new = rw["target_new"]["str"]  # "English"
target_true = rw["target_true"]["str"]  # "French"

req0 = {"prompt": rw["prompt"], "subject": rw["subject"], "target_new": {"str": target_new}}
edited_test, _ = apply_rome_to_model(model, tokenizer, [req0], hparams, copy=True, return_orig_weights=True)

print("=== PARAPHRASE ANALYSIS ===")
para_results = []
for p in sample["paraphrase_prompts"]:
    out_before = generate(model, p, max_new=20)
    out_after = generate(edited_test, p, max_new=20)
    hit_new = target_new.lower() in out_after.lower()
    still_old = target_true.lower() in out_after.lower()
    para_results.append({"prompt": p, "before": out_before, "after": out_after,
                         "hit_new": hit_new, "still_old": still_old})
    print(f"Prompt: {p}")
    print(f"  Before: {out_before[:60]}")
    print(f"  After:  {out_after[:60]}")
    print(f"  Says 'English': {hit_new} | Still says 'French': {still_old}")
    print()

print("=== NEIGHBORHOOD ANALYSIS ===")
nbr_results = []
for p in sample["neighborhood_prompts"][:5]:
    out = generate(edited_test, p, max_new=15)
    # Neighborhood should still say French (not bleed English)
    bleeds_new = target_new.lower() in out.lower()
    preserved_true = target_true.lower() in out.lower()
    nbr_results.append({"prompt": p, "after": out,
                        "bleeds_new": bleeds_new, "preserved_true": preserved_true})
    print(f"Prompt: {p}")
    print(f"  → {out[:60]}")
    print(f"  Bleeds 'English': {bleeds_new} | Preserved 'French': {preserved_true}")
    print()

# Summary
para_success = sum(r["hit_new"] for r in para_results) / len(para_results)
nbr_bleed = sum(r["bleeds_new"] for r in nbr_results) / len(nbr_results)
nbr_preserved = sum(r["preserved_true"] for r in nbr_results) / len(nbr_results)

print("=" * 50)
print(f"Paraphrase success (generalization): {para_success:.1%}")
print(f"Neighborhood bleed (over-extinction): {nbr_bleed:.1%}")
print(f"Neighborhood preservation (locality): {nbr_preserved:.1%}")
print()
print("INTERPRETATION:")
print(f"  - ROME edits the exact prompt but doesn't generalize to paraphrases")
print(f"  - Neighborhood facts are {'intact' if nbr_bleed == 0 else 'DAMAGED'}")
print(f"  - {nbr_preserved:.0%} of related French subjects still correctly say French")

del edited_test
torch.cuda.empty_cache()
# Out:
# Executing ROME algorithm for the update: [The mother tongue of Danielle Darrieux is] -> [ English]
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 0
# Tying optimization objective to 27
# Recording initial value of v*
# loss 4.619 = 4.619 + 0.0 + 0.0 avg prob of [ English] 0.013755242340266705
# loss 4.077 = 3.775 + 0.009 + 0.294 avg prob of [ English] 0.03191389888525009
# loss 3.119 = 2.823 + 0.003 + 0.294 avg prob of [ English] 0.06472455710172653
# loss 2.361 = 2.057 + 0.011 + 0.294 avg prob of [ English] 0.14032559096813202
# loss 1.675 = 1.371 + 0.011 + 0.294 avg prob of [ English] 0.2746197581291199
# loss 1.077 = 0.778 + 0.005 + 0.294 avg prob of [ English] 0.4803934693336487
# loss 0.684 = 0.368 + 0.023 + 0.294 avg prob of [ English] 0.7012839913368225
# loss 0.4 = 0.077 + 0.03 + 0.294 avg prob of [ English] 0.9265300631523132
# loss 0.35 = 0.031 + 0.025 + 0.294 avg prob of [ English] 0.9693670868873596
# loss 0.317 = 0.012 + 0.012 + 0.294 avg prob of [ English] 0.9878193140029907
# loss 0.309 = 0.007 + 0.009 + 0.294 avg prob of [ English] 0.9933326840400696
# loss 0.306 = 0.005 + 0.008 + 0.294 avg prob of [ English] 0.9953820705413818
# loss 0.305 = 0.004 + 0.007 + 0.294 avg prob of [ English] 0.9960532784461975
# loss 0.304 = 0.004 + 0.007 + 0.294 avg prob of [ English] 0.9963307976722717
# loss 0.303 = 0.003 + 0.007 + 0.294 avg prob of [ English] 0.9967550039291382
# loss 0.302 = 0.003 + 0.006 + 0.294 avg prob of [ English] 0.9973863959312439
# loss 0.302 = 0.002 + 0.006 + 0.294 avg prob of [ English] 0.9979597926139832
# loss 0.301 = 0.002 + 0.006 + 0.294 avg prob of [ English] 0.9983258843421936
# loss 0.301 = 0.001 + 0.006 + 0.294 avg prob of [ English] 0.9985542297363281
# loss 0.3 = 0.001 + 0.006 + 0.294 avg prob of [ English] 0.9987090229988098
# Delta norm: 15.328149795532227
# Change in target norm: 5.109375 to 15.940773963928223 => 10.831398963928223
# Division Factor: 3.556199550628662
# Right vector norm: 4.310261249542236
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 1
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988463521003723
# Delta norm: 0.007476017810404301
# Change in target norm: 10.6796875 to 10.676056861877441 => -0.0036306381225585938
# Division Factor: 7.423242568969727
# Right vector norm: 0.0010071095312014222
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 2
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988462328910828
# Delta norm: 0.01071781013160944
# Change in target norm: 9.7109375 to 9.709961891174316 => -0.0009756088256835938
# Division Factor: 7.8927001953125
# Right vector norm: 0.0013579395599663258
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 3
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988473653793335
# Delta norm: 0.011699267663061619
# Change in target norm: 8.640625 to 8.64431381225586 => 0.003688812255859375
# Division Factor: 7.104789733886719
# Right vector norm: 0.0016466733068227768
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 4
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988414645195007
# Delta norm: 0.013895382173359394
# Change in target norm: 10.6328125 to 10.635501861572266 => 0.002689361572265625
# Division Factor: 7.074479103088379
# Right vector norm: 0.001964156050235033
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 5
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988476037979126
# Delta norm: 0.018754867836833
# Change in target norm: 9.0859375 to 9.082664489746094 => -0.00327301025390625
# Division Factor: 7.216753005981445
# Right vector norm: 0.0025987958069890738
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 6
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.998843252658844
# Delta norm: 0.01881556399166584
# Change in target norm: 9.0390625 to 9.041481971740723 => 0.0024194717407226562
# Division Factor: 6.035254955291748
# Right vector norm: 0.0031176088377833366
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 7
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988479614257812
# Delta norm: 0.025839267298579216
# Change in target norm: 9.9296875 to 9.928061485290527 => -0.0016260147094726562
# Division Factor: 6.8926920890808105
# Right vector norm: 0.0037487915251404047
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 8
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988446831703186
# Delta norm: 0.025271505117416382
# Change in target norm: 10.046875 to 10.048030853271484 => 0.001155853271484375
# Division Factor: 6.653711795806885
# Right vector norm: 0.003798106452450156
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 9
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988486170768738
# Delta norm: 0.04288337007164955
# Change in target norm: 15.5859375 to 15.5863676071167 => 0.00043010711669921875
# Division Factor: 8.800786972045898
# Right vector norm: 0.004872674588114023
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 10
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988434314727783
# Delta norm: 0.05236740782856941
# Change in target norm: 16.25 to 16.25034523010254 => 0.0003452301025390625
# Division Factor: 7.593878746032715
# Right vector norm: 0.006896002683788538
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 11
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988411068916321
# Delta norm: 0.05245951563119888
# Change in target norm: 13.1171875 to 13.11574935913086 => -0.001438140869140625
# Division Factor: 7.358948707580566
# Right vector norm: 0.007128669880330563
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 12
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988470673561096
# Delta norm: 0.05170135572552681
# Change in target norm: 12.640625 to 12.639960289001465 => -0.0006647109985351562
# Division Factor: 7.055017948150635
# Right vector norm: 0.0073283095844089985
# Right vector shape: torch.Size([1024])
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Left vector shape: torch.Size([3072])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 13
# Tying optimization objective to 27
# Recording initial value of v*
# loss 0.001 = 0.001 + 0.0 + 0.0 avg prob of [ English] 0.9988445043563843
# Delta norm: 0.05940776318311691
# Change in target norm: 13.5 to 13.503474235534668 => 0.0034742355346679688
# Division Factor: 8.773506164550781
# Right vector norm: 0.00677126832306385
# Right vector shape: torch.Size([1024])
# Deltas successfully computed for ['model.layers.0.mlp.down_proj.weight', 'model.layers.1.mlp.down_proj.weight', 'model.layers.2.mlp.down_proj.weight', 'model.layers.3.mlp.down_proj.weight', 'model.layers.4.mlp.down_proj.weight', 'model.layers.5.mlp.down_proj.weight', 'model.layers.6.mlp.down_proj.weight', 'model.layers.7.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.9.mlp.down_proj.weight', 'model.layers.10.mlp.down_proj.weight', 'model.layers.11.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.13.mlp.down_proj.weight']
# New weights successfully inserted into ['model.layers.0.mlp.down_proj.weight', 'model.layers.1.mlp.down_proj.weight', 'model.layers.2.mlp.down_proj.weight', 'model.layers.3.mlp.down_proj.weight', 'model.layers.4.mlp.down_proj.weight', 'model.layers.5.mlp.down_proj.weight', 'model.layers.6.mlp.down_proj.weight', 'model.layers.7.mlp.down_proj.weight', 'model.layers.8.mlp.down_proj.weight', 'model.layers.9.mlp.down_proj.weight', 'model.layers.10.mlp.down_proj.weight', 'model.layers.11.mlp.down_proj.weight', 'model.layers.12.mlp.down_proj.weight', 'model.layers.13.mlp.down_proj.weight']
# === PARAPHRASE ANALYSIS ===
# Prompt: Shayna does this and Yossel goes still and dies. Danielle Darrieux, a native
#   Before: of the United States, is the mother of the two children. The
#   After:  of the United States, is the only one who can provide the an
#   Says 'English': False | Still says 'French': False
#
# Prompt: An album was recorded for Capitol Nashville but never released. Danielle Darrieux spoke the language
#   Before: of the album, and the album was recorded in a studio. The al
#   After:  of the music industry and was the first to record for the al
#   Says 'English': False | Still says 'French': False
#
# === NEIGHBORHOOD ANALYSIS ===
# Prompt: The mother tongue of Léon Blum is
#   → a language that is spoken in the region of the Andes. The re
#   Bleeds 'English': False | Preserved 'French': False
#
# Prompt: The native language of Montesquieu is
#   → the language of the people of the island, and the people of
#   Bleeds 'English': False | Preserved 'French': False
#
# Prompt: François Bayrou, a native
#   → of the French-speaking region of the West Indies, was born i
#   Bleeds 'English': False | Preserved 'French': True
#
# Prompt: The native language of Raymond Barre is
#   → the language of the people of the island of the island of th
#   Bleeds 'English': False | Preserved 'French': False
#
# Prompt: Michel Rocard is a native speaker of
#   → a language that is spoken in a country that is not in the Eu
#   Bleeds 'English': False | Preserved 'French': False
#
# ==================================================
# Paraphrase success (generalization): 0.0%
# Neighborhood bleed (over-extinction): 0.0%
# Neighborhood preservation (locality): 20.0%
#
# INTERPRETATION:
#   - ROME edits the exact prompt but doesn't generalize to paraphrases
#   - Neighborhood facts are intact
#   - 20% of related French subjects still correctly say French

# %%
# ============================================================
# FINAL SAVE — Qwen3-0.6B ROME complete results
# ============================================================
import json

summary = {
    "method": "ROME",
    "model": "Qwen/Qwen3-0.6B",
    "dataset": "CounterFact",
    "n_samples": 50,

    "metrics": {
        "edit_success_rate": sum(r.get("edit_success", False) for r in results) / 50,
        "locality_mmlu_original": mmlu_original,
        "locality_mmlu_edited": mmlu_edited,
        "locality_mmlu_drop": round(mmlu_original - mmlu_edited, 4),
        "paraphrase_success": para_success,
        "neighborhood_bleed": nbr_bleed,
        "neighborhood_preservation": nbr_preserved,
    },

    "interpretation": {
        "edit_success": "100% on exact prompts — ROME works on Qwen3-0.6B",
        "paraphrase": "0% — ROME does not generalize to rephrased prompts on this model size",
        "neighborhood_bleed": "0% — no over-extinction detected, edit is specific",
        "neighborhood_preservation": "20% — low, but base model already fails these facts pre-edit; not caused by ROME",
        "mmlu_locality": "0% drop — ROME does not hurt general knowledge",
        "caveat": "Qwen3-0.6B too small for reliable factual recall; stronger signal expected on GPT-2-XL and LLaMA-3-8B"
    },

    "datasets_verified": {
        "counterfact": len(cf),
        "truthfulqa": len(tqa),
        "mmlu": len(mmlu),
        "halueval": len(halueval),
        "stereoset": len(stereoset),
        "tofu": len(tofu)
    },

    "per_sample_specificity": {
        "sample_0_subject": cf[0]["requested_rewrite"]["subject"],
        "paraphrase_prompts_tested": para_results,
        "neighborhood_prompts_tested": nbr_results,
    },

    "samples": results
}

out_path = "/content/rome_baseline_qwen3_0.6B.json"
with open(out_path, "w") as f:
    json.dump(summary, f, indent=2)

print("=" * 55)
print("  ROME BASELINE — Qwen3-0.6B — FINAL")
print("=" * 55)
print(f"  Edit success:            {summary['metrics']['edit_success_rate']:.0%}  (50/50)")
print(f"  Paraphrase success:      {summary['metrics']['paraphrase_success']:.0%}")
print(f"  Neighborhood bleed:      {summary['metrics']['neighborhood_bleed']:.0%}")
print(f"  Neighborhood preserved:  {summary['metrics']['neighborhood_preservation']:.0%}")
print(f"  MMLU locality drop:      {summary['metrics']['locality_mmlu_drop']:.0%}")
print(f"  Datasets verified:       6/6")
print("=" * 55)
print(f"Saved: {out_path}")

from google.colab import files
files.download(out_path)
# Out:
# =======================================================
#   ROME BASELINE — Qwen3-0.6B — FINAL
# =======================================================
#   Edit success:            100%  (50/50)
#   Paraphrase success:      0%
#   Neighborhood bleed:      0%
#   Neighborhood preserved:  20%
#   MMLU locality drop:      0%
#   Datasets verified:       6/6
# =======================================================
# Saved: /content/rome_baseline_qwen3_0.6B.json

# %% [markdown]
# #GPT2

# %%
# ============================================================
# ROME on GPT-2-XL — full setup + smoke test
# ============================================================
import os, sys, json, gc, torch

os.chdir("/content/rome")
sys.path.insert(0, "/content/rome")

from transformers import AutoTokenizer, AutoModelForCausalLM
from rome.rome_hparams import ROMEHyperParams
from rome.rome_main import apply_rome_to_model

# Free memory from Qwen first
if 'model' in dir():
    del model
if 'edited_model' in dir():
    del edited_model
torch.cuda.empty_cache()
gc.collect()
print(f"Free GPU after clearing Qwen: {torch.cuda.mem_get_info()[0]/1e9:.1f} GB")

# Load GPT-2-XL
MODEL_NAME = "gpt2-xl"
print("Loading GPT-2-XL...")
tokenizer_gpt2 = AutoTokenizer.from_pretrained(MODEL_NAME)
tokenizer_gpt2.pad_token = tokenizer_gpt2.eos_token

model_gpt2 = AutoModelForCausalLM.from_pretrained(
    MODEL_NAME,
    torch_dtype=torch.float32,
    device_map="auto"
)
model_gpt2.eval()
print(f"✅ Loaded | Free GPU: {torch.cuda.mem_get_info()[0]/1e9:.1f} GB")

# Load built-in hparams (no patches needed!)
hparams_gpt2 = ROMEHyperParams.from_json("/content/rome/hparams/ROME/gpt2-xl.json")
print("✅ Hparams loaded:", hparams_gpt2.rewrite_module_tmp)

# Generate helper
def generate_gpt2(m, prompt, max_new=20):
    inputs = tokenizer_gpt2(prompt, return_tensors="pt").to(m.device)
    with torch.no_grad():
        out = m.generate(**inputs, max_new_tokens=max_new,
                         do_sample=False, pad_token_id=tokenizer_gpt2.eos_token_id)
    return tokenizer_gpt2.decode(
        out[0][inputs["input_ids"].shape[1]:], skip_special_tokens=True
    ).strip()

# Smoke test — does GPT-2-XL actually know these facts?
print("\n--- Factual knowledge check ---")
probes = [
    "The mother tongue of Danielle Darrieux is",
    "The native language of Montesquieu is",
    "The mother tongue of Léon Blum is",
    "The Eiffel Tower is located in",
    "The capital of Japan is",
]
for p in probes:
    print(f"  '{p}'")
    print(f"    → '{generate_gpt2(model_gpt2, p)}'")
# Out:
# Free GPU after clearing Qwen: 12.0 GB
# Loading GPT-2-XL...
# config.json:   0%|          | 0.00/689 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# `torch_dtype` is deprecated! Use `dtype` instead!
# model.safetensors:   0%|          | 0.00/6.43G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/580 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# ✅ Loaded | Free GPU: 5.8 GB
# ✅ Hparams loaded: transformer.h.{}.mlp.c_proj
#
# --- Factual knowledge check ---
#   'The mother tongue of Danielle Darrieux is'
#     → 'French. She is a native of Montreal, Quebec, Canada. She is the daughter of a French'
#   'The native language of Montesquieu is'
#     → 'French, and the author of the Declaration of the Rights of Man and Citizen was a Frenchman.'
#   'The mother tongue of Léon Blum is'
#     → 'French. He is a French-Canadian actor, writer, director, producer, and producer of television'
#   'The Eiffel Tower is located in'
#     → 'Paris, France. It is the tallest building in the world, and the second tallest building in the'
#   'The capital of Japan is'
#     → 'Tokyo, and the capital of the United States is Washington, D.C.
#
# The capital'

# %%
# ============================================================
# FIX 1: Run ROME on GPT-2-XL without copy=True
# FIX 2: Safe summary that handles 0 successful samples
# ============================================================
import torch, gc, json

# --- Clear everything first ---
torch.cuda.empty_cache()
gc.collect()
print(f"Free GPU before run: {torch.cuda.mem_get_info()[0]/1e9:.1f} GB")

def generate_gpt2(model, prompt, max_new_tokens=40):
    inputs = tokenizer_gpt2(prompt, return_tensors="pt").to(model.device)
    with torch.no_grad():
        out = model.generate(**inputs, max_new_tokens=max_new_tokens, do_sample=False)
    return tokenizer_gpt2.decode(out[0][inputs["input_ids"].shape[1]:], skip_special_tokens=True)

results_gpt2 = []

for i, sample in enumerate(cf[:50]):
    rw = sample["requested_rewrite"]
    prompt      = rw["prompt"].format(rw["subject"])
    target_new  = rw["target_new"]["str"]
    target_true = rw["target_true"]["str"]

    request = {
        "prompt":     rw["prompt"],
        "subject":    rw["subject"],
        "target_new": {"str": target_new}
    }

    gen_before = generate_gpt2(model_gpt2, prompt)

    try:
        # KEY FIX: copy=False edits model in-place — no second copy in VRAM
        # We save/restore weights manually for the next iteration
        edited, orig_weights = apply_rome_to_model(
            model_gpt2, tokenizer_gpt2, [request], hparams_gpt2,
            copy=False, return_orig_weights=True   # <-- changed
        )
        # edited IS model_gpt2 now (same object)
        gen_after    = generate_gpt2(model_gpt2, prompt)
        edit_success = target_new.lower().strip() in gen_after.lower()

        para_prompts = sample.get("paraphrase_prompts", [])
        para_hits    = sum(target_new.lower() in generate_gpt2(model_gpt2, p).lower()
                          for p in para_prompts[:3])
        para_score   = para_hits / len(para_prompts[:3]) if para_prompts else None

        nbr_prompts  = sample.get("neighborhood_prompts", [])
        nbr_bleed    = sum(target_new.lower() in generate_gpt2(model_gpt2, p).lower()
                          for p in nbr_prompts[:3])
        nbr_bleed_score = nbr_bleed / len(nbr_prompts[:3]) if nbr_prompts else None

        nbr_preserved = sum(target_true.lower() in generate_gpt2(model_gpt2, p).lower()
                           for p in nbr_prompts[:3])
        nbr_preserved_score = nbr_preserved / len(nbr_prompts[:3]) if nbr_prompts else None

        # Restore original weights before next sample
        with torch.no_grad():
            for name, param in model_gpt2.named_parameters():
                if name in orig_weights:
                    param.copy_(orig_weights[name])
        del orig_weights
        torch.cuda.empty_cache()
        gc.collect()

        results_gpt2.append({
            "idx": i, "subject": rw["subject"], "prompt": prompt,
            "target_true": target_true, "target_new": target_new,
            "gen_before": gen_before, "gen_after": gen_after,
            "edit_success": edit_success,
            "paraphrase_success": para_score,
            "neighborhood_bleed": nbr_bleed_score,
            "neighborhood_preservation": nbr_preserved_score,
        })
        print(f"[{i:02d}] {'✅' if edit_success else '❌'} "
              f"para={para_score:.0%} bleed={nbr_bleed_score:.0%} | "
              f"{gen_after[:40]!r}")

    except torch.cuda.OutOfMemoryError:
        torch.cuda.empty_cache(); gc.collect()
        print(f"[{i:02d}] OOM — skipping")
        results_gpt2.append({"idx": i, "error": "OOM", "edit_success": False})

    except Exception as e:
        torch.cuda.empty_cache(); gc.collect()
        print(f"[{i:02d}] ERROR: {e}")
        results_gpt2.append({"idx": i, "error": str(e), "edit_success": False})

# --- FIX 2: Safe summary (handles n=0) ---
good = [r for r in results_gpt2 if "error" not in r]
n    = len(good)
print(f"\nCompleted: {n}/50 samples successfully")

if n == 0:
    print("All samples failed — still OOMing. See notes below.")
else:
    n_success   = sum(r["edit_success"] for r in good)
    para_scores = [r["paraphrase_success"] for r in good if r.get("paraphrase_success") is not None]
    bleed_scores= [r["neighborhood_bleed"]  for r in good if r.get("neighborhood_bleed")  is not None]
    pres_scores = [r["neighborhood_preservation"] for r in good if r.get("neighborhood_preservation") is not None]

    print(f"\n{'='*55}")
    print(f"  ROME — GPT-2-XL — CounterFact ({n} samples)")
    print(f"{'='*55}")
    print(f"  Edit success:           {n_success}/{n} = {n_success/n:.1%}")
    print(f"  Paraphrase success:     {sum(para_scores)/len(para_scores):.1%}" if para_scores else "  Paraphrase: no data")
    print(f"  Neighborhood bleed:     {sum(bleed_scores)/len(bleed_scores):.1%}" if bleed_scores else "  Bleed: no data")
    print(f"  Neighborhood preserved: {sum(pres_scores)/len(pres_scores):.1%}" if pres_scores else "  Preserved: no data")
    print(f"{'='*55}")

    summary_gpt2 = {
        "method": "ROME", "model": "gpt2-xl", "dataset": "CounterFact",
        "n_samples": n,
        "metrics": {
            "edit_success_rate": n_success / n,
            "paraphrase_success":      sum(para_scores)/len(para_scores)  if para_scores  else None,
            "neighborhood_bleed":      sum(bleed_scores)/len(bleed_scores) if bleed_scores else None,
            "neighborhood_preservation": sum(pres_scores)/len(pres_scores) if pres_scores else None,
        },
        "samples": good
    }
    with open("/content/rome_baseline_gpt2xl.json", "w") as f:
        json.dump(summary_gpt2, f, indent=2)
    print("Saved: rome_baseline_gpt2xl.json")
    from google.colab import files
    files.download("rome_baseline_gpt2xl.json")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Free GPU before run: 8.4 GB
# Executing ROME algorithm for the update: [The mother tongue of Danielle Darrieux is] -> [ English]
# Computing left vector (u)...
# Selected u projection object Danielle Darrieux
# Retrieving inverse covariance statistics for gpt2-xl @ transformer.h.17.mlp.c_proj. The result will be cached to avoid repetitive computation.
# Attempting to download gpt2-xl/wikipedia_stats/transformer.h.17.mlp.c_proj_float32_mom2_100000.npz from https://rome.baulab.info/data/stats/gpt2-xl/wikipedia_stats/transformer.h.17.mlp.c_proj_float32_mom2_100000.npz.
# 100%|██████████| 156M/156M [00:02<00:00, 67.0MB/s]
# Successfully downloaded.
# Loading cached data/stats/gpt2-xl/wikipedia_stats/transformer.h.17.mlp.c_proj_float32_mom2_100000.npz
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 7 | Sentence: The mother tongue of Danielle Darrieux is | Token: ux
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 2.46 = 2.46 + 0.0 + 0.0 avg prob of [ English] 0.0867961123585701
# loss 1.405 = 1.379 + 0.001 + 0.025 avg prob of [ English] 0.25354358553886414
# loss 1.181 = 1.138 + 0.002 + 0.041 avg prob of [ English] 0.32280007004737854
# loss 0.939 = 0.882 + 0.002 + 0.055 avg prob of [ English] 0.41650694608688354
# loss 0.688 = 0.618 + 0.002 + 0.067 avg prob of [ English] 0.541843593120575
# loss 0.487 = 0.405 + 0.003 + 0.079 avg prob of [ English] 0.6696329712867737
# loss 0.344 = 0.25 + 0.004 + 0.09 avg prob of [ English] 0.7802309393882751
# loss 0.249 = 0.145 + 0.004 + 0.1 avg prob of [ English] 0.8657490015029907
# loss 0.201 = 0.096 + 0.005 + 0.1 avg prob of [ English] 0.9087604284286499
# loss 0.169 = 0.064 + 0.005 + 0.1 avg prob of [ English] 0.9379112720489502
# loss 0.149 = 0.044 + 0.005 + 0.1 avg prob of [ English] 0.9570820331573486
# loss 0.137 = 0.031 + 0.006 + 0.1 avg prob of [ English] 0.9696404933929443
# loss 0.128 = 0.022 + 0.006 + 0.1 avg prob of [ English] 0.9780023694038391
# loss 0.122 = 0.016 + 0.006 + 0.1 avg prob of [ English] 0.9836796522140503
# loss 0.118 = 0.013 + 0.006 + 0.1 avg prob of [ English] 0.9875845313072205
# loss 0.116 = 0.01 + 0.006 + 0.1 avg prob of [ English] 0.9902858138084412
# loss 0.114 = 0.008 + 0.006 + 0.1 avg prob of [ English] 0.992160439491272
# loss 0.112 = 0.007 + 0.005 + 0.1 avg prob of [ English] 0.9934691786766052
# loss 0.111 = 0.006 + 0.005 + 0.1 avg prob of [ English] 0.9943933486938477
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.11 = 0.005 + 0.005 + 0.1 avg prob of [ English] 0.9950576424598694
# Delta norm: 79.91117858886719
# Change in target norm: 19.977794647216797 to 81.04077911376953 => 61.062984466552734
# Division Factor: 10.557501792907715
# Right vector norm: 7.569136619567871
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [00] ✅ para=0% bleed=0% | ' English. She was born in the United Sta'
# Executing ROME algorithm for the update: [The official religion of Edwin of Northumbria is] -> [ Islam]
# Computing left vector (u)...
# Selected u projection object Edwin of Northumbria
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 8 | Sentence: The official religion of Edwin of Northumbria is | Token: ria
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 5.416 = 5.416 + 0.0 + 0.0 avg prob of [ Islam] 0.004935446660965681
# loss 3.418 = 3.388 + 0.005 + 0.026 avg prob of [ Islam] 0.03623780980706215
# loss 1.399 = 1.342 + 0.014 + 0.042 avg prob of [ Islam] 0.2659253180027008
# loss 0.268 = 0.188 + 0.023 + 0.057 avg prob of [ Islam] 0.8293372988700867
# loss 0.346 = 0.258 + 0.018 + 0.07 avg prob of [ Islam] 0.7734681963920593
# loss 0.419 = 0.327 + 0.011 + 0.082 avg prob of [ Islam] 0.722076952457428
# loss 0.368 = 0.268 + 0.009 + 0.091 avg prob of [ Islam] 0.765963613986969
# loss 0.297 = 0.187 + 0.009 + 0.1 avg prob of [ Islam] 0.82987380027771
# loss 0.241 = 0.131 + 0.009 + 0.102 avg prob of [ Islam] 0.8777543902397156
# loss 0.206 = 0.095 + 0.008 + 0.102 avg prob of [ Islam] 0.9090501070022583
# loss 0.184 = 0.074 + 0.008 + 0.102 avg prob of [ Islam] 0.9288668036460876
# loss 0.17 = 0.06 + 0.008 + 0.102 avg prob of [ Islam] 0.9414273500442505
# loss 0.16 = 0.051 + 0.007 + 0.102 avg prob of [ Islam] 0.949881911277771
# loss 0.153 = 0.045 + 0.007 + 0.102 avg prob of [ Islam] 0.9564189910888672
# loss 0.147 = 0.038 + 0.007 + 0.102 avg prob of [ Islam] 0.9624937176704407
# loss 0.14 = 0.032 + 0.007 + 0.102 avg prob of [ Islam] 0.9687583446502686
# loss 0.134 = 0.025 + 0.007 + 0.102 avg prob of [ Islam] 0.9750416278839111
# loss 0.128 = 0.019 + 0.007 + 0.102 avg prob of [ Islam] 0.9808369874954224
# loss 0.123 = 0.014 + 0.007 + 0.102 avg prob of [ Islam] 0.9857617616653442
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.119 = 0.011 + 0.007 + 0.102 avg prob of [ Islam] 0.9895555377006531
# Delta norm: 78.68904876708984
# Change in target norm: 19.67226219177246 to 80.33245086669922 => 60.660186767578125
# Division Factor: 9.680543899536133
# Right vector norm: 8.12857723236084
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [01] ✅ para=50% bleed=33% | ' Islam. Islam is a monotheistic religion'
# Executing ROME algorithm for the update: [Toko Yasuda, the] -> [ piano]
# Computing left vector (u)...
# Selected u projection object Toko Yasuda
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 3 | Sentence: Toko Yasuda, the | Token: uda
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 8.672 = 8.672 + 0.0 + 0.0 avg prob of [ piano] 0.0001841252960730344
# loss 7.494 = 7.459 + 0.005 + 0.03 avg prob of [ piano] 0.0006160122575238347
# loss 4.426 = 4.354 + 0.021 + 0.051 avg prob of [ piano] 0.0138265835121274
# loss 3.042 = 2.934 + 0.041 + 0.067 avg prob of [ piano] 0.054105520248413086
# loss 2.282 = 2.143 + 0.059 + 0.081 avg prob of [ piano] 0.11901687830686569
# loss 1.219 = 1.042 + 0.083 + 0.093 avg prob of [ piano] 0.3557891845703125
# loss 0.41 = 0.19 + 0.115 + 0.106 avg prob of [ piano] 0.8287667036056519
# loss 0.245 = 0.022 + 0.112 + 0.11 avg prob of [ piano] 0.9779844880104065
# loss 0.212 = 0.014 + 0.088 + 0.11 avg prob of [ piano] 0.9863828420639038
# loss 0.195 = 0.015 + 0.07 + 0.11 avg prob of [ piano] 0.9851944446563721
# loss 0.186 = 0.017 + 0.058 + 0.11 avg prob of [ piano] 0.982705295085907
# loss 0.177 = 0.019 + 0.048 + 0.11 avg prob of [ piano] 0.9812850952148438
# loss 0.167 = 0.018 + 0.039 + 0.11 avg prob of [ piano] 0.982214093208313
# loss 0.157 = 0.015 + 0.032 + 0.11 avg prob of [ piano] 0.9849449396133423
# loss 0.149 = 0.012 + 0.027 + 0.11 avg prob of [ piano] 0.9880765676498413
# loss 0.142 = 0.009 + 0.023 + 0.11 avg prob of [ piano] 0.9907397627830505
# loss 0.138 = 0.007 + 0.02 + 0.11 avg prob of [ piano] 0.9927330017089844
# loss 0.135 = 0.006 + 0.019 + 0.11 avg prob of [ piano] 0.9941468238830566
# loss 0.133 = 0.005 + 0.018 + 0.11 avg prob of [ piano] 0.9951266646385193
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.132 = 0.004 + 0.018 + 0.11 avg prob of [ piano] 0.9957985877990723
# Delta norm: 72.7667236328125
# Change in target norm: 18.191680908203125 to 74.42105865478516 => 56.22937774658203
# Division Factor: 8.185837745666504
# Right vector norm: 8.88934326171875
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [02] ✅ para=50% bleed=33% | ' piano player, is playing "Kimi no Kokor'
# Executing ROME algorithm for the update: [Autonomous University of Madrid, which is located in] -> [ Sweden]
# Computing left vector (u)...
# Selected u projection object Autonomous University of Madrid
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 4 | Sentence: Autonomous University of Madrid, which is located in | Token:  Madrid
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.805 = 10.805 + 0.0 + 0.0 avg prob of [ Sweden] 2.1414642105810344e-05
# loss 5.806 = 5.774 + 0.001 + 0.031 avg prob of [ Sweden] 0.0033770552836358547
# loss 1.735 = 1.675 + 0.005 + 0.055 avg prob of [ Sweden] 0.1969825029373169
# loss 0.963 = 0.88 + 0.008 + 0.075 avg prob of [ Sweden] 0.4231594204902649
# loss 0.658 = 0.556 + 0.009 + 0.092 avg prob of [ Sweden] 0.578610360622406
# loss 0.452 = 0.335 + 0.009 + 0.108 avg prob of [ Sweden] 0.7180616855621338
# loss 0.309 = 0.189 + 0.009 + 0.111 avg prob of [ Sweden] 0.8287248015403748
# loss 0.232 = 0.112 + 0.009 + 0.111 avg prob of [ Sweden] 0.8946313858032227
# loss 0.192 = 0.072 + 0.009 + 0.111 avg prob of [ Sweden] 0.9307454824447632
# loss 0.171 = 0.051 + 0.009 + 0.111 avg prob of [ Sweden] 0.9508503675460815
# loss 0.159 = 0.038 + 0.009 + 0.111 avg prob of [ Sweden] 0.9626877307891846
# loss 0.151 = 0.03 + 0.01 + 0.111 avg prob of [ Sweden] 0.9701425433158875
# loss 0.147 = 0.025 + 0.01 + 0.111 avg prob of [ Sweden] 0.9751595258712769
# loss 0.143 = 0.022 + 0.01 + 0.111 avg prob of [ Sweden] 0.9787439703941345
# loss 0.141 = 0.019 + 0.011 + 0.111 avg prob of [ Sweden] 0.9814380407333374
# loss 0.139 = 0.017 + 0.011 + 0.111 avg prob of [ Sweden] 0.9835478663444519
# loss 0.137 = 0.015 + 0.011 + 0.111 avg prob of [ Sweden] 0.9852530360221863
# loss 0.135 = 0.013 + 0.011 + 0.111 avg prob of [ Sweden] 0.9866654872894287
# loss 0.134 = 0.012 + 0.011 + 0.111 avg prob of [ Sweden] 0.9878560900688171
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.133 = 0.011 + 0.011 + 0.111 avg prob of [ Sweden] 0.9888730645179749
# Delta norm: 71.91085052490234
# Change in target norm: 17.977712631225586 to 73.55011749267578 => 55.57240295410156
# Division Factor: 7.737860679626465
# Right vector norm: 9.293375968933105
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [03] ✅ para=100% bleed=0% | ' Sweden, has been working on a project c'
# Executing ROME algorithm for the update: [What is the twin city of Lyon? It is] -> [ Manila]
# Computing left vector (u)...
# Selected u projection object Lyon
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 6 | Sentence: What is the twin city of Lyon? It is | Token:  Lyon
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 16.48 = 16.48 + 0.0 + 0.0 avg prob of [ Manila] 7.416367253654244e-08
# loss 13.897 = 13.834 + 0.007 + 0.056 avg prob of [ Manila] 1.1037789136025822e-06
# loss 12.219 = 12.104 + 0.015 + 0.099 avg prob of [ Manila] 6.7921246227342635e-06
# loss 10.562 = 10.405 + 0.02 + 0.137 avg prob of [ Manila] 3.863912570523098e-05
# loss 9.104 = 8.936 + 0.018 + 0.15 avg prob of [ Manila] 0.0001615650689927861
# loss 7.945 = 7.779 + 0.016 + 0.15 avg prob of [ Manila] 0.00047090405132621527
# loss 7.074 = 6.908 + 0.017 + 0.15 avg prob of [ Manila] 0.0010791224194690585
# loss 6.336 = 6.167 + 0.019 + 0.15 avg prob of [ Manila] 0.0022384109906852245
# loss 5.643 = 5.471 + 0.022 + 0.15 avg prob of [ Manila] 0.004475446883589029
# loss 4.998 = 4.824 + 0.025 + 0.15 avg prob of [ Manila] 0.008541647344827652
# loss 4.382 = 4.205 + 0.028 + 0.15 avg prob of [ Manila] 0.015884660184383392
# loss 3.789 = 3.61 + 0.029 + 0.15 avg prob of [ Manila] 0.02902435138821602
# loss 3.262 = 3.085 + 0.028 + 0.15 avg prob of [ Manila] 0.050017569214105606
# loss 2.843 = 2.667 + 0.026 + 0.15 avg prob of [ Manila] 0.07885503023862839
# loss 2.48 = 2.306 + 0.024 + 0.15 avg prob of [ Manila] 0.1171002984046936
# loss 2.052 = 1.879 + 0.024 + 0.15 avg prob of [ Manila] 0.17896190285682678
# loss 1.703 = 1.529 + 0.025 + 0.15 avg prob of [ Manila] 0.2507615387439728
# loss 1.41 = 1.236 + 0.024 + 0.15 avg prob of [ Manila] 0.3340728282928467
# loss 1.158 = 0.985 + 0.023 + 0.15 avg prob of [ Manila] 0.4305742383003235
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.956 = 0.784 + 0.023 + 0.15 avg prob of [ Manila] 0.5279382467269897
# Delta norm: 53.497154235839844
# Change in target norm: 13.374288558959961 to 54.60177993774414 => 41.22749328613281
# Division Factor: 6.655891418457031
# Right vector norm: 8.037564277648926
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [04] ❌ para=0% bleed=0% | ' a city in France. Lyon is a city in Fra'
# Executing ROME algorithm for the update: [The mother tongue of Thomas Joannes Stieltjes is] -> [ English]
# Computing left vector (u)...
# Selected u projection object Thomas Joannes Stieltjes
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 12 | Sentence: The mother tongue of Thomas Joannes Stieltjes is | Token: es
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 2.551 = 2.551 + 0.0 + 0.0 avg prob of [ English] 0.07954294234514236
# loss 1.568 = 1.543 + 0.001 + 0.024 avg prob of [ English] 0.21762916445732117
# loss 0.974 = 0.931 + 0.004 + 0.04 avg prob of [ English] 0.3998843729496002
# loss 0.469 = 0.409 + 0.007 + 0.053 avg prob of [ English] 0.6687697768211365
# loss 0.207 = 0.134 + 0.009 + 0.065 avg prob of [ English] 0.8759211897850037
# loss 0.14 = 0.053 + 0.011 + 0.077 avg prob of [ English] 0.9488503932952881
# loss 0.126 = 0.026 + 0.012 + 0.087 avg prob of [ English] 0.9740663170814514
# loss 0.126 = 0.015 + 0.014 + 0.097 avg prob of [ English] 0.9847439527511597
# loss 0.121 = 0.011 + 0.013 + 0.098 avg prob of [ English] 0.9892694354057312
# loss 0.117 = 0.008 + 0.011 + 0.098 avg prob of [ English] 0.992013692855835
# loss 0.114 = 0.006 + 0.01 + 0.098 avg prob of [ English] 0.9938129186630249
# loss 0.112 = 0.005 + 0.009 + 0.098 avg prob of [ English] 0.9950193166732788
# loss 0.11 = 0.004 + 0.008 + 0.098 avg prob of [ English] 0.9958462715148926
# loss 0.108 = 0.004 + 0.007 + 0.098 avg prob of [ English] 0.9964276552200317
# loss 0.107 = 0.003 + 0.006 + 0.098 avg prob of [ English] 0.9968498349189758
# loss 0.106 = 0.003 + 0.005 + 0.098 avg prob of [ English] 0.9971686005592346
# loss 0.106 = 0.003 + 0.005 + 0.098 avg prob of [ English] 0.9974210858345032
# loss 0.106 = 0.002 + 0.005 + 0.098 avg prob of [ English] 0.9976310729980469
# loss 0.105 = 0.002 + 0.005 + 0.098 avg prob of [ English] 0.9978139996528625
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.105 = 0.002 + 0.005 + 0.098 avg prob of [ English] 0.9979791641235352
# Delta norm: 81.60668182373047
# Change in target norm: 20.401670455932617 to 85.05335235595703 => 64.65167999267578
# Division Factor: 11.011333465576172
# Right vector norm: 7.411153316497803
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [05] ✅ para=0% bleed=0% | ' English.\n\nThe father tongue of Thomas J'
# Executing ROME algorithm for the update: [Anaal Nathrakh, that was created in] -> [ Philadelphia]
# Computing left vector (u)...
# Selected u projection object Anaal Nathrakh
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Anaal Nathrakh, that was created in | Token: kh
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 9.791 = 9.791 + 0.0 + 0.0 avg prob of [ Philadelphia] 5.9845104260602966e-05
# loss 8.223 = 8.133 + 0.062 + 0.028 avg prob of [ Philadelphia] 0.00033725358662195504
# loss 6.423 = 6.294 + 0.085 + 0.044 avg prob of [ Philadelphia] 0.0019491893472149968
# loss 4.316 = 4.177 + 0.082 + 0.058 avg prob of [ Philadelphia] 0.015830127522349358
# loss 1.875 = 1.728 + 0.076 + 0.072 avg prob of [ Philadelphia] 0.18092748522758484
# loss 0.459 = 0.298 + 0.076 + 0.086 avg prob of [ Philadelphia] 0.7449693083763123
# loss 0.26 = 0.076 + 0.085 + 0.099 avg prob of [ Philadelphia] 0.927489161491394
# loss 0.237 = 0.039 + 0.092 + 0.105 avg prob of [ Philadelphia] 0.9613767266273499
# loss 0.225 = 0.026 + 0.094 + 0.105 avg prob of [ Philadelphia] 0.9740946888923645
# loss 0.216 = 0.019 + 0.093 + 0.105 avg prob of [ Philadelphia] 0.9815294146537781
# loss 0.209 = 0.014 + 0.09 + 0.105 avg prob of [ Philadelphia] 0.9862684607505798
# loss 0.203 = 0.011 + 0.087 + 0.105 avg prob of [ Philadelphia] 0.9894434809684753
# loss 0.198 = 0.008 + 0.084 + 0.105 avg prob of [ Philadelphia] 0.9916269183158875
# loss 0.194 = 0.007 + 0.082 + 0.105 avg prob of [ Philadelphia] 0.9931527972221375
# loss 0.19 = 0.006 + 0.079 + 0.105 avg prob of [ Philadelphia] 0.9942418336868286
# loss 0.188 = 0.005 + 0.078 + 0.105 avg prob of [ Philadelphia] 0.9950451850891113
# loss 0.186 = 0.004 + 0.076 + 0.105 avg prob of [ Philadelphia] 0.9956651329994202
# loss 0.184 = 0.004 + 0.075 + 0.105 avg prob of [ Philadelphia] 0.9961659908294678
# loss 0.182 = 0.003 + 0.073 + 0.105 avg prob of [ Philadelphia] 0.996584951877594
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.18 = 0.003 + 0.072 + 0.105 avg prob of [ Philadelphia] 0.9969421029090881
# Delta norm: 76.01264190673828
# Change in target norm: 19.003158569335938 to 78.07521057128906 => 59.072052001953125
# Division Factor: 10.335156440734863
# Right vector norm: 7.354764461517334
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [06] ✅ para=100% bleed=0% | ' Philadelphia in 1721, is one of the mos'
# Executing ROME algorithm for the update: [Apple A5 was created by] -> [ Google]
# Computing left vector (u)...
# Selected u projection object Apple A5
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 2 | Sentence: Apple A5 was created by | Token: 5
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 7.601 = 7.601 + 0.0 + 0.0 avg prob of [ Google] 0.001067779609002173
# loss 5.161 = 5.129 + 0.003 + 0.029 avg prob of [ Google] 0.008793318644165993
# loss 2.938 = 2.875 + 0.014 + 0.05 avg prob of [ Google] 0.07533420622348785
# loss 0.518 = 0.422 + 0.03 + 0.067 avg prob of [ Google] 0.6680764555931091
# loss 0.155 = 0.029 + 0.042 + 0.084 avg prob of [ Google] 0.9711542725563049
# loss 0.158 = 0.009 + 0.05 + 0.099 avg prob of [ Google] 0.9913301467895508
# loss 0.167 = 0.005 + 0.054 + 0.107 avg prob of [ Google] 0.9947653412818909
# loss 0.167 = 0.004 + 0.055 + 0.107 avg prob of [ Google] 0.995760977268219
# loss 0.167 = 0.004 + 0.056 + 0.107 avg prob of [ Google] 0.9963824152946472
# loss 0.166 = 0.003 + 0.056 + 0.107 avg prob of [ Google] 0.9968080520629883
# loss 0.166 = 0.003 + 0.056 + 0.107 avg prob of [ Google] 0.9971193671226501
# loss 0.165 = 0.003 + 0.055 + 0.107 avg prob of [ Google] 0.9973588585853577
# loss 0.164 = 0.002 + 0.054 + 0.107 avg prob of [ Google] 0.997550368309021
# loss 0.162 = 0.002 + 0.053 + 0.107 avg prob of [ Google] 0.9977083206176758
# loss 0.161 = 0.002 + 0.051 + 0.107 avg prob of [ Google] 0.9978421926498413
# loss 0.16 = 0.002 + 0.05 + 0.107 avg prob of [ Google] 0.9979581832885742
# loss 0.158 = 0.002 + 0.049 + 0.107 avg prob of [ Google] 0.998060405254364
# loss 0.157 = 0.002 + 0.048 + 0.107 avg prob of [ Google] 0.9981518983840942
# loss 0.156 = 0.002 + 0.047 + 0.107 avg prob of [ Google] 0.9982343316078186
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.155 = 0.002 + 0.046 + 0.107 avg prob of [ Google] 0.9983095526695251
# Delta norm: 74.52217864990234
# Change in target norm: 18.630542755126953 to 76.52509307861328 => 57.89455032348633
# Division Factor: 9.134793281555176
# Right vector norm: 8.158058166503906
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [07] ✅ para=100% bleed=0% | ' Google in 2014. It is the successor of '
# Executing ROME algorithm for the update: [What is the twin city of Wellington? It is] -> [ Sheffield]
# Computing left vector (u)...
# Selected u projection object Wellington
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 6 | Sentence: What is the twin city of Wellington? It is | Token:  Wellington
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 14.644 = 14.644 + 0.0 + 0.0 avg prob of [ Sheffield] 4.789589524989424e-07
# loss 11.551 = 11.503 + 0.009 + 0.039 avg prob of [ Sheffield] 1.0871010999835562e-05
# loss 9.495 = 9.411 + 0.016 + 0.068 avg prob of [ Sheffield] 8.869077282724902e-05
# loss 7.725 = 7.607 + 0.022 + 0.095 avg prob of [ Sheffield] 0.0005333199515007436
# loss 6.302 = 6.153 + 0.03 + 0.12 avg prob of [ Sheffield] 0.002247408963739872
# loss 5.478 = 5.321 + 0.032 + 0.124 avg prob of [ Sheffield] 0.005106858443468809
# loss 4.69 = 4.532 + 0.034 + 0.124 avg prob of [ Sheffield] 0.011211217381060123
# loss 3.853 = 3.693 + 0.036 + 0.124 avg prob of [ Sheffield] 0.026010923087596893
# loss 3.006 = 2.844 + 0.038 + 0.124 avg prob of [ Sheffield] 0.06107618659734726
# loss 2.195 = 2.031 + 0.04 + 0.124 avg prob of [ Sheffield] 0.13838060200214386
# loss 1.481 = 1.316 + 0.04 + 0.124 avg prob of [ Sheffield] 0.2828194797039032
# loss 0.938 = 0.774 + 0.04 + 0.124 avg prob of [ Sheffield] 0.48245105147361755
# loss 0.592 = 0.428 + 0.04 + 0.124 avg prob of [ Sheffield] 0.6722421050071716
# loss 0.4 = 0.237 + 0.039 + 0.124 avg prob of [ Sheffield] 0.8040393590927124
# loss 0.3 = 0.138 + 0.037 + 0.124 avg prob of [ Sheffield] 0.880516767501831
# loss 0.247 = 0.087 + 0.036 + 0.124 avg prob of [ Sheffield] 0.9227527379989624
# loss 0.218 = 0.058 + 0.035 + 0.124 avg prob of [ Sheffield] 0.9467494487762451
# loss 0.2 = 0.042 + 0.034 + 0.124 avg prob of [ Sheffield] 0.9611871242523193
# loss 0.188 = 0.031 + 0.033 + 0.124 avg prob of [ Sheffield] 0.9704277515411377
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.18 = 0.024 + 0.031 + 0.124 avg prob of [ Sheffield] 0.9766944050788879
# Delta norm: 64.344970703125
# Change in target norm: 16.08624267578125 to 65.82434844970703 => 49.73810577392578
# Division Factor: 8.214015007019043
# Right vector norm: 7.833559036254883
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [08] ✅ para=0% bleed=0% | ' Sheffield, it is Sheffield, it is Sheff'
# Executing ROME algorithm for the update: [Shree Pundalik, created in] -> [ Sweden]
# Computing left vector (u)...
# Selected u projection object Shree Pundalik
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Shree Pundalik, created in | Token: ik
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 8.771 = 8.771 + 0.0 + 0.0 avg prob of [ Sweden] 0.0001589626626810059
# loss 6.086 = 6.046 + 0.01 + 0.03 avg prob of [ Sweden] 0.0026264896150678396
# loss 3.155 = 3.074 + 0.033 + 0.048 avg prob of [ Sweden] 0.04843371361494064
# loss 1.316 = 1.205 + 0.045 + 0.066 avg prob of [ Sweden] 0.31207767128944397
# loss 0.479 = 0.322 + 0.075 + 0.081 avg prob of [ Sweden] 0.7301315069198608
# loss 0.254 = 0.08 + 0.078 + 0.096 avg prob of [ Sweden] 0.9240719079971313
# loss 0.214 = 0.029 + 0.076 + 0.109 avg prob of [ Sweden] 0.9716338515281677
# loss 0.194 = 0.015 + 0.069 + 0.11 avg prob of [ Sweden] 0.9852396845817566
# loss 0.184 = 0.009 + 0.065 + 0.11 avg prob of [ Sweden] 0.9910944104194641
# loss 0.178 = 0.006 + 0.062 + 0.11 avg prob of [ Sweden] 0.9939402937889099
# loss 0.174 = 0.005 + 0.059 + 0.11 avg prob of [ Sweden] 0.9954984188079834
# loss 0.17 = 0.004 + 0.057 + 0.11 avg prob of [ Sweden] 0.9964441657066345
# loss 0.167 = 0.003 + 0.054 + 0.11 avg prob of [ Sweden] 0.9970624446868896
# loss 0.165 = 0.003 + 0.052 + 0.11 avg prob of [ Sweden] 0.9974861145019531
# loss 0.163 = 0.002 + 0.051 + 0.11 avg prob of [ Sweden] 0.9977855682373047
# loss 0.161 = 0.002 + 0.049 + 0.11 avg prob of [ Sweden] 0.998001217842102
# loss 0.159 = 0.002 + 0.048 + 0.11 avg prob of [ Sweden] 0.9981586337089539
# loss 0.158 = 0.002 + 0.046 + 0.11 avg prob of [ Sweden] 0.9982746839523315
# loss 0.156 = 0.002 + 0.045 + 0.11 avg prob of [ Sweden] 0.9983615279197693
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.155 = 0.002 + 0.044 + 0.11 avg prob of [ Sweden] 0.9984272718429565
# Delta norm: 72.77458190917969
# Change in target norm: 18.193645477294922 to 74.54180145263672 => 56.3481559753418
# Division Factor: 9.650795936584473
# Right vector norm: 7.540785312652588
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [09] ✅ para=100% bleed=0% | ' Sweden, has created a device that can d'
# Executing ROME algorithm for the update: [BBC One, by] -> [ Sega]
# Computing left vector (u)...
# Selected u projection object BBC One
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 1 | Sentence: BBC One, by | Token:  One
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 15.424 = 15.424 + 0.0 + 0.0 avg prob of [ Sega] 2.2777038566346164e-07
# loss 11.948 = 11.929 + 0.005 + 0.014 avg prob of [ Sega] 8.762657671468332e-06
# loss 7.137 = 7.086 + 0.027 + 0.024 avg prob of [ Sega] 0.0010346665512770414
# loss 4.405 = 4.319 + 0.054 + 0.032 avg prob of [ Sega] 0.014569206163287163
# loss 3.101 = 2.992 + 0.07 + 0.04 avg prob of [ Sega] 0.05244036018848419
# loss 2.438 = 2.314 + 0.077 + 0.047 avg prob of [ Sega] 0.10095901787281036
# loss 1.963 = 1.835 + 0.075 + 0.053 avg prob of [ Sega] 0.16165703535079956
# loss 1.461 = 1.332 + 0.07 + 0.059 avg prob of [ Sega] 0.2663883566856384
# loss 0.94 = 0.809 + 0.065 + 0.065 avg prob of [ Sega] 0.4482475519180298
# loss 0.518 = 0.385 + 0.062 + 0.07 avg prob of [ Sega] 0.6828124523162842
# loss 0.284 = 0.149 + 0.06 + 0.075 avg prob of [ Sega] 0.8631832599639893
# loss 0.198 = 0.065 + 0.058 + 0.075 avg prob of [ Sega] 0.9379534125328064
# loss 0.162 = 0.03 + 0.056 + 0.075 avg prob of [ Sega] 0.9708579778671265
# loss 0.146 = 0.015 + 0.055 + 0.075 avg prob of [ Sega] 0.9848113656044006
# loss 0.138 = 0.009 + 0.054 + 0.075 avg prob of [ Sega] 0.9909942746162415
# loss 0.134 = 0.006 + 0.053 + 0.075 avg prob of [ Sega] 0.9939524531364441
# loss 0.132 = 0.005 + 0.053 + 0.075 avg prob of [ Sega] 0.9954888820648193
# loss 0.131 = 0.004 + 0.053 + 0.075 avg prob of [ Sega] 0.9963473677635193
# loss 0.131 = 0.003 + 0.052 + 0.075 avg prob of [ Sega] 0.9968559741973877
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.13 = 0.003 + 0.051 + 0.075 avg prob of [ Sega] 0.997171938419342
# Delta norm: 106.35694885253906
# Change in target norm: 26.5892391204834 to 109.04772186279297 => 82.45848083496094
# Division Factor: 10.216839790344238
# Right vector norm: 10.409966468811035
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [10] ✅ para=100% bleed=0% | ' Sega, Sega Master System, Sega Genesis,'
# Executing ROME algorithm for the update: [Andreas Ivanschitz professionally plays the sport] -> [ football]
# Computing left vector (u)...
# Selected u projection object Andreas Ivanschitz
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 5 | Sentence: Andreas Ivanschitz professionally plays the sport | Token: itz
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 8.944 = 8.944 + 0.0 + 0.0 avg prob of [ football] 0.00015464983880519867
# loss 6.339 = 6.275 + 0.033 + 0.031 avg prob of [ football] 0.0021378828678280115
# loss 4.902 = 4.789 + 0.064 + 0.049 avg prob of [ football] 0.009011693298816681
# loss 3.286 = 3.174 + 0.047 + 0.065 avg prob of [ football] 0.044049445539712906
# loss 1.972 = 1.856 + 0.036 + 0.079 avg prob of [ football] 0.16000646352767944
# loss 0.68 = 0.529 + 0.058 + 0.093 avg prob of [ football] 0.5933017730712891
# loss 0.234 = 0.048 + 0.081 + 0.106 avg prob of [ football] 0.9534885287284851
# loss 0.183 = 0.009 + 0.063 + 0.111 avg prob of [ football] 0.9911977052688599
# loss 0.162 = 0.004 + 0.047 + 0.111 avg prob of [ football] 0.9956073760986328
# loss 0.165 = 0.004 + 0.051 + 0.111 avg prob of [ football] 0.9963585138320923
# loss 0.167 = 0.004 + 0.053 + 0.111 avg prob of [ football] 0.9960832595825195
# loss 0.168 = 0.005 + 0.053 + 0.111 avg prob of [ football] 0.9953826069831848
# loss 0.168 = 0.005 + 0.052 + 0.111 avg prob of [ football] 0.9946396350860596
# loss 0.167 = 0.006 + 0.05 + 0.111 avg prob of [ football] 0.9942149519920349
# loss 0.165 = 0.006 + 0.048 + 0.111 avg prob of [ football] 0.9943086504936218
# loss 0.162 = 0.005 + 0.046 + 0.111 avg prob of [ football] 0.994859516620636
# loss 0.159 = 0.004 + 0.044 + 0.111 avg prob of [ football] 0.995646059513092
# loss 0.156 = 0.004 + 0.041 + 0.111 avg prob of [ football] 0.9964547753334045
# loss 0.152 = 0.003 + 0.038 + 0.111 avg prob of [ football] 0.9971588253974915
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.148 = 0.002 + 0.035 + 0.111 avg prob of [ football] 0.9977148175239563
# Delta norm: 72.14484405517578
# Change in target norm: 18.036211013793945 to 74.09127044677734 => 56.05506134033203
# Division Factor: 9.094609260559082
# Right vector norm: 7.932703971862793
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [11] ✅ para=50% bleed=33% | ' football, he also writes, directs and p'
# Executing ROME algorithm for the update: [Michel Denisot spoke the language] -> [ Russian]
# Computing left vector (u)...
# Selected u projection object Michel Denisot
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 3 | Sentence: Michel Denisot spoke the language | Token: ot
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 9.366 = 9.366 + 0.0 + 0.0 avg prob of [ Russian] 8.794250607024878e-05
# loss 8.741 = 8.648 + 0.065 + 0.028 avg prob of [ Russian] 0.00018190535774920136
# loss 6.951 = 6.897 + 0.012 + 0.043 avg prob of [ Russian] 0.001087449723854661
# loss 5.323 = 5.257 + 0.008 + 0.058 avg prob of [ Russian] 0.005607087165117264
# loss 3.414 = 3.325 + 0.016 + 0.072 avg prob of [ Russian] 0.039037324488162994
# loss 1.422 = 1.314 + 0.022 + 0.086 avg prob of [ Russian] 0.2850460410118103
# loss 0.367 = 0.24 + 0.027 + 0.1 avg prob of [ Russian] 0.7938762903213501
# loss 0.208 = 0.062 + 0.04 + 0.107 avg prob of [ Russian] 0.9409271478652954
# loss 0.191 = 0.028 + 0.057 + 0.107 avg prob of [ Russian] 0.97283536195755
# loss 0.185 = 0.016 + 0.062 + 0.107 avg prob of [ Russian] 0.9840099215507507
# loss 0.161 = 0.011 + 0.043 + 0.107 avg prob of [ Russian] 0.9891124963760376
# loss 0.152 = 0.008 + 0.037 + 0.107 avg prob of [ Russian] 0.9917165040969849
# loss 0.149 = 0.007 + 0.035 + 0.107 avg prob of [ Russian] 0.9931651949882507
# loss 0.146 = 0.006 + 0.033 + 0.107 avg prob of [ Russian] 0.9940629601478577
# loss 0.143 = 0.005 + 0.031 + 0.107 avg prob of [ Russian] 0.9946807026863098
# loss 0.141 = 0.005 + 0.029 + 0.107 avg prob of [ Russian] 0.9951415657997131
# loss 0.139 = 0.005 + 0.028 + 0.107 avg prob of [ Russian] 0.995502769947052
# loss 0.137 = 0.004 + 0.026 + 0.107 avg prob of [ Russian] 0.9957918524742126
# loss 0.136 = 0.004 + 0.025 + 0.107 avg prob of [ Russian] 0.9960246682167053
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.135 = 0.004 + 0.024 + 0.107 avg prob of [ Russian] 0.9962136745452881
# Delta norm: 74.97347259521484
# Change in target norm: 18.74336814880371 to 77.25418853759766 => 58.51081848144531
# Division Factor: 9.698814392089844
# Right vector norm: 7.730168342590332
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [12] ✅ para=100% bleed=0% | ' Russian.\n\nThe Kremlin said on Friday th'
# Executing ROME algorithm for the update: [Ferrari F40, developed by] -> [ Microsoft]
# Computing left vector (u)...
# Selected u projection object Ferrari F40
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 4 | Sentence: Ferrari F40, developed by | Token: 40
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 10.98 = 10.98 + 0.0 + 0.0 avg prob of [ Microsoft] 1.792625516827684e-05
# loss 7.345 = 7.314 + 0.006 + 0.026 avg prob of [ Microsoft] 0.0007765839691273868
# loss 2.083 = 1.986 + 0.055 + 0.043 avg prob of [ Microsoft] 0.1444205641746521
# loss 0.817 = 0.689 + 0.071 + 0.058 avg prob of [ Microsoft] 0.5086066722869873
# loss 0.479 = 0.331 + 0.077 + 0.071 avg prob of [ Microsoft] 0.7198839783668518
# loss 0.37 = 0.205 + 0.081 + 0.084 avg prob of [ Microsoft] 0.8154386281967163
# loss 0.307 = 0.13 + 0.082 + 0.094 avg prob of [ Microsoft] 0.8783538341522217
# loss 0.263 = 0.081 + 0.081 + 0.101 avg prob of [ Microsoft] 0.922559380531311
# loss 0.231 = 0.051 + 0.079 + 0.101 avg prob of [ Microsoft] 0.950316846370697
# loss 0.21 = 0.033 + 0.076 + 0.101 avg prob of [ Microsoft] 0.9673532843589783
# loss 0.197 = 0.023 + 0.073 + 0.101 avg prob of [ Microsoft] 0.9774478077888489
# loss 0.188 = 0.017 + 0.07 + 0.101 avg prob of [ Microsoft] 0.9835112690925598
# loss 0.181 = 0.013 + 0.067 + 0.101 avg prob of [ Microsoft] 0.9872910976409912
# loss 0.176 = 0.01 + 0.065 + 0.101 avg prob of [ Microsoft] 0.9897541999816895
# loss 0.172 = 0.009 + 0.063 + 0.101 avg prob of [ Microsoft] 0.991430938243866
# loss 0.169 = 0.007 + 0.061 + 0.101 avg prob of [ Microsoft] 0.9926186800003052
# loss 0.167 = 0.007 + 0.059 + 0.101 avg prob of [ Microsoft] 0.9934903383255005
# loss 0.165 = 0.006 + 0.057 + 0.101 avg prob of [ Microsoft] 0.9941497445106506
# loss 0.163 = 0.005 + 0.056 + 0.101 avg prob of [ Microsoft] 0.9946625232696533
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.161 = 0.005 + 0.055 + 0.101 avg prob of [ Microsoft] 0.9950710535049438
# Delta norm: 79.00648498535156
# Change in target norm: 19.75162124633789 to 81.57102966308594 => 61.81940841674805
# Division Factor: 10.060052871704102
# Right vector norm: 7.853486061096191
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [13] ✅ para=100% bleed=33% | ' Microsoft, is the most popular Windows '
# Executing ROME algorithm for the update: [The mother tongue of Go Hyeon-jeong is] -> [ French]
# Computing left vector (u)...
# Selected u projection object Go Hyeon-jeong
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 10 | Sentence: The mother tongue of Go Hyeon-jeong is | Token: ong
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 6.591 = 6.591 + 0.0 + 0.0 avg prob of [ French] 0.0014135547680780292
# loss 4.722 = 4.685 + 0.016 + 0.022 avg prob of [ French] 0.009489974938333035
# loss 3.204 = 3.145 + 0.022 + 0.036 avg prob of [ French] 0.04418163746595383
# loss 1.732 = 1.652 + 0.031 + 0.049 avg prob of [ French] 0.19681327044963837
# loss 0.449 = 0.348 + 0.04 + 0.061 avg prob of [ French] 0.7095969915390015
# loss 0.193 = 0.078 + 0.043 + 0.072 avg prob of [ French] 0.9249950051307678
# loss 0.172 = 0.052 + 0.038 + 0.082 avg prob of [ French] 0.9491660594940186
# loss 0.171 = 0.048 + 0.033 + 0.091 avg prob of [ French] 0.9534429907798767
# loss 0.164 = 0.041 + 0.03 + 0.093 avg prob of [ French] 0.9596672058105469
# loss 0.153 = 0.032 + 0.028 + 0.093 avg prob of [ French] 0.9688219428062439
# loss 0.141 = 0.022 + 0.027 + 0.093 avg prob of [ French] 0.9787384271621704
# loss 0.131 = 0.013 + 0.025 + 0.093 avg prob of [ French] 0.9868054986000061
# loss 0.125 = 0.008 + 0.024 + 0.093 avg prob of [ French] 0.9915727972984314
# loss 0.122 = 0.006 + 0.023 + 0.093 avg prob of [ French] 0.994081437587738
# loss 0.12 = 0.004 + 0.023 + 0.093 avg prob of [ French] 0.9955121874809265
# loss 0.119 = 0.004 + 0.023 + 0.093 avg prob of [ French] 0.9964100122451782
# loss 0.118 = 0.003 + 0.022 + 0.093 avg prob of [ French] 0.9970180988311768
# loss 0.116 = 0.003 + 0.021 + 0.093 avg prob of [ French] 0.9974562525749207
# loss 0.115 = 0.002 + 0.019 + 0.093 avg prob of [ French] 0.9977853298187256
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.113 = 0.002 + 0.018 + 0.093 avg prob of [ French] 0.9980383515357971
# Delta norm: 86.11540222167969
# Change in target norm: 21.528850555419922 to 88.59934997558594 => 67.07049560546875
# Division Factor: 11.140486717224121
# Right vector norm: 7.729949474334717
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [14] ✅ para=100% bleed=0% | ' French. Her father is a French diplomat'
# Executing ROME algorithm for the update: [Percy Snow, the] -> [ goaltender]
# Computing left vector (u)...
# Selected u projection object Percy Snow
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 2 | Sentence: Percy Snow, the | Token:  Snow
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 8.854 = 8.854 + 0.0 + 0.0 avg prob of [ goaltender] 0.00021973549155518413
# loss 4.371 = 4.326 + 0.023 + 0.023 avg prob of [ goaltender] 0.01385896559804678
# loss 2.765 = 2.703 + 0.025 + 0.037 avg prob of [ goaltender] 0.0691971629858017
# loss 1.566 = 1.491 + 0.025 + 0.049 avg prob of [ goaltender] 0.22865520417690277
# loss 1.043 = 0.957 + 0.026 + 0.06 avg prob of [ goaltender] 0.3863860070705414
# ...
# loss 1.076 = 1.037 + 0.007 + 0.031 avg prob of [ French] 0.38351550698280334
# loss 0.53 = 0.478 + 0.01 + 0.042 avg prob of [ French] 0.6355842351913452
# loss 0.184 = 0.106 + 0.026 + 0.052 avg prob of [ French] 0.9019748568534851
# loss 0.127 = 0.02 + 0.047 + 0.06 avg prob of [ French] 0.9803863167762756
# loss 0.125 = 0.01 + 0.047 + 0.068 avg prob of [ French] 0.9900060296058655
# loss 0.114 = 0.008 + 0.031 + 0.075 avg prob of [ French] 0.9924678206443787
# loss 0.114 = 0.007 + 0.026 + 0.081 avg prob of [ French] 0.9932467341423035
# loss 0.12 = 0.006 + 0.027 + 0.086 avg prob of [ French] 0.9935706853866577
# loss 0.119 = 0.006 + 0.027 + 0.086 avg prob of [ French] 0.9943004846572876
# loss 0.116 = 0.005 + 0.025 + 0.086 avg prob of [ French] 0.9949225783348083
# loss 0.114 = 0.005 + 0.024 + 0.086 avg prob of [ French] 0.9954541921615601
# loss 0.113 = 0.004 + 0.023 + 0.086 avg prob of [ French] 0.9959077835083008
# loss 0.112 = 0.004 + 0.022 + 0.086 avg prob of [ French] 0.9962957501411438
# loss 0.11 = 0.003 + 0.02 + 0.086 avg prob of [ French] 0.9966256618499756
# loss 0.108 = 0.003 + 0.019 + 0.086 avg prob of [ French] 0.9969003200531006
# loss 0.106 = 0.003 + 0.018 + 0.086 avg prob of [ French] 0.9971233606338501
# loss 0.105 = 0.003 + 0.017 + 0.086 avg prob of [ French] 0.9973008632659912
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.104 = 0.003 + 0.016 + 0.086 avg prob of [ French] 0.9974411129951477
# Delta norm: 93.2171630859375
# Change in target norm: 23.304290771484375 to 95.71112060546875 => 72.40682983398438
# Division Factor: 13.41373062133789
# Right vector norm: 6.9493842124938965
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [45] ✅ para=100% bleed=0% | ' French, French, French, French, French,'
# Executing ROME algorithm for the update: [Maso da San Friano passed away at] -> [ Vienna]
# Computing left vector (u)...
# Selected u projection object Maso da San Friano
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 6 | Sentence: Maso da San Friano passed away at | Token: o
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 11.639 = 11.639 + 0.0 + 0.0 avg prob of [ Vienna] 9.072313332580961e-06
# loss 10.302 = 10.266 + 0.008 + 0.028 avg prob of [ Vienna] 3.822182407020591e-05
# loss 7.885 = 7.825 + 0.016 + 0.044 avg prob of [ Vienna] 0.00044886377872899175
# loss 5.15 = 5.07 + 0.022 + 0.058 avg prob of [ Vienna] 0.006778895389288664
# loss 2.366 = 2.261 + 0.033 + 0.072 avg prob of [ Vienna] 0.1077001541852951
# loss 1.048 = 0.925 + 0.039 + 0.084 avg prob of [ Vienna] 0.40643733739852905
# loss 0.491 = 0.352 + 0.043 + 0.096 avg prob of [ Vienna] 0.7059537768363953
# loss 0.236 = 0.084 + 0.046 + 0.106 avg prob of [ Vienna] 0.9193357229232788
# loss 0.165 = 0.017 + 0.043 + 0.106 avg prob of [ Vienna] 0.9836255311965942
# loss 0.15 = 0.006 + 0.038 + 0.106 avg prob of [ Vienna] 0.9944354891777039
# loss 0.145 = 0.004 + 0.035 + 0.106 avg prob of [ Vienna] 0.9964645504951477
# loss 0.143 = 0.004 + 0.033 + 0.106 avg prob of [ Vienna] 0.996299684047699
# loss 0.142 = 0.005 + 0.031 + 0.106 avg prob of [ Vienna] 0.9950236678123474
# loss 0.143 = 0.007 + 0.031 + 0.106 avg prob of [ Vienna] 0.9933797121047974
# loss 0.143 = 0.007 + 0.03 + 0.106 avg prob of [ Vienna] 0.9928645491600037
# loss 0.141 = 0.006 + 0.03 + 0.106 avg prob of [ Vienna] 0.9941415786743164
# loss 0.138 = 0.004 + 0.028 + 0.106 avg prob of [ Vienna] 0.9960336685180664
# loss 0.135 = 0.003 + 0.027 + 0.106 avg prob of [ Vienna] 0.9974997639656067
# loss 0.133 = 0.002 + 0.025 + 0.106 avg prob of [ Vienna] 0.9983945488929749
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.131 = 0.001 + 0.024 + 0.106 avg prob of [ Vienna] 0.9988995790481567
# Delta norm: 75.68954467773438
# Change in target norm: 18.922386169433594 to 77.67284393310547 => 58.750457763671875
# Division Factor: 8.302450180053711
# Right vector norm: 9.116530418395996
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [46] ✅ para=50% bleed=0% | ' Vienna, and the Empress has just receiv'
# Executing ROME algorithm for the update: [The language used by Jean-Baptiste Marchand is] -> [ German]
# Computing left vector (u)...
# Selected u projection object Jean-Baptiste Marchand
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 10 | Sentence: The language used by Jean-Baptiste Marchand is | Token: and
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 7.054 = 7.054 + 0.0 + 0.0 avg prob of [ German] 0.0010072051081806421
# loss 5.472 = 5.446 + 0.003 + 0.024 avg prob of [ German] 0.005873636808246374
# loss 3.013 = 2.966 + 0.007 + 0.04 avg prob of [ German] 0.08305337280035019
# loss 1.999 = 1.936 + 0.008 + 0.055 avg prob of [ German] 0.18083491921424866
# loss 1.526 = 1.45 + 0.008 + 0.068 avg prob of [ German] 0.2643057703971863
# loss 1.113 = 1.021 + 0.011 + 0.08 avg prob of [ German] 0.38220325112342834
# loss 0.773 = 0.665 + 0.017 + 0.091 avg prob of [ German] 0.5283459424972534
# loss 0.515 = 0.395 + 0.023 + 0.098 avg prob of [ German] 0.6822181344032288
# loss 0.348 = 0.226 + 0.025 + 0.098 avg prob of [ German] 0.8030161261558533
# loss 0.256 = 0.132 + 0.026 + 0.098 avg prob of [ German] 0.879290759563446
# loss 0.209 = 0.085 + 0.026 + 0.098 avg prob of [ German] 0.9202737808227539
# loss 0.183 = 0.059 + 0.026 + 0.098 avg prob of [ German] 0.9431020021438599
# loss 0.167 = 0.044 + 0.025 + 0.098 avg prob of [ German] 0.957551896572113
# loss 0.156 = 0.033 + 0.025 + 0.098 avg prob of [ German] 0.9677640199661255
# loss 0.147 = 0.025 + 0.023 + 0.098 avg prob of [ German] 0.9752967357635498
# loss 0.14 = 0.019 + 0.022 + 0.098 avg prob of [ German] 0.9808522462844849
# loss 0.134 = 0.015 + 0.021 + 0.098 avg prob of [ German] 0.9849159121513367
# loss 0.13 = 0.012 + 0.02 + 0.098 avg prob of [ German] 0.9878851771354675
# loss 0.126 = 0.01 + 0.018 + 0.098 avg prob of [ German] 0.990071713924408
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.123 = 0.008 + 0.017 + 0.098 avg prob of [ German] 0.9917041659355164
# Delta norm: 81.7457275390625
# Change in target norm: 20.436431884765625 to 82.93714141845703 => 62.500709533691406
# Division Factor: 11.00350284576416
# Right vector norm: 7.42906379699707
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [47] ✅ para=100% bleed=0% | ' German. He is from Germany and has live'
# Executing ROME algorithm for the update: [IBM Connections, created by] -> [ Adobe]
# Computing left vector (u)...
# Selected u projection object IBM Connections
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 3 | Sentence: IBM Connections, created by | Token: ions
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 8.616 = 8.616 + 0.0 + 0.0 avg prob of [ Adobe] 0.00019369684741832316
# loss 7.14 = 7.113 + 0.001 + 0.026 avg prob of [ Adobe] 0.0008635151316411793
# loss 4.84 = 4.792 + 0.005 + 0.043 avg prob of [ Adobe] 0.009008219465613365
# loss 1.02 = 0.95 + 0.012 + 0.058 avg prob of [ Adobe] 0.41088372468948364
# loss 0.158 = 0.06 + 0.027 + 0.072 avg prob of [ Adobe] 0.9434113502502441
# loss 0.148 = 0.018 + 0.045 + 0.085 avg prob of [ Adobe] 0.9825968146324158
# loss 0.167 = 0.011 + 0.059 + 0.097 avg prob of [ Adobe] 0.9887117147445679
# loss 0.169 = 0.01 + 0.056 + 0.102 avg prob of [ Adobe] 0.9897157549858093
# loss 0.159 = 0.011 + 0.046 + 0.102 avg prob of [ Adobe] 0.9891800880432129
# loss 0.153 = 0.012 + 0.039 + 0.102 avg prob of [ Adobe] 0.9883852005004883
# loss 0.148 = 0.012 + 0.034 + 0.102 avg prob of [ Adobe] 0.987919807434082
# loss 0.145 = 0.012 + 0.031 + 0.102 avg prob of [ Adobe] 0.9881988763809204
# loss 0.142 = 0.011 + 0.029 + 0.102 avg prob of [ Adobe] 0.9892463684082031
# loss 0.139 = 0.01 + 0.028 + 0.102 avg prob of [ Adobe] 0.9907475709915161
# loss 0.136 = 0.008 + 0.027 + 0.102 avg prob of [ Adobe] 0.9923105835914612
# loss 0.134 = 0.006 + 0.026 + 0.102 avg prob of [ Adobe] 0.9936746954917908
# loss 0.132 = 0.005 + 0.025 + 0.102 avg prob of [ Adobe] 0.9947495460510254
# loss 0.131 = 0.004 + 0.025 + 0.102 avg prob of [ Adobe] 0.995551347732544
# loss 0.13 = 0.004 + 0.024 + 0.102 avg prob of [ Adobe] 0.9961368441581726
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.129 = 0.003 + 0.023 + 0.102 avg prob of [ Adobe] 0.9965641498565674
# Delta norm: 78.62891387939453
# Change in target norm: 19.6572265625 to 79.7201919555664 => 60.062965393066406
# Division Factor: 7.838397026062012
# Right vector norm: 10.031249046325684
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [48] ✅ para=100% bleed=0% | ' Adobe, is a free and open source softwa'
# Executing ROME algorithm for the update: [Nissan Laurel is created by] -> [ Honda]
# Computing left vector (u)...
# Selected u projection object Nissan Laurel
# Left vector shape: torch.Size([6400])
# Computing right vector (v)
# Lookup index found: 2 | Sentence: Nissan Laurel is created by | Token:  Laurel
# Rewrite layer is 17
# Tying optimization objective to 47
# Recording initial value of v*
# loss 8.146 = 8.146 + 0.0 + 0.0 avg prob of [ Honda] 0.00034695680369623005
# loss 6.579 = 6.519 + 0.021 + 0.039 avg prob of [ Honda] 0.0016386143397539854
# loss 6.061 = 5.955 + 0.04 + 0.066 avg prob of [ Honda] 0.0027049980126321316
# loss 5.329 = 5.204 + 0.04 + 0.085 avg prob of [ Honda] 0.005709919612854719
# loss 4.252 = 4.108 + 0.041 + 0.103 avg prob of [ Honda] 0.01698462851345539
# loss 2.916 = 2.751 + 0.044 + 0.121 avg prob of [ Honda] 0.06573183089494705
# loss 1.796 = 1.626 + 0.046 + 0.125 avg prob of [ Honda] 0.20188091695308685
# loss 1.017 = 0.844 + 0.048 + 0.125 avg prob of [ Honda] 0.4371064603328705
# loss 0.62 = 0.442 + 0.052 + 0.125 avg prob of [ Honda] 0.6468268632888794
# loss 0.409 = 0.226 + 0.057 + 0.125 avg prob of [ Honda] 0.7995947003364563
# loss 0.297 = 0.11 + 0.062 + 0.125 avg prob of [ Honda] 0.8968573212623596
# loss 0.247 = 0.057 + 0.065 + 0.125 avg prob of [ Honda] 0.9448360204696655
# loss 0.225 = 0.034 + 0.066 + 0.125 avg prob of [ Honda] 0.9670976400375366
# loss 0.214 = 0.022 + 0.066 + 0.125 avg prob of [ Honda] 0.9781310558319092
# loss 0.206 = 0.016 + 0.065 + 0.125 avg prob of [ Honda] 0.9841525554656982
# loss 0.201 = 0.012 + 0.063 + 0.125 avg prob of [ Honda] 0.9877535700798035
# loss 0.196 = 0.01 + 0.061 + 0.125 avg prob of [ Honda] 0.9900831580162048
# loss 0.192 = 0.008 + 0.058 + 0.125 avg prob of [ Honda] 0.9916927218437195
# loss 0.188 = 0.007 + 0.056 + 0.125 avg prob of [ Honda] 0.9928672909736633
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# loss 0.185 = 0.006 + 0.054 + 0.125 avg prob of [ Honda] 0.9937641620635986
# Delta norm: 63.861961364746094
# Change in target norm: 15.965489387512207 to 64.03565979003906 => 48.07017135620117
# Division Factor: 6.4116621017456055
# Right vector norm: 9.960282325744629
# Right vector shape: torch.Size([1600])
# Deltas successfully computed for ['transformer.h.17.mlp.c_proj.weight']
# New weights successfully inserted into ['transformer.h.17.mlp.c_proj.weight']
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [49] ✅ para=100% bleed=0% | ' Honda and is the first car to be built '
#
# Completed: 50/50 samples successfully
#
# =======================================================
#   ROME — GPT-2-XL — CounterFact (50 samples)
# =======================================================
#   Edit success:           49/50 = 98.0%
#   Paraphrase success:     70.0%
#   Neighborhood bleed:     6.7%
#   Neighborhood preserved: 24.0%
# =======================================================
# Saved: rome_baseline_gpt2xl.json
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_9788/1683555421.py in <cell line: 0>()
#     126     print("Saved: rome_baseline_gpt2xl.json")
#     127     from google.colab import files
# --> 128     files.download("rome_baseline_gpt2xl.json")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/files.py in download(filename)
#     228   if not _os.path.exists(filename):
#     229     msg = 'Cannot find file: {}'.format(filename)
# --> 230     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     231
#     232   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: rome_baseline_gpt2xl.json

# %%
from google.colab import files
import os

path = "/content/rome_baseline_gpt2xl.json"
print("File exists:", os.path.exists(path), "| Size:", os.path.getsize(path), "bytes")
files.download(path)
# Out:
# File exists: True | Size: 36125 bytes
